# %%
import sys  
sys.path.insert(0, '../')
sys.path.insert(0, '../baselines')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from baselines.common.atari_wrappers import make_atari, wrap_deepmind

# %%
from datetime import datetime

# %%
import random

# %%
class CONFIG:
    pass

config=CONFIG()

config.use_cuda=True
config.device="cuda:5"

config.env_id="PongNoFrameskip-v4"
config.exp_name=config.env_id+"-"+datetime.now().strftime("%Y_%m_%d_%H:%M:%S")
config.result_path=%pwd 
config.result_path+= '/../results/'
print('result path is'+config.result_path)

config.learning_rate = 0.0001
config.num_episodes = 1000
config.gamma=0.99
#gamma=0.85
config.egreedy = 0.9
config.egreedy_final = 0.01
config.egreedy_decay = 10000

config.report_interval=10

config.score_to_solve = 18.0

config.hidden_layer_size=512

config.replay_memory_size=100000

config.batch_size=32

config.update_target_frequency = 5000

config.clip_error=True
config.normalize_image=True

config.double_dqn=True

config.save_movies=True

config.save_model_frequency=10000

config.resume_previous_training=False
# Out:
# result path is/home/wfedorko/RL_sandbox/notebooks/../results/

# %%
from utils.engine import Engine

# %%
my_engine=Engine(config)
# Out:
# Directory  /home/wfedorko/RL_sandbox/notebooks/../results//PongNoFrameskip-v4-2020_04_17_23:41:07  Created
# will save movies

# %%
# %load_ext line_profiler

# %%
from agents.QNet_Agent import QNet_Agent
from models.models import SimpleCNNDuelingAllMean
from utils.ExperienceReplay import ExperienceReplay

# %%
# %lprun -f Engine.train_agent -f QNet_Agent.optimize -f SimpleCNNDuelingAllMean.forward -f ExperienceReplay.push -f ExperienceReplay.sample my_engine.train_agent()
# Out:
# **** Episode  10 ****
# Recent average reward: -20.6
# Average over all episodes so far: -20.6
# epsilon: 0.3393830840916455
# Elapsed time:  00:03:05
# **** Episode  20 ****
# Recent average reward: -20.5
# Average over all episodes so far: -20.55
# epsilon: 0.1464586260374244
# Elapsed time:  00:05:49
# **** Episode  30 ****
# Recent average reward: -20.5
# Average over all episodes so far: -20.533333333333335
# epsilon: 0.06655544377428248
# Elapsed time:  00:08:32
# **** Episode  40 ****
# Recent average reward: -19.8
# Average over all episodes so far: -20.35
# epsilon: 0.030745336257213568
# Elapsed time:  00:11:43
# **** Episode  50 ****
# Recent average reward: -19.4
# Average over all episodes so far: -20.16
# epsilon: 0.01675053298647325
# Elapsed time:  00:15:13
# **** Episode  60 ****
# Recent average reward: -19.1
# Average over all episodes so far: -19.983333333333334
# epsilon: 0.011384614086250458
# Elapsed time:  00:20:06
# **** Episode  70 ****
# Recent average reward: -16.9
# Average over all episodes so far: -19.542857142857144
# epsilon: 0.010184320620090535
# Elapsed time:  00:26:17
# **** Episode  80 ****
# Recent average reward: -15.0
# Average over all episodes so far: -18.975
# epsilon: 0.010016217270290523
# Elapsed time:  00:33:50
# **** Episode  90 ****
# Recent average reward: -15.5
# Average over all episodes so far: -18.58888888888889
# epsilon: 0.010001865775420418
# Elapsed time:  00:40:28
# **** Episode  100 ****
# Recent average reward: -15.1
# Average over all episodes so far: -18.24
# epsilon: 0.010000190553314336
# Elapsed time:  00:47:20
# **** Episode  110 ****
# Recent average reward: -15.7
# Reward over last 100: -17.75
# Average over all episodes so far: -18.009090909090908
# epsilon: 0.010000017838017971
# Elapsed time:  00:54:29
# **** Episode  120 ****
# Recent average reward: -15.5
# Reward over last 100: -17.25
# Average over all episodes so far: -17.8
# epsilon: 0.010000001676372145
# Elapsed time:  01:01:38
# **** Episode  130 ****
# Recent average reward: -16.4
# Reward over last 100: -16.84
# Average over all episodes so far: -17.692307692307693
# epsilon: 0.010000000170662394
# Elapsed time:  01:08:41
# **** Episode  140 ****
# Recent average reward: -14.1
# Reward over last 100: -16.27
# Average over all episodes so far: -17.435714285714287
# epsilon: 0.010000000012159215
# Elapsed time:  01:16:51
# **** Episode  150 ****
# Recent average reward: -13.3
# Reward over last 100: -15.66
# Average over all episodes so far: -17.16
# epsilon: 0.010000000000608042
# Elapsed time:  01:26:04
# **** Episode  160 ****
# Recent average reward: -13.1
# Reward over last 100: -15.06
# Average over all episodes so far: -16.90625
# epsilon: 0.01000000000003267
# Elapsed time:  01:35:05
# **** Episode  170 ****
# Recent average reward: -13.6
# Reward over last 100: -14.73
# Average over all episodes so far: -16.711764705882352
# epsilon: 0.010000000000001485
# Elapsed time:  01:44:35
# **** Episode  180 ****
# Recent average reward: -10.0
# Reward over last 100: -14.23
# Average over all episodes so far: -16.33888888888889
# epsilon: 0.01000000000000005
# Elapsed time:  01:54:51
# **** Episode  190 ****
# Recent average reward: -8.4
# Reward over last 100: -13.52
# Average over all episodes so far: -15.921052631578947
# epsilon: 0.010000000000000002
# Elapsed time:  02:05:35
# **** Episode  200 ****
# Recent average reward: -6.1
# Reward over last 100: -12.62
# Average over all episodes so far: -15.43
# epsilon: 0.01
# Elapsed time:  02:15:53
# **** Episode  210 ****
# Recent average reward: -4.4
# Reward over last 100: -11.49
# Average over all episodes so far: -14.904761904761905
# epsilon: 0.01
# Elapsed time:  02:27:05
# **** Episode  220 ****
# Recent average reward: 3.6
# Reward over last 100: -9.58
# Average over all episodes so far: -14.063636363636364
# epsilon: 0.01
# Elapsed time:  02:37:54
# **** Episode  230 ****
# Recent average reward: 2.3
# Reward over last 100: -7.71
# Average over all episodes so far: -13.352173913043478
# epsilon: 0.01
# Elapsed time:  02:48:34
# **** Episode  240 ****
# Recent average reward: 4.5
# Reward over last 100: -5.85
# Average over all episodes so far: -12.608333333333333
# epsilon: 0.01
# Elapsed time:  02:58:20
# **** Episode  250 ****
# Recent average reward: 9.9
# Reward over last 100: -3.53
# Average over all episodes so far: -11.708
# epsilon: 0.01
# Elapsed time:  03:06:49
# **** Episode  260 ****
# Recent average reward: 11.2
# Reward over last 100: -1.1
# Average over all episodes so far: -10.826923076923077
# epsilon: 0.01
# Elapsed time:  03:15:03
# **** Episode  270 ****
# Recent average reward: 12.9
# Reward over last 100: 1.55
# Average over all episodes so far: -9.948148148148148
# epsilon: 0.01
# Elapsed time:  03:22:57
# **** Episode  280 ****
# Recent average reward: 17.2
# Reward over last 100: 4.27
# Average over all episodes so far: -8.978571428571428
# epsilon: 0.01
# Elapsed time:  03:28:56
# **** Episode  290 ****
# Recent average reward: 16.6
# Reward over last 100: 6.77
# Average over all episodes so far: -8.096551724137932
# epsilon: 0.01
# Elapsed time:  03:35:20
# **** Episode  300 ****
# Recent average reward: 15.0
# Reward over last 100: 8.88
# Average over all episodes so far: -7.326666666666667
# epsilon: 0.01
# Elapsed time:  03:42:02
# **** Episode  310 ****
# Recent average reward: 17.1
# Reward over last 100: 11.03
# Average over all episodes so far: -6.538709677419355
# epsilon: 0.01
# Elapsed time:  03:48:17
# **** Episode  320 ****
# Recent average reward: 18.8
# Reward over last 100: 12.55
# Average over all episodes so far: -5.746875
# epsilon: 0.01
# Elapsed time:  03:54:04
# **** Episode  330 ****
# Recent average reward: 17.4
# Reward over last 100: 14.06
# Average over all episodes so far: -5.045454545454546
# epsilon: 0.01
# Elapsed time:  04:00:26
# **** Episode  340 ****
# Recent average reward: 18.7
# Reward over last 100: 15.48
# Average over all episodes so far: -4.347058823529411
# epsilon: 0.01
# Elapsed time:  04:06:20
# **** Episode  350 ****
# Recent average reward: 18.1
# Reward over last 100: 16.3
# Average over all episodes so far: -3.7057142857142855
# epsilon: 0.01
# Elapsed time:  04:12:08
# **** Episode  360 ****
# Recent average reward: 16.3
# Reward over last 100: 16.81
# Average over all episodes so far: -3.15
# epsilon: 0.01
# Elapsed time:  04:18:25
# **** Episode  370 ****
# Recent average reward: 19.1
# Reward over last 100: 17.43
# Average over all episodes so far: -2.5486486486486486
# epsilon: 0.01
# Elapsed time:  04:24:01
# **** Episode  380 ****
# Recent average reward: 18.6
# Reward over last 100: 17.57
# Average over all episodes so far: -1.9921052631578948
# epsilon: 0.01
# Elapsed time:  04:29:40
# **** Episode  390 ****
# Recent average reward: 19.8
# Reward over last 100: 17.89
# Average over all episodes so far: -1.4333333333333333
# epsilon: 0.01
# Elapsed time:  04:35:08
# SOLVED! After 392 episodes
# **** Episode  400 ****
# Recent average reward: 19.5
# Reward over last 100: 18.34
# Average over all episodes so far: -0.91
# epsilon: 0.01
# Elapsed time:  04:40:42
# **** Episode  410 ****
# Recent average reward: 17.7
# Reward over last 100: 18.4
# Average over all episodes so far: -0.4560975609756098
# epsilon: 0.01
# Elapsed time:  04:46:29
# **** Episode  420 ****
# Recent average reward: 19.3
# Reward over last 100: 18.45
# Average over all episodes so far: 0.014285714285714285
# epsilon: 0.01
# Elapsed time:  04:51:58
# **** Episode  430 ****
# Recent average reward: 18.1
# Reward over last 100: 18.52
# Average over all episodes so far: 0.43488372093023253
# epsilon: 0.01
# Elapsed time:  04:57:51
# **** Episode  440 ****
# Recent average reward: 19.0
# Reward over last 100: 18.55
# Average over all episodes so far: 0.8568181818181818
# epsilon: 0.01
# Elapsed time:  05:03:16
# **** Episode  450 ****
# Recent average reward: 17.9
# Reward over last 100: 18.53
# Average over all episodes so far: 1.2355555555555555
# epsilon: 0.01
# Elapsed time:  05:09:03
# **** Episode  460 ****
# Recent average reward: 18.8
# Reward over last 100: 18.78
# Average over all episodes so far: 1.617391304347826
# epsilon: 0.01
# Elapsed time:  05:14:39
# **** Episode  470 ****
# Recent average reward: 17.8
# Reward over last 100: 18.65
# Average over all episodes so far: 1.9617021276595745
# epsilon: 0.01
# Elapsed time:  05:20:29
# **** Episode  480 ****
# Recent average reward: 19.6
# Reward over last 100: 18.75
# Average over all episodes so far: 2.3291666666666666
# epsilon: 0.01
# Elapsed time:  05:25:56
# **** Episode  490 ****
# Recent average reward: 19.2
# Reward over last 100: 18.69
# Average over all episodes so far: 2.673469387755102
# epsilon: 0.01
# Elapsed time:  05:31:26
# **** Episode  500 ****
# Recent average reward: 19.6
# Reward over last 100: 18.7
# Average over all episodes so far: 3.012
# epsilon: 0.01
# Elapsed time:  05:36:45
# **** Episode  510 ****
# Recent average reward: 18.4
# Reward over last 100: 18.77
# Average over all episodes so far: 3.3137254901960786
# epsilon: 0.01
# Elapsed time:  05:42:28
# **** Episode  520 ****
# Recent average reward: 19.0
# Reward over last 100: 18.74
# Average over all episodes so far: 3.6153846153846154
# epsilon: 0.01
# Elapsed time:  05:47:59
# **** Episode  530 ****
# Recent average reward: 19.1
# Reward over last 100: 18.84
# Average over all episodes so far: 3.9075471698113207
# epsilon: 0.01
# Elapsed time:  05:53:27
# **** Episode  540 ****
# Recent average reward: 17.3
# Reward over last 100: 18.67
# Average over all episodes so far: 4.155555555555556
# epsilon: 0.01
# Elapsed time:  05:59:53
# **** Episode  550 ****
# Recent average reward: 18.3
# Reward over last 100: 18.71
# Average over all episodes so far: 4.412727272727273
# epsilon: 0.01
# Elapsed time:  06:05:42
# **** Episode  560 ****
# Recent average reward: 18.7
# Reward over last 100: 18.7
# Average over all episodes so far: 4.667857142857143
# epsilon: 0.01
# Elapsed time:  06:11:32
# **** Episode  570 ****
# Recent average reward: 18.9
# Reward over last 100: 18.81
# Average over all episodes so far: 4.917543859649123
# epsilon: 0.01
# Elapsed time:  06:17:17
# **** Episode  580 ****
# Recent average reward: 19.0
# Reward over last 100: 18.75
# Average over all episodes so far: 5.160344827586207
# epsilon: 0.01
# Elapsed time:  06:23:09
# **** Episode  590 ****
# Recent average reward: 19.3
# Reward over last 100: 18.76
# Average over all episodes so far: 5.4
# epsilon: 0.01
# Elapsed time:  06:28:56
# **** Episode  600 ****
# Recent average reward: 19.3
# Reward over last 100: 18.73
# Average over all episodes so far: 5.631666666666667
# epsilon: 0.01
# Elapsed time:  06:34:38
# **** Episode  610 ****
# Recent average reward: 20.0
# Reward over last 100: 18.89
# Average over all episodes so far: 5.867213114754098
# epsilon: 0.01
# Elapsed time:  06:40:10
# **** Episode  620 ****
# Recent average reward: 18.7
# Reward over last 100: 18.86
# Average over all episodes so far: 6.074193548387097
# epsilon: 0.01
# Elapsed time:  06:46:02
# **** Episode  630 ****
# Recent average reward: 20.1
# Reward over last 100: 18.96
# Average over all episodes so far: 6.296825396825397
# epsilon: 0.01
# Elapsed time:  06:51:38
# **** Episode  640 ****
# Recent average reward: 20.1
# Reward over last 100: 19.24
# Average over all episodes so far: 6.5125
# epsilon: 0.01
# Elapsed time:  06:57:05
# **** Episode  650 ****
# Recent average reward: 18.8
# Reward over last 100: 19.29
# Average over all episodes so far: 6.701538461538462
# epsilon: 0.01
# Elapsed time:  07:02:56
# **** Episode  660 ****
# Recent average reward: 18.8
# Reward over last 100: 19.3
# Average over all episodes so far: 6.884848484848485
# epsilon: 0.01
# Elapsed time:  07:08:42
# **** Episode  670 ****
# Recent average reward: 18.8
# Reward over last 100: 19.29
# Average over all episodes so far: 7.062686567164179
# epsilon: 0.01
# Elapsed time:  07:14:21
# **** Episode  680 ****
# Recent average reward: 19.0
# Reward over last 100: 19.29
# Average over all episodes so far: 7.238235294117647
# epsilon: 0.01
# Elapsed time:  07:20:03
# **** Episode  690 ****
# Recent average reward: 18.9
# Reward over last 100: 19.25
# Average over all episodes so far: 7.407246376811594
# epsilon: 0.01
# Elapsed time:  07:25:52
# **** Episode  700 ****
# Recent average reward: 18.6
# Reward over last 100: 19.18
# Average over all episodes so far: 7.567142857142857
# epsilon: 0.01
# Elapsed time:  07:31:45
# **** Episode  710 ****
# Recent average reward: 19.1
# Reward over last 100: 19.09
# Average over all episodes so far: 7.729577464788733
# epsilon: 0.01
# Elapsed time:  07:37:32
# **** Episode  720 ****
# Recent average reward: 19.0
# Reward over last 100: 19.12
# Average over all episodes so far: 7.886111111111111
# epsilon: 0.01
# Elapsed time:  07:43:12
# **** Episode  730 ****
# Recent average reward: 19.3
# Reward over last 100: 19.04
# Average over all episodes so far: 8.042465753424658
# epsilon: 0.01
# Elapsed time:  07:48:50
# **** Episode  740 ****
# Recent average reward: 20.1
# Reward over last 100: 19.04
# Average over all episodes so far: 8.205405405405406
# epsilon: 0.01
# Elapsed time:  07:54:22
# **** Episode  750 ****
# Recent average reward: 19.9
# Reward over last 100: 19.15
# Average over all episodes so far: 8.361333333333333
# epsilon: 0.01
# Elapsed time:  07:59:57
# **** Episode  760 ****
# Recent average reward: 20.1
# Reward over last 100: 19.28
# Average over all episodes so far: 8.51578947368421
# epsilon: 0.01
# Elapsed time:  08:05:26
# **** Episode  770 ****
# Recent average reward: 20.0
# Reward over last 100: 19.4
# Average over all episodes so far: 8.664935064935065
# epsilon: 0.01
# Elapsed time:  08:10:54
# **** Episode  780 ****
# Recent average reward: 19.3
# Reward over last 100: 19.43
# Average over all episodes so far: 8.801282051282051
# epsilon: 0.01
# Elapsed time:  08:16:37
# **** Episode  790 ****
# Recent average reward: 19.6
# Reward over last 100: 19.5
# Average over all episodes so far: 8.937974683544304
# epsilon: 0.01
# Elapsed time:  08:22:15
# **** Episode  800 ****
# Recent average reward: 19.7
# Reward over last 100: 19.61
# Average over all episodes so far: 9.0725
# epsilon: 0.01
# Elapsed time:  08:27:50
# **** Episode  810 ****
# Recent average reward: 19.3
# Reward over last 100: 19.63
# Average over all episodes so far: 9.198765432098766
# epsilon: 0.01
# Elapsed time:  08:33:24
# **** Episode  820 ****
# Recent average reward: 19.3
# Reward over last 100: 19.66
# Average over all episodes so far: 9.321951219512195
# epsilon: 0.01
# Elapsed time:  08:38:58
# **** Episode  830 ****
# Recent average reward: 19.9
# Reward over last 100: 19.72
# Average over all episodes so far: 9.449397590361446
# epsilon: 0.01
# Elapsed time:  08:44:21
# **** Episode  840 ****
# Recent average reward: 20.1
# Reward over last 100: 19.72
# Average over all episodes so far: 9.576190476190476
# epsilon: 0.01
# Elapsed time:  08:49:48
# **** Episode  850 ****
# Recent average reward: 18.9
# Reward over last 100: 19.62
# Average over all episodes so far: 9.685882352941176
# epsilon: 0.01
# Elapsed time:  08:55:22
# **** Episode  860 ****
# Recent average reward: 18.9
# Reward over last 100: 19.5
# Average over all episodes so far: 9.793023255813953
# epsilon: 0.01
# Elapsed time:  09:00:49
# **** Episode  870 ****
# Recent average reward: 19.2
# Reward over last 100: 19.42
# Average over all episodes so far: 9.901149425287356
# epsilon: 0.01
# Elapsed time:  09:06:30
# **** Episode  880 ****
# Recent average reward: 19.3
# Reward over last 100: 19.42
# Average over all episodes so far: 10.007954545454545
# epsilon: 0.01
# Elapsed time:  09:12:02
# **** Episode  890 ****
# Recent average reward: 19.8
# Reward over last 100: 19.44
# Average over all episodes so far: 10.117977528089888
# epsilon: 0.01
# Elapsed time:  09:17:38
# **** Episode  900 ****
# Recent average reward: 19.5
# Reward over last 100: 19.42
# Average over all episodes so far: 10.222222222222221
# epsilon: 0.01
# Elapsed time:  09:23:09
# **** Episode  910 ****
# Recent average reward: 19.7
# Reward over last 100: 19.46
# Average over all episodes so far: 10.326373626373627
# epsilon: 0.01
# Elapsed time:  09:28:43
# **** Episode  920 ****
# Recent average reward: 19.8
# Reward over last 100: 19.51
# Average over all episodes so far: 10.429347826086957
# epsilon: 0.01
# Elapsed time:  09:34:00
# **** Episode  930 ****
# Recent average reward: 19.1
# Reward over last 100: 19.43
# Average over all episodes so far: 10.522580645161291
# epsilon: 0.01
# Elapsed time:  09:39:38
# **** Episode  940 ****
# Recent average reward: 19.1
# Reward over last 100: 19.33
# Average over all episodes so far: 10.613829787234042
# epsilon: 0.01
# Elapsed time:  09:45:15
# **** Episode  950 ****
# Recent average reward: 19.7
# Reward over last 100: 19.41
# Average over all episodes so far: 10.709473684210526
# epsilon: 0.01
# Elapsed time:  09:50:43
# **** Episode  960 ****
# Recent average reward: 19.6
# Reward over last 100: 19.48
# Average over all episodes so far: 10.802083333333334
# epsilon: 0.01
# Elapsed time:  09:56:13
# **** Episode  970 ****
# Recent average reward: 19.7
# Reward over last 100: 19.53
# Average over all episodes so far: 10.893814432989691
# epsilon: 0.01
# Elapsed time:  10:01:33
# **** Episode  980 ****
# Recent average reward: 19.3
# Reward over last 100: 19.53
# Average over all episodes so far: 10.979591836734693
# epsilon: 0.01
# Elapsed time:  10:07:12
# **** Episode  990 ****
# Recent average reward: 19.0
# Reward over last 100: 19.45
# Average over all episodes so far: 11.06060606060606
# epsilon: 0.01
# Elapsed time:  10:12:42
# Solved after 392 episodes
