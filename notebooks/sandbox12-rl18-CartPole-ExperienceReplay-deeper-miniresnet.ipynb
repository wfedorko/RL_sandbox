# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython import display

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
import numpy as np
import math
import random

# %%
import time

# %%
def show_state(env, episode,step, info=""):
    plt.figure(99999,figsize=[8,6])
    plt.clf()
    plt.imshow(env.render(mode='rgb_array'))
    plt.title("episode: {} step: {} ".format(episode,step))
    #plt.title("%s | Step: %d %s" % (env._spec.id,step, info))
    plt.axis('off')

    display.clear_output(wait=True)
    display.display(plt.gcf())

# %%
import gym

# %%
use_cuda = torch.cuda.is_available()
device=torch.device("cuda:4" if use_cuda else "cpu")

# %%
###### PARAMS ######
learning_rate = 0.01
num_episodes = 1000
gamma=0.99
#gamma=0.85
egreedy = 0.9
egreedy_final = 0.02
egreedy_decay = 500

report_interval=10

score_to_solve = 195

hidden_layer_size=64

replay_memory_size=50000

batch_size=32

# %%
env = gym.make('CartPole-v1')

# %%
#env = gym.wrappers.Monitor(env, '../mp4/sandbox10',video_callable=lambda episode_id: True,force=True)
#env = gym.wrappers.Monitor(env, '../mp4/cartpole-5',video_callable=lambda episode_id: episode_id%10==0)

# %%
number_of_inputs=env.observation_space.shape[0]
number_of_outputs=env.action_space.n

# %%
def calculate_epsilon(steps_done):
    epsilon = egreedy_final + (egreedy - egreedy_final) * \
              math.exp(-1. * steps_done / egreedy_decay )
    return epsilon

# %%
class ExperienceReplay():
    def __init__(self, capacity):
        self.capacity=capacity
        self.memory=[]
        self.position=0
        
    
    def push(self, state,
             action, new_state,
             reward, done):
        
            transition=(state,action,new_state,reward,done)
            
            if self.position>=len(self.memory):
                self.memory.append(transition)
            else:
                self.memory[self.position]=transition
                
            self.position=(self.position+1)%self.capacity
        
    
    def sample(self,batch_size):
        return zip(*random.sample(self.memory, batch_size))
    
    def __len__(self):
        return len(self.memory)

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.linear_in = nn.Linear(number_of_inputs,hidden_layer_size)
        self.linearh1 = nn.Linear(hidden_layer_size,hidden_layer_size)
        self.bn1=nn.BatchNorm1d(hidden_layer_size)
        #self.linearh2 = nn.Linear(hidden_layer_size,hidden_layer_size)
        #self.linearh3 = nn.Linear(hidden_layer_size,hidden_layer_size)
        #self.linearh4 = nn.Linear(hidden_layer_size,hidden_layer_size)
        self.linear_out = nn.Linear(hidden_layer_size,number_of_outputs)
        
        self.activation=nn.Tanh()
        
    def forward(self, x):
        x = self.linear_in(x)
        x = self.activation(x)
        
        skip=x
        #print(x.shape)
        x=self.bn1(x)
        x = self.linearh1(x)
        x = self.activation(x)
        x=x+skip
        
        #x = self.linearh2(x)
        #x = self.activation(x)
        
        #x = self.linearh3(x)
        #x = self.activation(x)
        
        #x = self.linearh4(x)
        #x = self.activation(x)
        
        output = self.linear_out(x)
        
        return output

# %%
class QNet_Agent():
    def __init__(self):
        self.nn = NeuralNetwork().to(device)
        self.loss_function = nn.MSELoss()
        self.optimizer = optim.Adam(params=self.nn.parameters(), lr=learning_rate)
        
    def select_action(self,state,epsilon):
        
        random_for_egreedy=torch.rand(1).item()
        
        if random_for_egreedy>epsilon:
            self.nn.eval()
            with torch.no_grad():
                state=torch.Tensor(state).to(device)
                predicted_value_from_nn=torch.squeeze(self.nn(torch.unsqueeze(state,0)))
                action=torch.argmax(predicted_value_from_nn).item()
        else:
            action=env.action_space.sample()
                
                
        return action
    
    def optimize(self):
        
        if len(memory)<batch_size:
            return
        
        state, action, new_state, reward, done = memory.sample(batch_size)
        
        state=torch.Tensor(state).to(device)
        new_state=torch.Tensor(new_state).to(device)
        reward=torch.Tensor(reward).to(device)
        
        #the view call below is to transform into column vector
        #so that it can be used in the gather call
        #i.e. we will use it to pick out from the computed value
        #tensor only values indexed by selected action
        action=(torch.Tensor(action).view(-1,1).long()).to(device)
        #print('action: ')
        #print(action)
        #print('contiguous?', action.is_contiguous())
        done=torch.Tensor(done).to(device)
        
        #print('shape of: state, new state, reward, action, done:')
        #print(state.shape)
        #print(new_state.shape)
        #print(reward.shape)
        #print(action.shape)
        #print(done.shape)
        
        
        self.nn.eval()
            
        new_state_values=self.nn(new_state).detach()
        #print('shape of: new_state_values')
        #print(new_state_values.shape)
        
        max_new_state_values=torch.max(new_state_values,dim=1)[0]
        #print('shape of: max_new_state_values')
        #print(max_new_state_values.shape)
        target_value=(reward + (1-done)*gamma*max_new_state_values).view(-1,1)
        
        #print('shape of: target_value')
        #print(target_value.shape)
        self.nn.train()
        
        #this will select only the values of the desired actions
        predicted_value=torch.gather(self.nn(state),1,action)
        #print('shape of: predicted_value')
        #print(predicted_value.shape)
        
        
        loss=self.loss_function(predicted_value,target_value)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

# %%
memory=ExperienceReplay(replay_memory_size)

# %%
qnet_agent=QNet_Agent()

# %%
seed_value=23
env.seed(seed_value)
torch.manual_seed(seed_value)
random.seed(seed_value)

# %%
# %%time

num_episodes=1000

steps_total=np.full([num_episodes],-999,dtype=np.int32)

frames_total=0

solved_after = 0
solved = False

start_time = time.time()

for i_episode in range(num_episodes):
    
    state = env.reset()
    #for step in range(100):
    step=0
    while True:
        
        step+=1
        frames_total += 1
        
        epsilon=calculate_epsilon(frames_total)
        
        #action=env.action_space.sample()
        action=qnet_agent.select_action(state,epsilon)
        
        new_state, reward, done, info = env.step(action)
        memory.push(state, action, new_state,
                     reward, done)
        
        qnet_agent.optimize()
        
        state=new_state
        
        if done:
            steps_total[i_episode]=step
            
            if i_episode>100:
                mean_reward_100 = np.sum(steps_total[i_episode-100:i_episode])/100
            
                if (mean_reward_100 > score_to_solve and solved == False):
                    print("SOLVED! After %i episodes " % i_episode)
                    solved_after = i_episode
                    solved = True
            
            if (i_episode % report_interval == 0 and i_episode>1):
                print("**** Episode  {} **** ".format(i_episode))
                recent_avg_reward=np.average(steps_total[i_episode-report_interval:i_episode])
                print("Recent average reward: {}".format(recent_avg_reward))
                if i_episode>100:
                    print("Reward over last 100: {}".format(mean_reward_100))
                full_avg_so_far=np.average(steps_total[:i_episode])
                print("Average over all episodes so far: {}".format(full_avg_so_far))
                print("epsilon: {}".format(epsilon))
            
                #print("Episode {} finished after: {}".format(i_episode,step))
            break
            
if solved:
    print("Solved after %i episodes" % solved_after)
# Out:
# **** Episode  10 ****
# Recent average reward: 16.5
# Average over all episodes so far: 16.5
# epsilon: 0.6364159058070221
# **** Episode  20 ****
# Recent average reward: 46.1
# Average over all episodes so far: 31.3
# epsilon: 0.2463136587108341
# **** Episode  30 ****
# Recent average reward: 88.9
# Average over all episodes so far: 50.5
# epsilon: 0.052849019854115234
# **** Episode  40 ****
# Recent average reward: 199.5
# Average over all episodes so far: 87.75
# epsilon: 0.020533616377424072
# **** Episode  50 ****
# Recent average reward: 136.5
# Average over all episodes so far: 97.5
# epsilon: 0.020034941568203485
# **** Episode  60 ****
# Recent average reward: 236.7
# Average over all episodes so far: 120.7
# epsilon: 0.020000165907841986
# **** Episode  70 ****
# Recent average reward: 364.0
# Average over all episodes so far: 155.45714285714286
# epsilon: 0.02000000011434129
# **** Episode  80 ****
# Recent average reward: 357.9
# Average over all episodes so far: 180.7625
# epsilon: 0.020000000000164178
# **** Episode  90 ****
# Recent average reward: 370.7
# Average over all episodes so far: 201.86666666666667
# epsilon: 0.020000000000000052
# **** Episode  100 ****
# Recent average reward: 386.4
# Average over all episodes so far: 220.32
# epsilon: 0.02
# SOLVED! After 101 episodes
# **** Episode  110 ****
# Recent average reward: 343.9
# Reward over last 100: 253.06
# Average over all episodes so far: 231.55454545454546
# epsilon: 0.02
# **** Episode  120 ****
# Recent average reward: 355.2
# Reward over last 100: 283.97
# Average over all episodes so far: 241.85833333333332
# epsilon: 0.02
# **** Episode  130 ****
# Recent average reward: 445.2
# Reward over last 100: 319.6
# Average over all episodes so far: 257.5
# epsilon: 0.02
# **** Episode  140 ****
# Recent average reward: 333.1
# Reward over last 100: 332.96
# Average over all episodes so far: 262.9
# epsilon: 0.02
# **** Episode  150 ****
# Recent average reward: 471.6
# Reward over last 100: 366.47
# Average over all episodes so far: 276.81333333333333
# epsilon: 0.02
# **** Episode  160 ****
# Recent average reward: 345.6
# Reward over last 100: 377.36
# Average over all episodes so far: 281.1125
# epsilon: 0.02
# **** Episode  170 ****
# Recent average reward: 457.3
# Reward over last 100: 386.69
# Average over all episodes so far: 291.4764705882353
# epsilon: 0.02
# **** Episode  180 ****
# Recent average reward: 366.7
# Reward over last 100: 387.57
# Average over all episodes so far: 295.65555555555557
# epsilon: 0.02
# **** Episode  190 ****
# Recent average reward: 155.7
# Reward over last 100: 366.07
# Average over all episodes so far: 288.2894736842105
# epsilon: 0.02
# **** Episode  200 ****
# Recent average reward: 237.5
# Reward over last 100: 351.18
# Average over all episodes so far: 285.75
# epsilon: 0.02
# **** Episode  210 ****
# Recent average reward: 410.6
# Reward over last 100: 357.85
# Average over all episodes so far: 291.6952380952381
# epsilon: 0.02
# **** Episode  220 ****
# Recent average reward: 402.1
# Reward over last 100: 362.54
# Average over all episodes so far: 296.71363636363634
# epsilon: 0.02
# **** Episode  230 ****
# Recent average reward: 312.0
# Reward over last 100: 349.22
# Average over all episodes so far: 297.3782608695652
# epsilon: 0.02
# **** Episode  240 ****
# Recent average reward: 218.4
# Reward over last 100: 337.75
# Average over all episodes so far: 294.0875
# epsilon: 0.02
# **** Episode  250 ****
# Recent average reward: 224.8
# Reward over last 100: 313.07
# Average over all episodes so far: 291.316
# epsilon: 0.02
# **** Episode  260 ****
# Recent average reward: 270.1
# Reward over last 100: 305.52
# Average over all episodes so far: 290.5
# epsilon: 0.02
# **** Episode  270 ****
# Recent average reward: 128.7
# Reward over last 100: 272.66
# Average over all episodes so far: 284.5074074074074
# epsilon: 0.02
# **** Episode  280 ****
# Recent average reward: 153.5
# Reward over last 100: 251.34
# Average over all episodes so far: 279.8285714285714
# epsilon: 0.02
# **** Episode  290 ****
# Recent average reward: 350.7
# Reward over last 100: 270.84
# Average over all episodes so far: 282.27241379310345
# epsilon: 0.02
# **** Episode  300 ****
# Recent average reward: 424.6
# Reward over last 100: 289.55
# Average over all episodes so far: 287.01666666666665
# epsilon: 0.02
# **** Episode  310 ****
# Recent average reward: 399.9
# Reward over last 100: 288.48
# Average over all episodes so far: 290.65806451612906
# epsilon: 0.02
# **** Episode  320 ****
# Recent average reward: 465.3
# Reward over last 100: 294.8
# Average over all episodes so far: 296.115625
# epsilon: 0.02
# **** Episode  330 ****
# Recent average reward: 354.9
# Reward over last 100: 299.09
# Average over all episodes so far: 297.8969696969697
# epsilon: 0.02
# **** Episode  340 ****
# Recent average reward: 369.4
# Reward over last 100: 314.19
# Average over all episodes so far: 300.0
# epsilon: 0.02
# **** Episode  350 ****
# Recent average reward: 243.1
# Reward over last 100: 316.02
# Average over all episodes so far: 298.3742857142857
# epsilon: 0.02
# **** Episode  360 ****
# Recent average reward: 304.6
# Reward over last 100: 319.47
# Average over all episodes so far: 298.5472222222222
# epsilon: 0.02
# **** Episode  370 ****
# Recent average reward: 445.6
# Reward over last 100: 351.16
# Average over all episodes so far: 302.52162162162165
# epsilon: 0.02
# **** Episode  380 ****
# Recent average reward: 417.9
# Reward over last 100: 377.6
# Average over all episodes so far: 305.5578947368421
# epsilon: 0.02
# **** Episode  390 ****
# Recent average reward: 333.4
# Reward over last 100: 375.87
# Average over all episodes so far: 306.2717948717949
# epsilon: 0.02
# **** Episode  400 ****
# Recent average reward: 418.1
# Reward over last 100: 375.22
# Average over all episodes so far: 309.0675
# epsilon: 0.02
# **** Episode  410 ****
# Recent average reward: 458.3
# Reward over last 100: 381.06
# Average over all episodes so far: 312.7073170731707
# epsilon: 0.02
# **** Episode  420 ****
# Recent average reward: 464.7
# Reward over last 100: 381.0
# Average over all episodes so far: 316.3261904761905
# epsilon: 0.02
# **** Episode  430 ****
# Recent average reward: 374.3
# Reward over last 100: 382.94
# Average over all episodes so far: 317.6744186046512
# epsilon: 0.02
# **** Episode  440 ****
# Recent average reward: 281.3
# Reward over last 100: 374.13
# Average over all episodes so far: 316.8477272727273
# epsilon: 0.02
# **** Episode  450 ****
# Recent average reward: 360.6
# Reward over last 100: 385.88
# Average over all episodes so far: 317.82
# epsilon: 0.02
# **** Episode  460 ****
# Recent average reward: 420.9
# Reward over last 100: 397.51
# Average over all episodes so far: 320.0608695652174
# epsilon: 0.02
# **** Episode  470 ****
# Recent average reward: 493.4
# Reward over last 100: 402.29
# Average over all episodes so far: 323.74893617021274
# epsilon: 0.02
# **** Episode  480 ****
# Recent average reward: 273.9
# Reward over last 100: 387.89
# Average over all episodes so far: 322.7104166666667
# epsilon: 0.02
# **** Episode  490 ****
# Recent average reward: 196.4
# Reward over last 100: 374.19
# Average over all episodes so far: 320.1326530612245
# epsilon: 0.02
# **** Episode  500 ****
# Recent average reward: 177.0
# Reward over last 100: 350.08
# Average over all episodes so far: 317.27
# epsilon: 0.02
# **** Episode  510 ****
# Recent average reward: 159.3
# Reward over last 100: 320.18
# Average over all episodes so far: 314.17254901960786
# epsilon: 0.02
# **** Episode  520 ****
# Recent average reward: 231.5
# Reward over last 100: 296.86
# Average over all episodes so far: 312.5826923076923
# epsilon: 0.02
# **** Episode  530 ****
# Recent average reward: 146.0
# Reward over last 100: 274.03
# Average over all episodes so far: 309.43962264150946
# epsilon: 0.02
# **** Episode  540 ****
# Recent average reward: 194.1
# Reward over last 100: 265.31
# Average over all episodes so far: 307.3037037037037
# epsilon: 0.02
# **** Episode  550 ****
# Recent average reward: 309.3
# Reward over last 100: 260.18
# Average over all episodes so far: 307.34
# epsilon: 0.02
# **** Episode  560 ****
# Recent average reward: 312.2
# Reward over last 100: 249.31
# Average over all episodes so far: 307.4267857142857
# epsilon: 0.02
# **** Episode  570 ****
# Recent average reward: 392.8
# Reward over last 100: 239.25
# Average over all episodes so far: 308.9245614035088
# epsilon: 0.02
# **** Episode  580 ****
# Recent average reward: 442.9
# Reward over last 100: 256.15
# Average over all episodes so far: 311.2344827586207
# epsilon: 0.02
# **** Episode  590 ****
# Recent average reward: 303.2
# Reward over last 100: 266.83
# Average over all episodes so far: 311.0983050847458
# epsilon: 0.02
# **** Episode  600 ****
# Recent average reward: 147.9
# Reward over last 100: 263.92
# Average over all episodes so far: 308.37833333333333
# epsilon: 0.02
# **** Episode  610 ****
# Recent average reward: 218.9
# Reward over last 100: 269.88
# Average over all episodes so far: 306.91147540983604
# epsilon: 0.02
# **** Episode  620 ****
# Recent average reward: 243.4
# Reward over last 100: 271.07
# Average over all episodes so far: 305.88709677419354
# epsilon: 0.02
# **** Episode  630 ****
# Recent average reward: 494.0
# Reward over last 100: 305.87
# Average over all episodes so far: 308.87301587301585
# epsilon: 0.02
# **** Episode  640 ****
# Recent average reward: 399.2
# Reward over last 100: 326.38
# Average over all episodes so far: 310.284375
# epsilon: 0.02
# **** Episode  650 ****
# Recent average reward: 65.6
# Reward over last 100: 302.01
# Average over all episodes so far: 306.52
# epsilon: 0.02
# **** Episode  660 ****
# Recent average reward: 228.5
# Reward over last 100: 293.64
# Average over all episodes so far: 305.33787878787876
# epsilon: 0.02
# **** Episode  670 ****
# Recent average reward: 124.8
# Reward over last 100: 266.84
# Average over all episodes so far: 302.64328358208957
# epsilon: 0.02
# **** Episode  680 ****
# Recent average reward: 167.2
# Reward over last 100: 239.27
# Average over all episodes so far: 300.65147058823527
# epsilon: 0.02
# **** Episode  690 ****
# Recent average reward: 307.5
# Reward over last 100: 239.7
# Average over all episodes so far: 300.7507246376812
# epsilon: 0.02
# **** Episode  700 ****
# Recent average reward: 251.6
# Reward over last 100: 250.07
# Average over all episodes so far: 300.04857142857145
# epsilon: 0.02
# **** Episode  710 ****
# Recent average reward: 192.0
# Reward over last 100: 247.38
# Average over all episodes so far: 298.52676056338026
# epsilon: 0.02
# **** Episode  720 ****
# Recent average reward: 41.4
# Reward over last 100: 227.18
# Average over all episodes so far: 294.9555555555556
# epsilon: 0.02
# **** Episode  730 ****
# Recent average reward: 305.6
# Reward over last 100: 208.34
# Average over all episodes so far: 295.1013698630137
# epsilon: 0.02
# **** Episode  740 ****
# Recent average reward: 218.8
# Reward over last 100: 190.3
# Average over all episodes so far: 294.07027027027027
# epsilon: 0.02
# **** Episode  750 ****
# Recent average reward: 126.9
# Reward over last 100: 196.43
# Average over all episodes so far: 291.84133333333335
# epsilon: 0.02
# **** Episode  760 ****
# Recent average reward: 127.2
# Reward over last 100: 186.3
# Average over all episodes so far: 289.675
# epsilon: 0.02
# **** Episode  770 ****
# Recent average reward: 152.8
# Reward over last 100: 189.1
# Average over all episodes so far: 287.8974025974026
# epsilon: 0.02
# **** Episode  780 ****
# Recent average reward: 119.2
# Reward over last 100: 184.3
# Average over all episodes so far: 285.7346153846154
# epsilon: 0.02
# **** Episode  790 ****
# Recent average reward: 35.5
# Reward over last 100: 157.1
# Average over all episodes so far: 282.56708860759494
# epsilon: 0.02
# **** Episode  800 ****
# Recent average reward: 28.1
# Reward over last 100: 134.75
# Average over all episodes so far: 279.38625
# epsilon: 0.02
# **** Episode  810 ****
# Recent average reward: 31.7
# Reward over last 100: 118.72
# Average over all episodes so far: 276.3283950617284
# epsilon: 0.02
# **** Episode  820 ****
# Recent average reward: 69.6
# Reward over last 100: 121.54
# Average over all episodes so far: 273.80731707317074
# epsilon: 0.02
# **** Episode  830 ****
# Recent average reward: 131.4
# Reward over last 100: 104.12
# Average over all episodes so far: 272.09156626506024
# epsilon: 0.02
# **** Episode  840 ****
# Recent average reward: 183.3
# Reward over last 100: 100.57
# Average over all episodes so far: 271.0345238095238
# epsilon: 0.02
# **** Episode  850 ****
# Recent average reward: 227.6
# Reward over last 100: 110.64
# Average over all episodes so far: 270.5235294117647
# epsilon: 0.02
# **** Episode  860 ****
# Recent average reward: 202.6
# Reward over last 100: 118.18
# Average over all episodes so far: 269.73372093023255
# epsilon: 0.02
# **** Episode  870 ****
# Recent average reward: 97.9
# Reward over last 100: 112.69
# Average over all episodes so far: 267.7586206896552
# epsilon: 0.02
# **** Episode  880 ****
# Recent average reward: 126.7
# Reward over last 100: 113.44
# Average over all episodes so far: 266.1556818181818
# epsilon: 0.02
# **** Episode  890 ****
# Recent average reward: 148.4
# Reward over last 100: 124.73
# Average over all episodes so far: 264.8325842696629
# epsilon: 0.02
# **** Episode  900 ****
# Recent average reward: 159.2
# Reward over last 100: 137.84
# Average over all episodes so far: 263.6588888888889
# epsilon: 0.02
# **** Episode  910 ****
# Recent average reward: 82.5
# Reward over last 100: 142.92
# Average over all episodes so far: 261.66813186813187
# epsilon: 0.02
# **** Episode  920 ****
# Recent average reward: 46.6
# Reward over last 100: 140.62
# Average over all episodes so far: 259.3304347826087
# epsilon: 0.02
# **** Episode  930 ****
# Recent average reward: 200.9
# Reward over last 100: 147.57
# Average over all episodes so far: 258.7021505376344
# epsilon: 0.02
# **** Episode  940 ****
# Recent average reward: 219.5
# Reward over last 100: 151.19
# Average over all episodes so far: 258.2851063829787
# epsilon: 0.02
# **** Episode  950 ****
# Recent average reward: 129.2
# Reward over last 100: 141.35
# Average over all episodes so far: 256.9263157894737
# epsilon: 0.02
# **** Episode  960 ****
# Recent average reward: 129.0
# Reward over last 100: 133.99
# Average over all episodes so far: 255.59375
# epsilon: 0.02
# **** Episode  970 ****
# Recent average reward: 191.7
# Reward over last 100: 143.37
# Average over all episodes so far: 254.93505154639175
# epsilon: 0.02
# **** Episode  980 ****
# Recent average reward: 116.0
# Reward over last 100: 142.3
# Average over all episodes so far: 253.51734693877552
# epsilon: 0.02
# **** Episode  990 ****
# Recent average reward: 11.7
# Reward over last 100: 128.63
# Average over all episodes so far: 251.07474747474748
# epsilon: 0.02
# Solved after 101 episodes
# CPU times: user 23min 52s, sys: 31.7 s, total: 24min 24s
# Wall time: 24min 51s

# %%
plt.plot(steps_total)
plt.show()

# %%
print("Average number of steps: {}". format(np.average(steps_total)))
# Out:
# Average number of steps: 250.525

# %%
print("Average number of steps=reward: {}". format(np.average(steps_total)))
print("Average number of steps=reward in last 100 episodes: {}". format(np.average(steps_total[-100:])))
# Out:
# Average number of steps=reward: 250.525
# Average number of steps=reward in last 100 episodes: 132.32

# %% [markdown]
# plt.figure(1,figsize=[12,5])
# plt.title("Rewards")
# plt.bar(torch.arange(len(rewards_total)), rewards_total,alpha=0.6, color='green')
# #plt.plot(rewards_total)
# plt.show()

# %%
plt.figure(2,figsize=[12,5])
plt.title("Steps to finish episode")
plt.plot(steps_total)
plt.show()
