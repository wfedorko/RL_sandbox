# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython import display

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
import numpy as np
import math
import random

# %%
import time

# %%
def show_state(env, episode,step, info=""):
    plt.figure(99999,figsize=[8,6])
    plt.clf()
    plt.imshow(env.render(mode='rgb_array'))
    plt.title("episode: {} step: {} ".format(episode,step))
    #plt.title("%s | Step: %d %s" % (env._spec.id,step, info))
    plt.axis('off')

    display.clear_output(wait=True)
    display.display(plt.gcf())

# %%
import gym

# %%
use_cuda = torch.cuda.is_available()
device=torch.device("cuda:4" if use_cuda else "cpu")

# %%
###### PARAMS ######
learning_rate = 0.01
num_episodes = 1000
gamma=0.99
#gamma=0.85
egreedy = 0.9
egreedy_final = 0.0002
egreedy_decay = 5000

report_interval=10

score_to_solve = 195

hidden_layer_size=64

# %%
env = gym.make('CartPole-v1')

# %%
#env = gym.wrappers.Monitor(env, '../mp4/sandbox10',video_callable=lambda episode_id: True,force=True)
#env = gym.wrappers.Monitor(env, '../mp4/cartpole-5',video_callable=lambda episode_id: episode_id%10==0)

# %%
number_of_inputs=env.observation_space.shape[0]
number_of_outputs=env.action_space.n

# %%
def calculate_epsilon(steps_done):
    epsilon = egreedy_final + (egreedy - egreedy_final) * \
              math.exp(-1. * steps_done / egreedy_decay )
    return epsilon

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.linear1 = nn.Linear(number_of_inputs,hidden_layer_size)
        self.linear2 = nn.Linear(hidden_layer_size,number_of_outputs)
        
        self.activation=nn.Tanh()
        
    def forward(self, x):
        output1 = self.linear1(x)
        output1 = self.activation(output1)
        output2 = self.linear2(output1)
        
        return output2

# %%
class QNet_Agent():
    def __init__(self):
        self.nn = NeuralNetwork().to(device)
        self.loss_function = nn.MSELoss()
        self.optimizer = optim.Adam(params=self.nn.parameters(), lr=learning_rate)
        
    def select_action(self,state,epsilon):
        
        random_for_egreedy=torch.rand(1).item()
        
        if random_for_egreedy>epsilon:
            self.nn.eval()
            with torch.no_grad():
                state=torch.Tensor(state).to(device)
                predicted_value_from_nn=self.nn(state)
                action=torch.argmax(predicted_value_from_nn).item()
        else:
            action=env.action_space.sample()
                
                
        return action
    
    def optimize(self, state, action, new_state, reward, done):
        
        state=torch.Tensor(state).to(device)
        new_state=torch.Tensor(new_state).to(device)
        reward=torch.Tensor([reward]).to(device)
        
        
        if done:
            target_value=reward
        else:
            self.nn.eval()
            new_state_values=self.nn(new_state).detach()
            max_new_state_values=torch.max(new_state_values)
            target_value=reward + gamma*max_new_state_values
        
        self.nn.train()
        #the view call needed to make it a tensor
        predicted_value=self.nn(state)[action].view(-1)
        
        loss=self.loss_function(predicted_value,target_value)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

# %%
qnet_agent=QNet_Agent()

# %%
seed_value=23
env.seed(seed_value)
torch.manual_seed(seed_value)
random.seed(seed_value)

# %%
# %%time

num_episodes=1000

steps_total=np.full([num_episodes],-999,dtype=np.int32)

frames_total=0

solved_after = 0
solved = False

start_time = time.time()

for i_episode in range(num_episodes):
    
    state = env.reset()
    #for step in range(100):
    step=0
    while True:
        
        step+=1
        frames_total += 1
        
        epsilon=calculate_epsilon(frames_total)
        
        #action=env.action_space.sample()
        action=qnet_agent.select_action(state,epsilon)
        
        new_state, reward, done, info = env.step(action)
        
        qnet_agent.optimize(state,
                            action,
                            new_state,
                            reward,
                            done)
        
        state=new_state
        
        if done:
            steps_total[i_episode]=step
            
            if i_episode>100:
                mean_reward_100 = np.sum(steps_total[i_episode-100:i_episode])/100
            
                if (mean_reward_100 > score_to_solve and solved == False):
                    print("SOLVED! After %i episodes " % i_episode)
                    solved_after = i_episode
                    solved = True
            
            if (i_episode % report_interval == 0 and i_episode>1):
                print("**** Episode  {} **** ".format(i_episode))
                recent_avg_reward=np.average(steps_total[i_episode-report_interval:i_episode])
                print("Recent average reward: {}".format(recent_avg_reward))
                if i_episode>100:
                    print("Reward over last 100: {}".format(mean_reward_100))
                full_avg_so_far=np.average(steps_total[:i_episode])
                print("Average over all episodes so far: {}".format(full_avg_so_far))
                print("epsilon: {}".format(epsilon))
            
                #print("Episode {} finished after: {}".format(i_episode,step))
            break
            
if solved:
    print("Solved after %i episodes" % solved_after)
# Out:
# **** Episode  10 ****
# Recent average reward: 27.1
# Average over all episodes so far: 27.1
# epsilon: 0.8508259722660717
# **** Episode  20 ****
# Recent average reward: 17.3
# Average over all episodes so far: 22.2
# epsilon: 0.8202559063477121
# **** Episode  30 ****
# Recent average reward: 18.6
# Average over all episodes so far: 21.0
# epsilon: 0.7914171977880939
# **** Episode  40 ****
# Recent average reward: 27.9
# Average over all episodes so far: 22.725
# epsilon: 0.7437027885070812
# **** Episode  50 ****
# Recent average reward: 24.5
# Average over all episodes so far: 23.08
# epsilon: 0.7105604493885667
# **** Episode  60 ****
# Recent average reward: 33.3
# Average over all episodes so far: 24.783333333333335
# epsilon: 0.6657225465715239
# **** Episode  70 ****
# Recent average reward: 44.9
# Average over all episodes so far: 27.65714285714286
# epsilon: 0.6081985617417713
# **** Episode  80 ****
# Recent average reward: 52.0
# Average over all episodes so far: 30.7
# epsilon: 0.5482532843339244
# **** Episode  90 ****
# Recent average reward: 86.3
# Average over all episodes so far: 36.87777777777778
# epsilon: 0.4529646782315471
# **** Episode  100 ****
# Recent average reward: 114.4
# Average over all episodes so far: 44.63
# epsilon: 0.36742418372935565
# **** Episode  110 ****
# Recent average reward: 144.5
# Reward over last 100: 56.37
# Average over all episodes so far: 53.70909090909091
# epsilon: 0.2659012391323839
# **** Episode  120 ****
# Recent average reward: 167.6
# Reward over last 100: 71.4
# Average over all episodes so far: 63.2
# epsilon: 0.19290731136684636
# **** Episode  130 ****
# Recent average reward: 177.2
# Reward over last 100: 87.26
# Average over all episodes so far: 71.96923076923076
# epsilon: 0.12553278959906874
# **** Episode  140 ****
# Recent average reward: 278.2
# Reward over last 100: 112.29
# Average over all episodes so far: 86.7
# epsilon: 0.07583903730686221
# **** Episode  150 ****
# Recent average reward: 282.4
# Reward over last 100: 138.08
# Average over all episodes so far: 99.74666666666667
# epsilon: 0.04131497935962611
# **** Episode  160 ****
# Recent average reward: 482.5
# Reward over last 100: 183.0
# Average over all episodes so far: 123.66875
# epsilon: 0.01736671812220471
# **** Episode  170 ****
# Recent average reward: 105.1
# Reward over last 100: 189.02
# Average over all episodes so far: 122.5764705882353
# epsilon: 0.013801397113601977
# SOLVED! After 176 episodes
# **** Episode  180 ****
# Recent average reward: 197.6
# Reward over last 100: 203.58
# Average over all episodes so far: 126.74444444444444
# epsilon: 0.00907086681951128
# **** Episode  190 ****
# Recent average reward: 357.4
# Reward over last 100: 230.69
# Average over all episodes so far: 138.8842105263158
# epsilon: 0.004525693681923954
# **** Episode  200 ****
# Recent average reward: 357.0
# Reward over last 100: 254.95
# Average over all episodes so far: 149.79
# epsilon: 0.0022351560854235717
# **** Episode  210 ****
# Recent average reward: 453.4
# Reward over last 100: 285.84
# Average over all episodes so far: 164.24761904761905
# epsilon: 0.0010218252616490656
# **** Episode  220 ****
# Recent average reward: 231.7
# Reward over last 100: 292.25
# Average over all episodes so far: 167.31363636363636
# epsilon: 0.000717043905959603
# **** Episode  230 ****
# Recent average reward: 380.8
# Reward over last 100: 312.61
# Average over all episodes so far: 176.59565217391304
# epsilon: 0.0004487697563479463
# **** Episode  240 ****
# Recent average reward: 384.9
# Reward over last 100: 323.28
# Average over all episodes so far: 185.275
# epsilon: 0.0003118018150506393
# **** Episode  250 ****
# Recent average reward: 274.4
# Reward over last 100: 322.48
# Average over all episodes so far: 188.84
# epsilon: 0.0002645814872983416
# **** Episode  260 ****
# Recent average reward: 500.0
# Reward over last 100: 324.23
# Average over all episodes so far: 200.80769230769232
# epsilon: 0.00022375820145733452
# **** Episode  270 ****
# Recent average reward: 435.7
# Reward over last 100: 357.29
# Average over all episodes so far: 209.5074074074074
# epsilon: 0.00020993961010837088
# **** Episode  280 ****
# Recent average reward: 500.0
# Reward over last 100: 387.53
# Average over all episodes so far: 219.88214285714287
# epsilon: 0.00020369480506059697
# **** Episode  290 ****
# Recent average reward: 471.7
# Reward over last 100: 398.96
# Average over all episodes so far: 228.5655172413793
# epsilon: 0.00020142351305021424
# **** Episode  300 ****
# Recent average reward: 496.8
# Reward over last 100: 412.94
# Average over all episodes so far: 237.50666666666666
# epsilon: 0.00020056888771338022
# **** Episode  310 ****
# Recent average reward: 461.8
# Reward over last 100: 413.78
# Average over all episodes so far: 244.74193548387098
# epsilon: 0.0002002092820940876
# **** Episode  320 ****
# Recent average reward: 419.3
# Reward over last 100: 432.54
# Average over all episodes so far: 250.196875
# epsilon: 0.00020009047585996188
# **** Episode  330 ****
# Recent average reward: 309.0
# Reward over last 100: 425.36
# Average over all episodes so far: 251.97878787878787
# epsilon: 0.00020005183590595914
# **** Episode  340 ****
# Recent average reward: 244.1
# Reward over last 100: 411.28
# Average over all episodes so far: 251.74705882352941
# epsilon: 0.00020003101537577835
# **** Episode  350 ****
# Recent average reward: 178.6
# Reward over last 100: 401.7
# Average over all episodes so far: 249.65714285714284
# epsilon: 0.00020002238705912697
# **** Episode  360 ****
# Recent average reward: 262.9
# Reward over last 100: 377.99
# Average over all episodes so far: 250.025
# epsilon: 0.00020001254450943177
# **** Episode  370 ****
# Recent average reward: 454.0
# Reward over last 100: 379.82
# Average over all episodes so far: 255.53783783783783
# epsilon: 0.00020000499223185036
# **** Episode  380 ****
# Recent average reward: 500.0
# Reward over last 100: 379.82
# Average over all episodes so far: 261.97105263157897
# epsilon: 0.00020000183653946332
# **** Episode  390 ****
# Recent average reward: 336.2
# Reward over last 100: 366.27
# Average over all episodes so far: 263.874358974359
# epsilon: 0.00020000093752024602
# **** Episode  400 ****
# Recent average reward: 500.0
# Reward over last 100: 366.59
# Average over all episodes so far: 269.7775
# epsilon: 0.0002000003448944242
# **** Episode  410 ****
# Recent average reward: 456.9
# Reward over last 100: 366.1
# Average over all episodes so far: 274.3414634146341
# epsilon: 0.00020000014507318706
# **** Episode  420 ****
# Recent average reward: 431.2
# Reward over last 100: 367.29
# Average over all episodes so far: 278.0761904761905
# epsilon: 0.00020000005838379412
# **** Episode  430 ****
# Recent average reward: 397.6
# Reward over last 100: 376.15
# Average over all episodes so far: 280.8558139534884
# epsilon: 0.0002000000263597534
# **** Episode  440 ****
# Recent average reward: 423.8
# Reward over last 100: 394.12
# Average over all episodes so far: 284.1045454545455
# epsilon: 0.0002000000112936244
# **** Episode  450 ****
# Recent average reward: 486.0
# Reward over last 100: 424.86
# Average over all episodes so far: 288.5911111111111
# epsilon: 0.00020000000427266757
# **** Episode  460 ****
# Recent average reward: 500.0
# Reward over last 100: 448.57
# Average over all episodes so far: 293.18695652173915
# epsilon: 0.00020000000157182655
# **** Episode  470 ****
# Recent average reward: 500.0
# Reward over last 100: 453.17
# Average over all episodes so far: 297.5872340425532
# epsilon: 0.00020000000057824268
# **** Episode  480 ****
# Recent average reward: 500.0
# Reward over last 100: 453.17
# Average over all episodes so far: 301.8041666666667
# epsilon: 0.0002000000002127236
# **** Episode  490 ****
# Recent average reward: 395.0
# Reward over last 100: 459.05
# Average over all episodes so far: 303.7061224489796
# epsilon: 0.0002000000000965435
# **** Episode  500 ****
# Recent average reward: 449.7
# Reward over last 100: 454.02
# Average over all episodes so far: 306.626
# epsilon: 0.00020000000003927523
# **** Episode  510 ****
# Recent average reward: 414.9
# Reward over last 100: 449.82
# Average over all episodes so far: 308.74901960784314
# epsilon: 0.00020000000001712937
# **** Episode  520 ****
# Recent average reward: 270.3
# Reward over last 100: 433.73
# Average over all episodes so far: 308.00961538461536
# epsilon: 0.00020000000001044784
# **** Episode  530 ****
# Recent average reward: 455.2
# Reward over last 100: 439.49
# Average over all episodes so far: 310.7867924528302
# epsilon: 0.00020000000000401402
# **** Episode  540 ****
# Recent average reward: 407.6
# Reward over last 100: 437.87
# Average over all episodes so far: 312.5796296296296
# epsilon: 0.00020000000000183307
# **** Episode  550 ****
# Recent average reward: 397.7
# Reward over last 100: 429.04
# Average over all episodes so far: 314.1272727272727
# epsilon: 0.00020000000000080189
# **** Episode  560 ****
# Recent average reward: 482.9
# Reward over last 100: 427.33
# Average over all episodes so far: 317.1410714285714
# epsilon: 0.00020000000000030527
# **** Episode  570 ****
# Recent average reward: 500.0
# Reward over last 100: 427.33
# Average over all episodes so far: 320.3491228070175
# epsilon: 0.0002000000000001123
# **** Episode  580 ****
# Recent average reward: 500.0
# Reward over last 100: 427.33
# Average over all episodes so far: 323.4465517241379
# epsilon: 0.00020000000000004132
# **** Episode  590 ****
# Recent average reward: 429.4
# Reward over last 100: 430.77
# Average over all episodes so far: 325.24237288135595
# epsilon: 0.00020000000000001752
# **** Episode  600 ****
# Recent average reward: 444.8
# Reward over last 100: 430.28
# Average over all episodes so far: 327.235
# epsilon: 0.0002000000000000072
# **** Episode  610 ****
# Recent average reward: 500.0
# Reward over last 100: 438.79
# Average over all episodes so far: 330.0672131147541
# epsilon: 0.00020000000000000267
# **** Episode  620 ****
# Recent average reward: 500.0
# Reward over last 100: 461.76
# Average over all episodes so far: 332.80806451612904
# epsilon: 0.00020000000000000099
# **** Episode  710 ****
# Recent average reward: 436.5
# Reward over last 100: 462.5
# Average over all episodes so far: 348.71971830985916
# epsilon: 0.0002
# **** Episode  720 ****
# Recent average reward: 354.7
# Reward over last 100: 447.97
# Average over all episodes so far: 348.8027777777778
# epsilon: 0.0002
# **** Episode  730 ****
# Recent average reward: 489.0
# Reward over last 100: 446.87
# Average over all episodes so far: 350.72328767123287
# epsilon: 0.0002
# **** Episode  740 ****
# Recent average reward: 500.0
# Reward over last 100: 461.55
# Average over all episodes so far: 352.74054054054056
# epsilon: 0.0002
# **** Episode  750 ****
# Recent average reward: 368.6
# Reward over last 100: 448.41
# Average over all episodes so far: 352.952
# epsilon: 0.0002
# **** Episode  760 ****
# Recent average reward: 500.0
# Reward over last 100: 448.65
# Average over all episodes so far: 354.88684210526316
# epsilon: 0.0002
# **** Episode  770 ****
# Recent average reward: 500.0
# Reward over last 100: 450.84
# Average over all episodes so far: 356.77142857142854
# epsilon: 0.0002
# **** Episode  780 ****
# Recent average reward: 500.0
# Reward over last 100: 451.88
# Average over all episodes so far: 358.60769230769233
# epsilon: 0.0002
# **** Episode  790 ****
# Recent average reward: 500.0
# Reward over last 100: 454.81
# Average over all episodes so far: 360.3974683544304
# epsilon: 0.0002
# **** Episode  800 ****
# Recent average reward: 500.0
# Reward over last 100: 464.88
# Average over all episodes so far: 362.1425
# epsilon: 0.0002
# **** Episode  810 ****
# Recent average reward: 500.0
# Reward over last 100: 471.23
# Average over all episodes so far: 363.84444444444443
# epsilon: 0.0002
# **** Episode  820 ****
# Recent average reward: 500.0
# Reward over last 100: 485.76
# Average over all episodes so far: 365.5048780487805
# epsilon: 0.0002
# **** Episode  830 ****
# Recent average reward: 500.0
# Reward over last 100: 486.86
# Average over all episodes so far: 367.12530120481927
# epsilon: 0.0002
# **** Episode  840 ****
# Recent average reward: 259.5
# Reward over last 100: 462.81
# Average over all episodes so far: 365.8440476190476
# epsilon: 0.0002
# **** Episode  850 ****
# Recent average reward: 488.2
# Reward over last 100: 474.77
# Average over all episodes so far: 367.28352941176473
# epsilon: 0.0002
# **** Episode  860 ****
# Recent average reward: 409.9
# Reward over last 100: 465.76
# Average over all episodes so far: 367.77906976744185
# epsilon: 0.0002
# **** Episode  870 ****
# Recent average reward: 410.5
# Reward over last 100: 456.81
# Average over all episodes so far: 368.2701149425287
# epsilon: 0.0002
# **** Episode  880 ****
# Recent average reward: 466.6
# Reward over last 100: 453.47
# Average over all episodes so far: 369.3875
# epsilon: 0.0002
# **** Episode  890 ****
# Recent average reward: 327.0
# Reward over last 100: 436.17
# Average over all episodes so far: 368.91123595505616
# epsilon: 0.0002
# **** Episode  900 ****
# Recent average reward: 474.6
# Reward over last 100: 433.63
# Average over all episodes so far: 370.0855555555556
# epsilon: 0.0002
# **** Episode  910 ****
# Recent average reward: 500.0
# Reward over last 100: 433.63
# Average over all episodes so far: 371.5131868131868
# epsilon: 0.0002
# **** Episode  920 ****
# Recent average reward: 356.9
# Reward over last 100: 419.32
# Average over all episodes so far: 371.35434782608695
# epsilon: 0.0002
# **** Episode  930 ****
# Recent average reward: 379.9
# Reward over last 100: 407.31
# Average over all episodes so far: 371.4462365591398
# epsilon: 0.0002
# **** Episode  940 ****
# Recent average reward: 277.3
# Reward over last 100: 409.09
# Average over all episodes so far: 370.4446808510638
# epsilon: 0.0002
# **** Episode  950 ****
# Recent average reward: 475.5
# Reward over last 100: 407.82
# Average over all episodes so far: 371.55052631578945
# epsilon: 0.0002
# **** Episode  960 ****
# Recent average reward: 297.4
# Reward over last 100: 396.57
# Average over all episodes so far: 370.778125
# epsilon: 0.0002
# **** Episode  970 ****
# Recent average reward: 500.0
# Reward over last 100: 405.52
# Average over all episodes so far: 372.11030927835054
# epsilon: 0.0002
# **** Episode  980 ****
# Recent average reward: 438.4
# Reward over last 100: 402.7
# Average over all episodes so far: 372.7867346938776
# epsilon: 0.0002
# **** Episode  990 ****
# Recent average reward: 304.6
# Reward over last 100: 400.46
# Average over all episodes so far: 372.0979797979798
# epsilon: 0.0002
# Solved after 176 episodes
# CPU times: user 17min 43s, sys: 19.7 s, total: 18min 2s
# Wall time: 18min 17s

# %%
plt.plot(steps_total)
plt.show()

# %%
print("Average number of steps: {}". format(np.average(steps_total)))
# Out:
# Average number of steps: 370.022

# %%
print("Average number of steps=reward: {}". format(np.average(steps_total)))
print("Average number of steps=reward in last 100 episodes: {}". format(np.average(steps_total[-100:])))
# Out:
# Average number of steps=reward: 370.022
# Average number of steps=reward in last 100 episodes: 369.45

# %% [markdown]
# plt.figure(1,figsize=[12,5])
# plt.title("Rewards")
# plt.bar(torch.arange(len(rewards_total)), rewards_total,alpha=0.6, color='green')
# #plt.plot(rewards_total)
# plt.show()

# %%
plt.figure(2,figsize=[12,5])
plt.title("Steps to finish episode")
plt.plot(steps_total)
plt.show()
