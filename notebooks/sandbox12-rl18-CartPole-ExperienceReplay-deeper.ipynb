# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython import display

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
import numpy as np
import math
import random

# %%
import time

# %%
def show_state(env, episode,step, info=""):
    plt.figure(99999,figsize=[8,6])
    plt.clf()
    plt.imshow(env.render(mode='rgb_array'))
    plt.title("episode: {} step: {} ".format(episode,step))
    #plt.title("%s | Step: %d %s" % (env._spec.id,step, info))
    plt.axis('off')

    display.clear_output(wait=True)
    display.display(plt.gcf())

# %%
import gym

# %%
use_cuda = torch.cuda.is_available()
device=torch.device("cuda:4" if use_cuda else "cpu")

# %%
###### PARAMS ######
learning_rate = 0.01
num_episodes = 1000
gamma=0.99
#gamma=0.85
egreedy = 0.9
egreedy_final = 0.02
egreedy_decay = 500

report_interval=10

score_to_solve = 195

hidden_layer_size=64

replay_memory_size=50000

batch_size=32

# %%
env = gym.make('CartPole-v1')

# %%
#env = gym.wrappers.Monitor(env, '../mp4/sandbox10',video_callable=lambda episode_id: True,force=True)
#env = gym.wrappers.Monitor(env, '../mp4/cartpole-5',video_callable=lambda episode_id: episode_id%10==0)

# %%
number_of_inputs=env.observation_space.shape[0]
number_of_outputs=env.action_space.n

# %%
def calculate_epsilon(steps_done):
    epsilon = egreedy_final + (egreedy - egreedy_final) * \
              math.exp(-1. * steps_done / egreedy_decay )
    return epsilon

# %%
class ExperienceReplay():
    def __init__(self, capacity):
        self.capacity=capacity
        self.memory=[]
        self.position=0
        
    
    def push(self, state,
             action, new_state,
             reward, done):
        
            transition=(state,action,new_state,reward,done)
            
            if self.position>=len(self.memory):
                self.memory.append(transition)
            else:
                self.memory[self.position]=transition
                
            self.position=(self.position+1)%self.capacity
        
    
    def sample(self,batch_size):
        return zip(*random.sample(self.memory, batch_size))
    
    def __len__(self):
        return len(self.memory)

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.linear_in = nn.Linear(number_of_inputs,hidden_layer_size)
        self.linearh1 = nn.Linear(hidden_layer_size,hidden_layer_size)
        self.linearh2 = nn.Linear(hidden_layer_size,hidden_layer_size)
        self.linearh3 = nn.Linear(hidden_layer_size,hidden_layer_size)
        self.linearh4 = nn.Linear(hidden_layer_size,hidden_layer_size)
        self.linear_out = nn.Linear(hidden_layer_size,number_of_outputs)
        
        self.activation=nn.Tanh()
        
    def forward(self, x):
        x = self.linear_in(x)
        x = self.activation(x)
        
        x = self.linearh1(x)
        x = self.activation(x)
        
        #x = self.linearh2(x)
        #x = self.activation(x)
        
        #x = self.linearh3(x)
        #x = self.activation(x)
        
        #x = self.linearh4(x)
        #x = self.activation(x)
        
        output = self.linear_out(x)
        
        return output

# %%
class QNet_Agent():
    def __init__(self):
        self.nn = NeuralNetwork().to(device)
        self.loss_function = nn.MSELoss()
        self.optimizer = optim.Adam(params=self.nn.parameters(), lr=learning_rate)
        
    def select_action(self,state,epsilon):
        
        random_for_egreedy=torch.rand(1).item()
        
        if random_for_egreedy>epsilon:
            self.nn.eval()
            with torch.no_grad():
                state=torch.Tensor(state).to(device)
                predicted_value_from_nn=self.nn(state)
                action=torch.argmax(predicted_value_from_nn).item()
        else:
            action=env.action_space.sample()
                
                
        return action
    
    def optimize(self):
        
        if len(memory)<batch_size:
            return
        
        state, action, new_state, reward, done = memory.sample(batch_size)
        
        state=torch.Tensor(state).to(device)
        new_state=torch.Tensor(new_state).to(device)
        reward=torch.Tensor(reward).to(device)
        
        #the view call below is to transform into column vector
        #so that it can be used in the gather call
        #i.e. we will use it to pick out from the computed value
        #tensor only values indexed by selected action
        action=(torch.Tensor(action).view(-1,1).long()).to(device)
        #print('action: ')
        #print(action)
        #print('contiguous?', action.is_contiguous())
        done=torch.Tensor(done).to(device)
        
        #print('shape of: state, new state, reward, action, done:')
        #print(state.shape)
        #print(new_state.shape)
        #print(reward.shape)
        #print(action.shape)
        #print(done.shape)
        
        
        self.nn.eval()
            
        new_state_values=self.nn(new_state).detach()
        #print('shape of: new_state_values')
        #print(new_state_values.shape)
        
        max_new_state_values=torch.max(new_state_values,dim=1)[0]
        #print('shape of: max_new_state_values')
        #print(max_new_state_values.shape)
        target_value=(reward + (1-done)*gamma*max_new_state_values).view(-1,1)
        
        #print('shape of: target_value')
        #print(target_value.shape)
        self.nn.train()
        
        #this will select only the values of the desired actions
        predicted_value=torch.gather(self.nn(state),1,action)
        #print('shape of: predicted_value')
        #print(predicted_value.shape)
        
        
        loss=self.loss_function(predicted_value,target_value)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

# %%
memory=ExperienceReplay(replay_memory_size)

# %%
qnet_agent=QNet_Agent()

# %%
seed_value=23
env.seed(seed_value)
torch.manual_seed(seed_value)
random.seed(seed_value)

# %%
# %%time

num_episodes=1000

steps_total=np.full([num_episodes],-999,dtype=np.int32)

frames_total=0

solved_after = 0
solved = False

start_time = time.time()

for i_episode in range(num_episodes):
    
    state = env.reset()
    #for step in range(100):
    step=0
    while True:
        
        step+=1
        frames_total += 1
        
        epsilon=calculate_epsilon(frames_total)
        
        #action=env.action_space.sample()
        action=qnet_agent.select_action(state,epsilon)
        
        new_state, reward, done, info = env.step(action)
        memory.push(state, action, new_state,
                     reward, done)
        
        qnet_agent.optimize()
        
        state=new_state
        
        if done:
            steps_total[i_episode]=step
            
            if i_episode>100:
                mean_reward_100 = np.sum(steps_total[i_episode-100:i_episode])/100
            
                if (mean_reward_100 > score_to_solve and solved == False):
                    print("SOLVED! After %i episodes " % i_episode)
                    solved_after = i_episode
                    solved = True
            
            if (i_episode % report_interval == 0 and i_episode>1):
                print("**** Episode  {} **** ".format(i_episode))
                recent_avg_reward=np.average(steps_total[i_episode-report_interval:i_episode])
                print("Recent average reward: {}".format(recent_avg_reward))
                if i_episode>100:
                    print("Reward over last 100: {}".format(mean_reward_100))
                full_avg_so_far=np.average(steps_total[:i_episode])
                print("Average over all episodes so far: {}".format(full_avg_so_far))
                print("epsilon: {}".format(epsilon))
            
                #print("Episode {} finished after: {}".format(i_episode,step))
            break
            
if solved:
    print("Solved after %i episodes" % solved_after)
# Out:
# **** Episode  10 ****
# Recent average reward: 23.5
# Average over all episodes so far: 23.5
# epsilon: 0.5463265867752299
# **** Episode  20 ****
# Recent average reward: 84.4
# Average over all episodes so far: 53.95
# epsilon: 0.10031222953869205
# **** Episode  30 ****
# Recent average reward: 142.5
# Average over all episodes so far: 83.46666666666667
# epsilon: 0.023083057833208312
# **** Episode  40 ****
# Recent average reward: 128.4
# Average over all episodes so far: 94.7
# epsilon: 0.020165948448090717
# **** Episode  50 ****
# Recent average reward: 271.1
# Average over all episodes so far: 129.98
# epsilon: 0.02000111146302327
# **** Episode  60 ****
# Recent average reward: 294.0
# Average over all episodes so far: 157.31666666666666
# epsilon: 0.02000000390958983
# **** Episode  70 ****
# Recent average reward: 200.7
# Average over all episodes so far: 163.5142857142857
# epsilon: 0.020000000084031164
# **** Episode  80 ****
# Recent average reward: 173.0
# Average over all episodes so far: 164.7
# epsilon: 0.020000000002907192
# **** Episode  90 ****
# Recent average reward: 190.7
# Average over all episodes so far: 167.5888888888889
# epsilon: 0.020000000000062863
# **** Episode  100 ****
# Recent average reward: 220.8
# Average over all episodes so far: 172.91
# epsilon: 0.020000000000000455
# **** Episode  110 ****
# Recent average reward: 192.9
# Reward over last 100: 189.85
# Average over all episodes so far: 174.72727272727272
# epsilon: 0.020000000000000014
# **** Episode  120 ****
# Recent average reward: 91.9
# Reward over last 100: 190.6
# Average over all episodes so far: 167.825
# epsilon: 0.020000000000000004
# **** Episode  130 ****
# Recent average reward: 52.2
# Reward over last 100: 181.57
# Average over all episodes so far: 158.93076923076924
# epsilon: 0.02
# **** Episode  140 ****
# Recent average reward: 248.5
# Reward over last 100: 193.58
# Average over all episodes so far: 165.32857142857142
# epsilon: 0.02
# **** Episode  150 ****
# Recent average reward: 155.7
# Reward over last 100: 182.04
# Average over all episodes so far: 164.68666666666667
# epsilon: 0.02
# **** Episode  160 ****
# Recent average reward: 104.0
# Reward over last 100: 163.04
# Average over all episodes so far: 160.89375
# epsilon: 0.02
# **** Episode  170 ****
# Recent average reward: 155.1
# Reward over last 100: 158.48
# Average over all episodes so far: 160.5529411764706
# epsilon: 0.02
# **** Episode  180 ****
# Recent average reward: 159.9
# Reward over last 100: 157.17
# Average over all episodes so far: 160.51666666666668
# epsilon: 0.02
# **** Episode  190 ****
# Recent average reward: 179.6
# Reward over last 100: 156.06
# Average over all episodes so far: 161.52105263157895
# epsilon: 0.02
# **** Episode  200 ****
# Recent average reward: 205.0
# Reward over last 100: 154.48
# Average over all episodes so far: 163.695
# epsilon: 0.02
# **** Episode  210 ****
# Recent average reward: 157.1
# Reward over last 100: 150.9
# Average over all episodes so far: 163.38095238095238
# epsilon: 0.02
# **** Episode  220 ****
# Recent average reward: 74.5
# Reward over last 100: 149.16
# Average over all episodes so far: 159.3409090909091
# epsilon: 0.02
# **** Episode  230 ****
# Recent average reward: 169.9
# Reward over last 100: 160.93
# Average over all episodes so far: 159.8
# epsilon: 0.02
# **** Episode  240 ****
# Recent average reward: 124.9
# Reward over last 100: 148.57
# Average over all episodes so far: 158.34583333333333
# epsilon: 0.02
# **** Episode  250 ****
# Recent average reward: 82.6
# Reward over last 100: 141.26
# Average over all episodes so far: 155.316
# epsilon: 0.02
# **** Episode  260 ****
# Recent average reward: 160.8
# Reward over last 100: 146.94
# Average over all episodes so far: 155.52692307692308
# epsilon: 0.02
# **** Episode  270 ****
# Recent average reward: 121.7
# Reward over last 100: 143.6
# Average over all episodes so far: 154.27407407407406
# epsilon: 0.02
# **** Episode  280 ****
# Recent average reward: 172.3
# Reward over last 100: 144.84
# Average over all episodes so far: 154.91785714285714
# epsilon: 0.02
# **** Episode  290 ****
# Recent average reward: 75.8
# Reward over last 100: 134.46
# Average over all episodes so far: 152.18965517241378
# epsilon: 0.02
# **** Episode  300 ****
# Recent average reward: 68.8
# Reward over last 100: 120.84
# Average over all episodes so far: 149.41
# epsilon: 0.02
# **** Episode  310 ****
# Recent average reward: 82.1
# Reward over last 100: 113.34
# Average over all episodes so far: 147.23870967741937
# epsilon: 0.02
# **** Episode  320 ****
# Recent average reward: 72.6
# Reward over last 100: 113.15
# Average over all episodes so far: 144.90625
# epsilon: 0.02
# **** Episode  330 ****
# Recent average reward: 70.5
# Reward over last 100: 103.21
# Average over all episodes so far: 142.65151515151516
# epsilon: 0.02
# **** Episode  340 ****
# Recent average reward: 196.7
# Reward over last 100: 110.39
# Average over all episodes so far: 144.24117647058824
# epsilon: 0.02
# **** Episode  350 ****
# Recent average reward: 83.0
# Reward over last 100: 110.43
# Average over all episodes so far: 142.49142857142857
# epsilon: 0.02
# **** Episode  360 ****
# Recent average reward: 177.6
# Reward over last 100: 112.11
# Average over all episodes so far: 143.46666666666667
# epsilon: 0.02
# **** Episode  370 ****
# Recent average reward: 92.5
# Reward over last 100: 109.19
# Average over all episodes so far: 142.0891891891892
# epsilon: 0.02
# **** Episode  380 ****
# Recent average reward: 111.0
# Reward over last 100: 103.06
# Average over all episodes so far: 141.27105263157895
# epsilon: 0.02
# **** Episode  390 ****
# Recent average reward: 150.7
# Reward over last 100: 110.55
# Average over all episodes so far: 141.51282051282053
# epsilon: 0.02
# **** Episode  400 ****
# Recent average reward: 108.9
# Reward over last 100: 114.56
# Average over all episodes so far: 140.6975
# epsilon: 0.02
# **** Episode  410 ****
# Recent average reward: 125.3
# Reward over last 100: 118.88
# Average over all episodes so far: 140.3219512195122
# epsilon: 0.02
# **** Episode  420 ****
# Recent average reward: 151.0
# Reward over last 100: 126.72
# Average over all episodes so far: 140.57619047619048
# epsilon: 0.02
# **** Episode  430 ****
# Recent average reward: 156.2
# Reward over last 100: 135.29
# Average over all episodes so far: 140.93953488372094
# epsilon: 0.02
# **** Episode  440 ****
# Recent average reward: 212.5
# Reward over last 100: 136.87
# Average over all episodes so far: 142.5659090909091
# epsilon: 0.02
# **** Episode  450 ****
# Recent average reward: 192.5
# Reward over last 100: 147.82
# Average over all episodes so far: 143.67555555555555
# epsilon: 0.02
# **** Episode  460 ****
# Recent average reward: 137.5
# Reward over last 100: 143.81
# Average over all episodes so far: 143.5413043478261
# epsilon: 0.02
# **** Episode  470 ****
# Recent average reward: 186.7
# Reward over last 100: 153.23
# Average over all episodes so far: 144.4595744680851
# epsilon: 0.02
# **** Episode  480 ****
# Recent average reward: 127.7
# Reward over last 100: 154.9
# Average over all episodes so far: 144.11041666666668
# epsilon: 0.02
# **** Episode  490 ****
# Recent average reward: 99.7
# Reward over last 100: 149.8
# Average over all episodes so far: 143.20408163265307
# epsilon: 0.02
# **** Episode  500 ****
# Recent average reward: 106.8
# Reward over last 100: 149.59
# Average over all episodes so far: 142.476
# epsilon: 0.02
# **** Episode  510 ****
# Recent average reward: 130.3
# Reward over last 100: 150.09
# Average over all episodes so far: 142.2372549019608
# epsilon: 0.02
# **** Episode  520 ****
# Recent average reward: 72.3
# Reward over last 100: 142.22
# Average over all episodes so far: 140.8923076923077
# epsilon: 0.02
# **** Episode  530 ****
# Recent average reward: 133.1
# Reward over last 100: 139.91
# Average over all episodes so far: 140.74528301886792
# epsilon: 0.02
# **** Episode  540 ****
# Recent average reward: 66.4
# Reward over last 100: 125.3
# Average over all episodes so far: 139.36851851851853
# epsilon: 0.02
# **** Episode  550 ****
# Recent average reward: 84.0
# Reward over last 100: 114.45
# Average over all episodes so far: 138.3618181818182
# epsilon: 0.02
# **** Episode  560 ****
# Recent average reward: 152.1
# Reward over last 100: 115.91
# Average over all episodes so far: 138.60714285714286
# epsilon: 0.02
# **** Episode  570 ****
# Recent average reward: 51.4
# Reward over last 100: 102.38
# Average over all episodes so far: 137.07719298245615
# epsilon: 0.02
# **** Episode  580 ****
# Recent average reward: 92.7
# Reward over last 100: 98.88
# Average over all episodes so far: 136.31206896551726
# epsilon: 0.02
# **** Episode  590 ****
# Recent average reward: 44.6
# Reward over last 100: 93.37
# Average over all episodes so far: 134.75762711864408
# epsilon: 0.02
# **** Episode  600 ****
# Recent average reward: 111.3
# Reward over last 100: 93.82
# Average over all episodes so far: 134.36666666666667
# epsilon: 0.02
# **** Episode  610 ****
# Recent average reward: 77.0
# Reward over last 100: 88.49
# Average over all episodes so far: 133.4262295081967
# epsilon: 0.02
# **** Episode  620 ****
# Recent average reward: 78.6
# Reward over last 100: 89.12
# Average over all episodes so far: 132.54193548387096
# epsilon: 0.02
# **** Episode  630 ****
# Recent average reward: 126.7
# Reward over last 100: 88.48
# Average over all episodes so far: 132.44920634920635
# epsilon: 0.02
# **** Episode  640 ****
# Recent average reward: 37.0
# Reward over last 100: 85.54
# Average over all episodes so far: 130.9578125
# epsilon: 0.02
# **** Episode  650 ****
# Recent average reward: 49.9
# Reward over last 100: 82.13
# Average over all episodes so far: 129.71076923076924
# epsilon: 0.02
# **** Episode  660 ****
# Recent average reward: 111.6
# Reward over last 100: 78.08
# Average over all episodes so far: 129.43636363636364
# epsilon: 0.02
# **** Episode  670 ****
# Recent average reward: 128.9
# Reward over last 100: 85.83
# Average over all episodes so far: 129.42835820895522
# epsilon: 0.02
# **** Episode  680 ****
# Recent average reward: 88.4
# Reward over last 100: 85.4
# Average over all episodes so far: 128.825
# epsilon: 0.02
# **** Episode  690 ****
# Recent average reward: 100.5
# Reward over last 100: 90.99
# Average over all episodes so far: 128.4144927536232
# epsilon: 0.02
# **** Episode  700 ****
# Recent average reward: 48.6
# Reward over last 100: 84.72
# Average over all episodes so far: 127.27428571428571
# epsilon: 0.02
# **** Episode  710 ****
# Recent average reward: 69.6
# Reward over last 100: 83.98
# Average over all episodes so far: 126.46197183098592
# epsilon: 0.02
# **** Episode  720 ****
# Recent average reward: 57.1
# Reward over last 100: 81.83
# Average over all episodes so far: 125.49861111111112
# epsilon: 0.02
# **** Episode  730 ****
# Recent average reward: 95.6
# Reward over last 100: 78.72
# Average over all episodes so far: 125.08904109589041
# epsilon: 0.02
# **** Episode  740 ****
# Recent average reward: 101.6
# Reward over last 100: 85.18
# Average over all episodes so far: 124.77162162162162
# epsilon: 0.02
# **** Episode  750 ****
# Recent average reward: 76.1
# Reward over last 100: 87.8
# Average over all episodes so far: 124.12266666666666
# epsilon: 0.02
# **** Episode  760 ****
# Recent average reward: 124.4
# Reward over last 100: 89.08
# Average over all episodes so far: 124.12631578947368
# epsilon: 0.02
# **** Episode  770 ****
# Recent average reward: 82.7
# Reward over last 100: 84.46
# Average over all episodes so far: 123.58831168831169
# epsilon: 0.02
# **** Episode  780 ****
# Recent average reward: 96.6
# Reward over last 100: 85.28
# Average over all episodes so far: 123.24230769230769
# epsilon: 0.02
# **** Episode  790 ****
# Recent average reward: 69.3
# Reward over last 100: 82.16
# Average over all episodes so far: 122.55949367088607
# epsilon: 0.02
# **** Episode  800 ****
# Recent average reward: 28.8
# Reward over last 100: 80.18
# Average over all episodes so far: 121.3875
# epsilon: 0.02
# **** Episode  810 ****
# Recent average reward: 65.0
# Reward over last 100: 79.72
# Average over all episodes so far: 120.69135802469135
# epsilon: 0.02
# **** Episode  820 ****
# Recent average reward: 94.4
# Reward over last 100: 83.45
# Average over all episodes so far: 120.37073170731708
# epsilon: 0.02
# **** Episode  830 ****
# Recent average reward: 82.0
# Reward over last 100: 82.09
# Average over all episodes so far: 119.90843373493976
# epsilon: 0.02
# **** Episode  840 ****
# Recent average reward: 85.9
# Reward over last 100: 80.52
# Average over all episodes so far: 119.50357142857143
# epsilon: 0.02
# **** Episode  850 ****
# Recent average reward: 77.0
# Reward over last 100: 80.61
# Average over all episodes so far: 119.0035294117647
# epsilon: 0.02
# **** Episode  860 ****
# Recent average reward: 103.6
# Reward over last 100: 78.53
# Average over all episodes so far: 118.82441860465116
# epsilon: 0.02
# **** Episode  870 ****
# Recent average reward: 82.5
# Reward over last 100: 78.51
# Average over all episodes so far: 118.40689655172413
# epsilon: 0.02
# **** Episode  880 ****
# Recent average reward: 26.9
# Reward over last 100: 71.54
# Average over all episodes so far: 117.36704545454545
# epsilon: 0.02
# **** Episode  890 ****
# Recent average reward: 76.7
# Reward over last 100: 72.28
# Average over all episodes so far: 116.91011235955057
# epsilon: 0.02
# **** Episode  900 ****
# Recent average reward: 84.6
# Reward over last 100: 77.86
# Average over all episodes so far: 116.55111111111111
# epsilon: 0.02
# **** Episode  910 ****
# Recent average reward: 120.5
# Reward over last 100: 83.41
# Average over all episodes so far: 116.5945054945055
# epsilon: 0.02
# **** Episode  920 ****
# Recent average reward: 144.3
# Reward over last 100: 88.4
# Average over all episodes so far: 116.89565217391305
# epsilon: 0.02
# **** Episode  930 ****
# Recent average reward: 47.2
# Reward over last 100: 84.92
# Average over all episodes so far: 116.14623655913978
# epsilon: 0.02
# **** Episode  940 ****
# Recent average reward: 132.0
# Reward over last 100: 89.53
# Average over all episodes so far: 116.31489361702128
# epsilon: 0.02
# **** Episode  950 ****
# Recent average reward: 86.3
# Reward over last 100: 90.46
# Average over all episodes so far: 115.99894736842106
# epsilon: 0.02
# **** Episode  960 ****
# Recent average reward: 119.1
# Reward over last 100: 92.01
# Average over all episodes so far: 116.03125
# epsilon: 0.02
# **** Episode  970 ****
# Recent average reward: 81.7
# Reward over last 100: 91.93
# Average over all episodes so far: 115.67731958762887
# epsilon: 0.02
# **** Episode  980 ****
# Recent average reward: 158.1
# Reward over last 100: 105.05
# Average over all episodes so far: 116.11020408163266
# epsilon: 0.02
# **** Episode  990 ****
# Recent average reward: 142.4
# Reward over last 100: 111.62
# Average over all episodes so far: 116.37575757575758
# epsilon: 0.02
# CPU times: user 9min 6s, sys: 7.25 s, total: 9min 13s
# Wall time: 9min 25s

# %%
plt.plot(steps_total)
plt.show()

# %%
print("Average number of steps: {}". format(np.average(steps_total)))
# Out:
# Average number of steps: 116.851

# %%
print("Average number of steps=reward: {}". format(np.average(steps_total)))
print("Average number of steps=reward in last 100 episodes: {}". format(np.average(steps_total[-100:])))
# Out:
# Average number of steps=reward: 116.851
# Average number of steps=reward in last 100 episodes: 119.55

# %% [markdown]
# plt.figure(1,figsize=[12,5])
# plt.title("Rewards")
# plt.bar(torch.arange(len(rewards_total)), rewards_total,alpha=0.6, color='green')
# #plt.plot(rewards_total)
# plt.show()

# %%
plt.figure(2,figsize=[12,5])
plt.title("Steps to finish episode")
plt.plot(steps_total)
plt.show()
