# %%
import sys  
sys.path.insert(0, '../')
sys.path.insert(0, '../baselines')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from datetime import datetime

# %%
import random

# %%
class CONFIG:
    pass

config=CONFIG()

config.use_cuda=True
config.device="cuda:5"

config.env_id="PongNoFrameskip-v4"
config.exp_name=config.env_id+"-"+datetime.now().strftime("%Y_%m_%d_%H:%M:%S")
config.result_path=%pwd 
config.result_path+= '/../results/'
print('result path is'+config.result_path)

config.learning_rate = 0.0001
config.num_episodes = 1000
config.gamma=0.99
#gamma=0.85
config.egreedy = 0.9
config.egreedy_final = 0.01
config.egreedy_decay = 10000

config.report_interval=10

config.score_to_solve = 18.0

config.hidden_layer_size=512

config.replay_memory_size=100000
#config.replay_memory_size=100

config.batch_size=32

config.update_target_frequency = 5000

config.clip_error=True
config.normalize_image=True

config.double_dqn=True

config.save_movies=True

config.save_model_frequency=10000

config.resume_previous_training=False

#config.memory_device=config.device
config.memory_device='cpu'
# Out:
# result path is/home/wfedorko/RL_sandbox/notebooks/../results/

# %%
from utils.engine import Engine

# %%
my_engine=Engine(config)
# Out:
# devices: compute: cuda:5; Experience Replay: cpu
# Directory  /home/wfedorko/RL_sandbox/notebooks/../results//PongNoFrameskip-v4-2020_04_27_19:34:24  Created
# will save movies
# creating state memory with shape: [100000, 1, 84, 84]

# %%
# %load_ext line_profiler

# %%
from agents.QNet_Agent import QNet_Agent
from models.models import SimpleCNNDuelingAllMean
from utils.ExperienceReplay import ExperienceReplay

# %%
# %lprun -f Engine.train_agent -f QNet_Agent.optimize -f SimpleCNNDuelingAllMean.forward -f ExperienceReplay.push -f ExperienceReplay.sample my_engine.train_agent()
# Out:
# training the agent
# **** Episode  10 ****
# Recent average reward: -20.0
# Average over all episodes so far: -20.0
# epsilon: 0.3268794642870936
# Elapsed time:  00:02:06
# **** Episode  20 ****
# Recent average reward: -20.3
# Average over all episodes so far: -20.15
# epsilon: 0.14376994052837147
# Elapsed time:  00:03:46
# **** Episode  30 ****
# Recent average reward: -20.2
# Average over all episodes so far: -20.166666666666668
# epsilon: 0.06458840309840348
# Elapsed time:  00:05:33
# **** Episode  40 ****
# Recent average reward: -19.9
# Average over all episodes so far: -20.1
# epsilon: 0.031132697017213364
# Elapsed time:  00:07:26
# **** Episode  50 ****
# Recent average reward: -19.2
# Average over all episodes so far: -19.92
# epsilon: 0.017696159688752672
# Elapsed time:  00:09:22
# **** Episode  60 ****
# Recent average reward: -19.3
# Average over all episodes so far: -19.816666666666666
# epsilon: 0.012741818709302376
# Elapsed time:  00:11:24
# **** Episode  70 ****
# Recent average reward: -18.1
# Average over all episodes so far: -19.571428571428573
# epsilon: 0.01074633662749001
# Elapsed time:  00:13:55
# **** Episode  80 ****
# Recent average reward: -16.9
# Average over all episodes so far: -19.2375
# epsilon: 0.010150908960094523
# Elapsed time:  00:17:01
# **** Episode  90 ****
# Recent average reward: -16.0
# Average over all episodes so far: -18.877777777777776
# epsilon: 0.010027439312330678
# Elapsed time:  00:20:19
# **** Episode  100 ****
# Recent average reward: -17.1
# Average over all episodes so far: -18.7
# epsilon: 0.010005135497597021
# Elapsed time:  00:23:35
# **** Episode  110 ****
# Recent average reward: -14.7
# Reward over last 100: -18.17
# Average over all episodes so far: -18.336363636363636
# epsilon: 0.010000476721289174
# Elapsed time:  00:28:07
# **** Episode  120 ****
# Recent average reward: -14.2
# Reward over last 100: -17.56
# Average over all episodes so far: -17.991666666666667
# epsilon: 0.010000051348309807
# Elapsed time:  00:32:28
# **** Episode  130 ****
# Recent average reward: -17.2
# Reward over last 100: -17.26
# Average over all episodes so far: -17.93076923076923
# epsilon: 0.010000008710524618
# Elapsed time:  00:35:53
# **** Episode  140 ****
# Recent average reward: -15.0
# Reward over last 100: -16.77
# Average over all episodes so far: -17.72142857142857
# epsilon: 0.010000001113081195
# Elapsed time:  00:39:53
# **** Episode  150 ****
# Recent average reward: -15.8
# Reward over last 100: -16.43
# Average over all episodes so far: -17.593333333333334
# epsilon: 0.010000000164364628
# Elapsed time:  00:43:37
# **** Episode  160 ****
# Recent average reward: -11.9
# Reward over last 100: -15.69
# Average over all episodes so far: -17.2375
# epsilon: 0.010000000014640437
# Elapsed time:  00:48:17
# **** Episode  170 ****
# Recent average reward: -13.3
# Reward over last 100: -15.21
# Average over all episodes so far: -17.00588235294118
# epsilon: 0.010000000001459345
# Elapsed time:  00:52:43
# **** Episode  180 ****
# Recent average reward: -13.0
# Reward over last 100: -14.82
# Average over all episodes so far: -16.783333333333335
# epsilon: 0.010000000000156217
# Elapsed time:  00:57:03
# **** Episode  190 ****
# Recent average reward: -12.1
# Reward over last 100: -14.43
# Average over all episodes so far: -16.53684210526316
# epsilon: 0.010000000000011585
# Elapsed time:  01:02:05
# **** Episode  200 ****
# Recent average reward: -11.7
# Reward over last 100: -13.89
# Average over all episodes so far: -16.295
# epsilon: 0.010000000000000822
# Elapsed time:  01:07:12
# **** Episode  210 ****
# Recent average reward: -9.0
# Reward over last 100: -13.32
# Average over all episodes so far: -15.947619047619048
# epsilon: 0.010000000000000049
# Elapsed time:  01:12:39
# **** Episode  220 ****
# Recent average reward: -6.4
# Reward over last 100: -12.54
# Average over all episodes so far: -15.513636363636364
# epsilon: 0.010000000000000002
# Elapsed time:  01:18:35
# **** Episode  230 ****
# Recent average reward: 0.7
# Reward over last 100: -10.75
# Average over all episodes so far: -14.808695652173913
# epsilon: 0.01
# Elapsed time:  01:24:29
# **** Episode  240 ****
# Recent average reward: 2.2
# Reward over last 100: -9.03
# Average over all episodes so far: -14.1
# epsilon: 0.01
# Elapsed time:  01:30:24
# **** Episode  250 ****
# Recent average reward: 14.1
# Reward over last 100: -6.04
# Average over all episodes so far: -12.972
# epsilon: 0.01
# Elapsed time:  01:34:47
# **** Episode  260 ****
# Recent average reward: 13.1
# Reward over last 100: -3.54
# Average over all episodes so far: -11.96923076923077
# epsilon: 0.01
# Elapsed time:  01:39:22
# **** Episode  270 ****
# Recent average reward: 14.0
# Reward over last 100: -0.81
# Average over all episodes so far: -11.007407407407408
# epsilon: 0.01
# Elapsed time:  01:43:30
# **** Episode  280 ****
# Recent average reward: 15.9
# Reward over last 100: 2.08
# Average over all episodes so far: -10.04642857142857
# epsilon: 0.01
# Elapsed time:  01:47:32
# **** Episode  290 ****
# Recent average reward: 18.4
# Reward over last 100: 5.13
# Average over all episodes so far: -9.065517241379311
# epsilon: 0.01
# Elapsed time:  01:51:11
# **** Episode  300 ****
# Recent average reward: 16.1
# Reward over last 100: 7.91
# Average over all episodes so far: -8.226666666666667
# epsilon: 0.01
# Elapsed time:  01:55:16
# **** Episode  310 ****
# Recent average reward: 18.2
# Reward over last 100: 10.63
# Average over all episodes so far: -7.374193548387097
# epsilon: 0.01
# Elapsed time:  01:58:53
# **** Episode  320 ****
# Recent average reward: 17.9
# Reward over last 100: 13.06
# Average over all episodes so far: -6.584375
# epsilon: 0.01
# Elapsed time:  02:02:31
# **** Episode  330 ****
# Recent average reward: 17.4
# Reward over last 100: 14.73
# Average over all episodes so far: -5.857575757575757
# epsilon: 0.01
# Elapsed time:  02:06:14
# **** Episode  340 ****
# Recent average reward: 16.8
# Reward over last 100: 16.19
# Average over all episodes so far: -5.1911764705882355
# epsilon: 0.01
# Elapsed time:  02:10:02
# **** Episode  350 ****
# Recent average reward: 18.6
# Reward over last 100: 16.64
# Average over all episodes so far: -4.511428571428572
# epsilon: 0.01
# Elapsed time:  02:13:41
# **** Episode  360 ****
# Recent average reward: 16.3
# Reward over last 100: 16.96
# Average over all episodes so far: -3.933333333333333
# epsilon: 0.01
# Elapsed time:  02:17:37
# **** Episode  370 ****
# Recent average reward: 16.3
# Reward over last 100: 17.19
# Average over all episodes so far: -3.3864864864864863
# epsilon: 0.01
# Elapsed time:  02:21:35
# **** Episode  380 ****
# Recent average reward: 17.6
# Reward over last 100: 17.36
# Average over all episodes so far: -2.8342105263157893
# epsilon: 0.01
# Elapsed time:  02:25:17
# **** Episode  390 ****
# Recent average reward: 18.5
# Reward over last 100: 17.37
# Average over all episodes so far: -2.287179487179487
# epsilon: 0.01
# Elapsed time:  02:28:56
# **** Episode  400 ****
# Recent average reward: 17.1
# Reward over last 100: 17.47
# Average over all episodes so far: -1.8025
# epsilon: 0.01
# Elapsed time:  02:32:47
# **** Episode  420 ****
# Recent average reward: 16.6
# Reward over last 100: 17.2
# Average over all episodes so far: -0.9214285714285714
# epsilon: 0.01
# Elapsed time:  02:40:40
# **** Episode  430 ****
# Recent average reward: 19.1
# Reward over last 100: 17.37
# Average over all episodes so far: -0.4558139534883721
# epsilon: 0.01
# Elapsed time:  02:44:06
# **** Episode  440 ****
# Recent average reward: 17.6
# Reward over last 100: 17.45
# Average over all episodes so far: -0.045454545454545456
# epsilon: 0.01
# Elapsed time:  02:47:44
# **** Episode  450 ****
# Recent average reward: 19.0
# Reward over last 100: 17.49
# Average over all episodes so far: 0.37777777777777777
# epsilon: 0.01
# Elapsed time:  02:51:15
# **** Episode  460 ****
# Recent average reward: 18.9
# Reward over last 100: 17.75
# Average over all episodes so far: 0.7804347826086957
# epsilon: 0.01
# Elapsed time:  02:54:44
# **** Episode  470 ****
# Recent average reward: 18.3
# Reward over last 100: 17.95
# Average over all episodes so far: 1.1531914893617021
# epsilon: 0.01
# Elapsed time:  02:58:24
# SOLVED! After 473 episodes
# **** Episode  480 ****
# Recent average reward: 18.8
# Reward over last 100: 18.07
# Average over all episodes so far: 1.5208333333333333
# epsilon: 0.01
# Elapsed time:  03:02:01
# **** Episode  490 ****
# Recent average reward: 15.2
# Reward over last 100: 17.74
# Average over all episodes so far: 1.8
# epsilon: 0.01
# Elapsed time:  03:06:14
# **** Episode  500 ****
# Recent average reward: 17.0
# Reward over last 100: 17.73
# Average over all episodes so far: 2.104
# epsilon: 0.01
# Elapsed time:  03:10:10
# **** Episode  510 ****
# Recent average reward: 19.0
# Reward over last 100: 17.95
# Average over all episodes so far: 2.4352941176470586
# epsilon: 0.01
# Elapsed time:  03:13:44
# **** Episode  520 ****
# Recent average reward: 19.0
# Reward over last 100: 18.19
# Average over all episodes so far: 2.753846153846154
# epsilon: 0.01
# Elapsed time:  03:17:11
# **** Episode  530 ****
# Recent average reward: 18.3
# Reward over last 100: 18.11
# Average over all episodes so far: 3.047169811320755
# epsilon: 0.01
# Elapsed time:  03:20:49
# **** Episode  540 ****
# Recent average reward: 18.4
# Reward over last 100: 18.19
# Average over all episodes so far: 3.3314814814814815
# epsilon: 0.01
# Elapsed time:  03:24:20
# **** Episode  550 ****
# Recent average reward: 19.0
# Reward over last 100: 18.19
# Average over all episodes so far: 3.6163636363636362
# epsilon: 0.01
# Elapsed time:  03:27:54
# **** Episode  560 ****
# Recent average reward: 19.7
# Reward over last 100: 18.27
# Average over all episodes so far: 3.9035714285714285
# epsilon: 0.01
# Elapsed time:  03:31:20
# **** Episode  570 ****
# Recent average reward: 18.6
# Reward over last 100: 18.3
# Average over all episodes so far: 4.161403508771929
# epsilon: 0.01
# Elapsed time:  03:34:56
# **** Episode  580 ****
# Recent average reward: 20.2
# Reward over last 100: 18.44
# Average over all episodes so far: 4.437931034482759
# epsilon: 0.01
# Elapsed time:  03:38:12
# **** Episode  590 ****
# Recent average reward: 18.9
# Reward over last 100: 18.81
# Average over all episodes so far: 4.683050847457627
# epsilon: 0.01
# Elapsed time:  03:41:50
# **** Episode  600 ****
# Recent average reward: 19.3
# Reward over last 100: 19.04
# Average over all episodes so far: 4.926666666666667
# epsilon: 0.01
# Elapsed time:  03:45:13
# **** Episode  610 ****
# Recent average reward: 17.0
# Reward over last 100: 18.84
# Average over all episodes so far: 5.1245901639344265
# epsilon: 0.01
# Elapsed time:  03:49:02
# **** Episode  620 ****
# Recent average reward: 18.5
# Reward over last 100: 18.79
# Average over all episodes so far: 5.340322580645161
# epsilon: 0.01
# Elapsed time:  03:52:45
# **** Episode  630 ****
# Recent average reward: 17.3
# Reward over last 100: 18.69
# Average over all episodes so far: 5.53015873015873
# epsilon: 0.01
# Elapsed time:  03:56:24
# **** Episode  640 ****
# Recent average reward: 19.4
# Reward over last 100: 18.79
# Average over all episodes so far: 5.746875
# epsilon: 0.01
# Elapsed time:  04:00:00
# **** Episode  650 ****
# Recent average reward: 19.1
# Reward over last 100: 18.8
# Average over all episodes so far: 5.952307692307692
# epsilon: 0.01
# Elapsed time:  04:03:32
# **** Episode  660 ****
# Recent average reward: 19.2
# Reward over last 100: 18.75
# Average over all episodes so far: 6.153030303030303
# epsilon: 0.01
# Elapsed time:  04:07:01
# **** Episode  670 ****
# Recent average reward: 19.1
# Reward over last 100: 18.8
# Average over all episodes so far: 6.3462686567164175
# epsilon: 0.01
# Elapsed time:  04:10:26
# **** Episode  680 ****
# Recent average reward: 17.0
# Reward over last 100: 18.48
# Average over all episodes so far: 6.502941176470588
# epsilon: 0.01
# Elapsed time:  04:14:19
# **** Episode  690 ****
# Recent average reward: 18.8
# Reward over last 100: 18.47
# Average over all episodes so far: 6.681159420289855
# epsilon: 0.01
# Elapsed time:  04:17:43
# **** Episode  700 ****
# Recent average reward: 17.5
# Reward over last 100: 18.29
# Average over all episodes so far: 6.835714285714285
# epsilon: 0.01
# Elapsed time:  04:21:24
# **** Episode  710 ****
# Recent average reward: 18.5
# Reward over last 100: 18.44
# Average over all episodes so far: 7.0
# epsilon: 0.01
# Elapsed time:  04:24:57
# **** Episode  720 ****
# Recent average reward: 17.8
# Reward over last 100: 18.37
# Average over all episodes so far: 7.15
# epsilon: 0.01
# Elapsed time:  04:28:29
# **** Episode  730 ****
# Recent average reward: 18.9
# Reward over last 100: 18.53
# Average over all episodes so far: 7.310958904109589
# epsilon: 0.01
# Elapsed time:  04:32:10
# **** Episode  740 ****
# Recent average reward: 17.8
# Reward over last 100: 18.37
# Average over all episodes so far: 7.452702702702703
# epsilon: 0.01
# Elapsed time:  04:35:47
# **** Episode  750 ****
# Recent average reward: 19.6
# Reward over last 100: 18.42
# Average over all episodes so far: 7.6146666666666665
# epsilon: 0.01
# Elapsed time:  04:39:26
# **** Episode  760 ****
# Recent average reward: 18.2
# Reward over last 100: 18.32
# Average over all episodes so far: 7.753947368421053
# epsilon: 0.01
# Elapsed time:  04:43:00
# **** Episode  770 ****
# Recent average reward: 19.3
# Reward over last 100: 18.34
# Average over all episodes so far: 7.903896103896104
# epsilon: 0.01
# Elapsed time:  04:46:25
# **** Episode  780 ****
# Recent average reward: 19.9
# Reward over last 100: 18.63
# Average over all episodes so far: 8.057692307692308
# epsilon: 0.01
# Elapsed time:  04:49:50
# **** Episode  790 ****
# Recent average reward: 18.4
# Reward over last 100: 18.59
# Average over all episodes so far: 8.188607594936709
# epsilon: 0.01
# Elapsed time:  04:53:31
# **** Episode  800 ****
# Recent average reward: 19.6
# Reward over last 100: 18.8
# Average over all episodes so far: 8.33125
# epsilon: 0.01
# Elapsed time:  04:56:56
# **** Episode  810 ****
# Recent average reward: 19.0
# Reward over last 100: 18.85
# Average over all episodes so far: 8.462962962962964
# epsilon: 0.01
# Elapsed time:  05:00:26
# **** Episode  820 ****
# Recent average reward: 19.6
# Reward over last 100: 19.03
# Average over all episodes so far: 8.598780487804879
# epsilon: 0.01
# Elapsed time:  05:03:47
# **** Episode  830 ****
# Recent average reward: 19.3
# Reward over last 100: 19.07
# Average over all episodes so far: 8.727710843373494
# epsilon: 0.01
# Elapsed time:  05:07:12
# **** Episode  840 ****
# Recent average reward: 18.2
# Reward over last 100: 19.11
# Average over all episodes so far: 8.84047619047619
# epsilon: 0.01
# Elapsed time:  05:11:02
# **** Episode  850 ****
# Recent average reward: 17.6
# Reward over last 100: 18.91
# Average over all episodes so far: 8.943529411764706
# epsilon: 0.01
# Elapsed time:  05:14:45
# **** Episode  860 ****
# Recent average reward: 20.1
# Reward over last 100: 19.1
# Average over all episodes so far: 9.07325581395349
# epsilon: 0.01
# Elapsed time:  05:18:03
# **** Episode  870 ****
# Recent average reward: 19.0
# Reward over last 100: 19.07
# Average over all episodes so far: 9.187356321839081
# epsilon: 0.01
# Elapsed time:  05:21:31
# **** Episode  880 ****
# Recent average reward: 18.3
# Reward over last 100: 18.91
# Average over all episodes so far: 9.290909090909091
# epsilon: 0.01
# Elapsed time:  05:25:03
# **** Episode  890 ****
# Recent average reward: 20.2
# Reward over last 100: 19.09
# Average over all episodes so far: 9.413483146067415
# epsilon: 0.01
# Elapsed time:  05:28:20
# **** Episode  900 ****
# Recent average reward: 19.5
# Reward over last 100: 19.08
# Average over all episodes so far: 9.525555555555556
# epsilon: 0.01
# Elapsed time:  05:31:45
# **** Episode  910 ****
# Recent average reward: 18.8
# Reward over last 100: 19.06
# Average over all episodes so far: 9.627472527472527
# epsilon: 0.01
# Elapsed time:  05:35:15
# **** Episode  920 ****
# Recent average reward: 18.7
# Reward over last 100: 18.97
# Average over all episodes so far: 9.726086956521739
# epsilon: 0.01
# Elapsed time:  05:38:54
# **** Episode  930 ****
# Recent average reward: 18.5
# Reward over last 100: 18.89
# Average over all episodes so far: 9.820430107526882
# epsilon: 0.01
# Elapsed time:  05:42:28
# **** Episode  940 ****
# Recent average reward: 19.3
# Reward over last 100: 19.0
# Average over all episodes so far: 9.921276595744681
# epsilon: 0.01
# Elapsed time:  05:46:01
# **** Episode  950 ****
# Recent average reward: 20.3
# Reward over last 100: 19.27
# Average over all episodes so far: 10.030526315789473
# epsilon: 0.01
# Elapsed time:  05:49:20
# **** Episode  960 ****
# Recent average reward: 19.3
# Reward over last 100: 19.19
# Average over all episodes so far: 10.127083333333333
# epsilon: 0.01
# Elapsed time:  05:52:42
# **** Episode  980 ****
# Recent average reward: 19.4
# Reward over last 100: 19.36
# Average over all episodes so far: 10.318367346938775
# epsilon: 0.01
# Elapsed time:  05:59:25
# **** Episode  990 ****
# Recent average reward: 18.3
# Reward over last 100: 19.17
# Average over all episodes so far: 10.3989898989899
# epsilon: 0.01
# Elapsed time:  06:02:55
# Solved after 473 episodes

# %%
## %debug my_engine.train_agent()
