# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython import display

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
import numpy as np
import math
import random

# %%
import time

# %%
def show_state(env, episode,step, info=""):
    plt.figure(99999,figsize=[8,6])
    plt.clf()
    plt.imshow(env.render(mode='rgb_array'))
    plt.title("episode: {} step: {} ".format(episode,step))
    #plt.title("%s | Step: %d %s" % (env._spec.id,step, info))
    plt.axis('off')

    display.clear_output(wait=True)
    display.display(plt.gcf())

# %%
import gym

# %%
use_cuda = torch.cuda.is_available()
device=torch.device("cuda:4" if use_cuda else "cpu")

# %%
###### PARAMS ######
learning_rate = 0.01
num_episodes = 50000
gamma=0.999999
#gamma=0.85
egreedy = 0.9
egreedy_final = 0.01
egreedy_decay = 500

report_interval=10

score_to_solve = 195

hidden_layer_size=64

replay_memory_size=50000

batch_size=32

update_target_frequency = 100

clip_error=False

# %%
env = gym.make('Breakout-ramDeterministic-v4')

# %%
#env = gym.wrappers.Monitor(env, '../mp4/sandbox10',video_callable=lambda episode_id: True,force=True)
env = gym.wrappers.Monitor(env, '../mp4/breakout_DQN',video_callable=lambda episode_id: episode_id%100==0,force=True)

# %%
number_of_inputs=env.observation_space.shape[0]
number_of_outputs=env.action_space.n

# %%
def calculate_epsilon(steps_done):
    epsilon = egreedy_final + (egreedy - egreedy_final) * \
              math.exp(-1. * steps_done / egreedy_decay )
    return epsilon

# %%
class ExperienceReplay():
    def __init__(self, capacity):
        self.capacity=capacity
        self.memory=[]
        self.position=0
        
    
    def push(self, state,
             action, new_state,
             reward, done):
        
            transition=(state,action,new_state,reward,done)
            
            if self.position>=len(self.memory):
                self.memory.append(transition)
            else:
                self.memory[self.position]=transition
                
            self.position=(self.position+1)%self.capacity
        
    
    def sample(self,batch_size):
        return zip(*random.sample(self.memory, batch_size))
    
    def __len__(self):
        return len(self.memory)

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.linear1 = nn.Linear(number_of_inputs,hidden_layer_size)
        self.linear2 = nn.Linear(hidden_layer_size,number_of_outputs)
        
        self.activation=nn.Tanh()
        
    def forward(self, x):
        output1 = self.linear1(x)
        output1 = self.activation(output1)
        output2 = self.linear2(output1)
        
        return output2

# %%
class QNet_Agent():
    def __init__(self):
        
        self.nn = NeuralNetwork().to(device)
        self.target_nn = NeuralNetwork().to(device)
        
        self.loss_function = nn.MSELoss()
        self.optimizer = optim.Adam(params=self.nn.parameters(), lr=learning_rate)
        
        self.update_target_counter = 0
        
    def select_action(self,state,epsilon):
        
        random_for_egreedy=torch.rand(1).item()
        
        if random_for_egreedy>epsilon:
            self.nn.eval()
            with torch.no_grad():
                state=torch.Tensor(state).to(device)
                predicted_value_from_nn=self.nn(state)
                action=torch.argmax(predicted_value_from_nn).item()
        else:
            action=env.action_space.sample()
                
                
        return action
    
    def optimize(self):
        
        if len(memory)<batch_size:
            return
        
        state, action, new_state, reward, done = memory.sample(batch_size)
        
        state=torch.Tensor(state).to(device)
        new_state=torch.Tensor(new_state).to(device)
        reward=torch.Tensor(reward).to(device)
        
        #the view call below is to transform into column vector
        #so that it can be used in the gather call
        #i.e. we will use it to pick out from the computed value
        #tensor only values indexed by selected action
        action=(torch.Tensor(action).view(-1,1).long()).to(device)
        #print('action: ')
        #print(action)
        #print('contiguous?', action.is_contiguous())
        done=torch.Tensor(done).to(device)
        
        #print('shape of: state, new state, reward, action, done:')
        #print(state.shape)
        #print(new_state.shape)
        #print(reward.shape)
        #print(action.shape)
        #print(done.shape)
        
        
        self.nn.eval()
        self.target_nn.eval()
            
        new_state_values=self.target_nn(new_state).detach()
        #print('shape of: new_state_values')
        #print(new_state_values.shape)
        
        max_new_state_values=torch.max(new_state_values,dim=1)[0]
        #print('shape of: max_new_state_values')
        #print(max_new_state_values.shape)
        target_value=(reward + (1-done)*gamma*max_new_state_values).view(-1,1)
        
        #print('shape of: target_value')
        #print(target_value.shape)
        self.nn.train()
        
        #this will select only the values of the desired actions
        predicted_value=torch.gather(self.nn(state),1,action)
        #print('shape of: predicted_value')
        #print(predicted_value.shape)
        
        
        loss=self.loss_function(predicted_value,target_value)
        self.optimizer.zero_grad()
        loss.backward()
        
        if clip_error:
            for param in self.nn.parameters():
                param.grad.clamp_(-1.0,1.0)
        
        self.optimizer.step()
        
        if self.update_target_counter % update_target_frequency == 0:
            #print("***********************")
            #print("UPDATING TARGET NETWORK")
            #print("update counter: {}".format(self.update_target_counter))
            #print("***********************")
            self.target_nn.load_state_dict(self.nn.state_dict())
        
        self.update_target_counter+=1

# %%
a=torch.randn([3,3])
print(a)
# Out:
# tensor([[ 1.5225,  1.1023,  1.4868],
#         [-2.0261, -0.6412,  0.4389],
#         [ 1.6641,  0.0969,  0.9602]])

# %%
a.clamp_(-1.0,1.0)
# Out:
# tensor([[ 1.0000,  1.0000,  1.0000],
#         [-1.0000, -0.6412,  0.4389],
#         [ 1.0000,  0.0969,  0.9602]])

# %%
a
# Out:
# tensor([[ 1.0000,  1.0000,  1.0000],
#         [-1.0000, -0.6412,  0.4389],
#         [ 1.0000,  0.0969,  0.9602]])

# %%
memory=ExperienceReplay(replay_memory_size)

# %%
qnet_agent=QNet_Agent()

# %%
seed_value=23
env.seed(seed_value)
torch.manual_seed(seed_value)
random.seed(seed_value)

# %%
# %%time

steps_total=np.full([num_episodes],-999,dtype=np.int32)
reward_total=np.full([num_episodes],-999,dtype=np.int32)

frames_total=0

solved_after = 0
solved = False

start_time = time.time()

for i_episode in range(num_episodes):
    
    state = env.reset()
    #for step in range(100):
    step=0
    reward_total[i_episode]=0
    
    while True:
        
        step+=1
        frames_total += 1
        
        epsilon=calculate_epsilon(frames_total)
        
        #action=env.action_space.sample()
        action=qnet_agent.select_action(state,epsilon)
        
        new_state, reward, done, info = env.step(action)
        memory.push(state, action, new_state,
                     reward, done)
        
        reward_total[i_episode]+=reward
        
        qnet_agent.optimize()
        
        state=new_state
        
        if done:
            steps_total[i_episode]=step
            
            if i_episode>100:
                mean_reward_100 = np.sum(reward_total[i_episode-100:i_episode])/100
            
                if (mean_reward_100 > score_to_solve and solved == False):
                    print("SOLVED! After %i episodes " % i_episode)
                    solved_after = i_episode
                    solved = True
            
            if (i_episode % report_interval == 0 and i_episode>1):
                print("**** Episode  {} **** ".format(i_episode))
                recent_avg_reward=np.average(reward_total[i_episode-report_interval:i_episode])
                print("Recent average reward: {}".format(recent_avg_reward))
                if i_episode>100:
                    print("Reward over last 100: {}".format(mean_reward_100))
                full_avg_so_far=np.average(reward_total[:i_episode])
                print("Average over all episodes so far: {}".format(full_avg_so_far))
                print("epsilon: {}".format(epsilon))
            
                #print("Episode {} finished after: {}".format(i_episode,step))
            break
            
if solved:
    print("Solved after %i episodes" % solved_after)
# Out:
# **** Episode  10 ****
# Recent average reward: 1.9
# Average over all episodes so far: 1.9
# epsilon: 0.016405912952911657
# **** Episode  20 ****
# Recent average reward: 2.1
# Average over all episodes so far: 2.0
# epsilon: 0.010057683821353419
# **** Episode  30 ****
# Recent average reward: 1.4
# Average over all episodes so far: 1.8
# epsilon: 0.010001167630803692
# **** Episode  40 ****
# Recent average reward: 1.1
# Average over all episodes so far: 1.625
# epsilon: 0.0100000226176827
# **** Episode  50 ****
# Recent average reward: 2.0
# Average over all episodes so far: 1.7
# epsilon: 0.010000000258394452
# **** Episode  60 ****
# Recent average reward: 1.2
# Average over all episodes so far: 1.6166666666666667
# epsilon: 0.010000000004248166
# **** Episode  70 ****
# Recent average reward: 2.3
# Average over all episodes so far: 1.7142857142857142
# epsilon: 0.010000000000030334
# **** Episode  80 ****
# Recent average reward: 1.7
# Average over all episodes so far: 1.7125
# epsilon: 0.010000000000000387
# **** Episode  90 ****
# Recent average reward: 1.9
# Average over all episodes so far: 1.7333333333333334
# epsilon: 0.010000000000000005
# **** Episode  100 ****
# Recent average reward: 1.6
# Average over all episodes so far: 1.72
# epsilon: 0.01
# **** Episode  110 ****
# Recent average reward: 1.8
# Reward over last 100: 1.71
# Average over all episodes so far: 1.7272727272727273
# epsilon: 0.01
# **** Episode  120 ****
# Recent average reward: 1.2
# Reward over last 100: 1.62
# Average over all episodes so far: 1.6833333333333333
# epsilon: 0.01
# **** Episode  130 ****
# Recent average reward: 1.8
# Reward over last 100: 1.66
# Average over all episodes so far: 1.6923076923076923
# epsilon: 0.01
# **** Episode  140 ****
# Recent average reward: 2.3
# Reward over last 100: 1.78
# Average over all episodes so far: 1.7357142857142858
# epsilon: 0.01
# **** Episode  150 ****
# Recent average reward: 1.6
# Reward over last 100: 1.74
# Average over all episodes so far: 1.7266666666666666
# epsilon: 0.01
# **** Episode  160 ****
# Recent average reward: 2.3
# Reward over last 100: 1.85
# Average over all episodes so far: 1.7625
# epsilon: 0.01
# **** Episode  170 ****
# Recent average reward: 1.1
# Reward over last 100: 1.73
# Average over all episodes so far: 1.723529411764706
# epsilon: 0.01
# **** Episode  180 ****
# Recent average reward: 1.5
# Reward over last 100: 1.71
# Average over all episodes so far: 1.711111111111111
# epsilon: 0.01
# **** Episode  190 ****
# Recent average reward: 2.3
# Reward over last 100: 1.75
# Average over all episodes so far: 1.7421052631578948
# epsilon: 0.01
# **** Episode  200 ****
# Recent average reward: 1.8
# Reward over last 100: 1.77
# Average over all episodes so far: 1.745
# epsilon: 0.01
# **** Episode  210 ****
# Recent average reward: 1.6
# Reward over last 100: 1.75
# Average over all episodes so far: 1.7380952380952381
# epsilon: 0.01
# **** Episode  220 ****
# Recent average reward: 1.4
# Reward over last 100: 1.77
# Average over all episodes so far: 1.7227272727272727
# epsilon: 0.01
# **** Episode  230 ****
# Recent average reward: 1.3
# Reward over last 100: 1.72
# Average over all episodes so far: 1.7043478260869565
# epsilon: 0.01
# **** Episode  240 ****
# Recent average reward: 2.1
# Reward over last 100: 1.7
# Average over all episodes so far: 1.7208333333333334
# epsilon: 0.01
# **** Episode  250 ****
# Recent average reward: 2.1
# Reward over last 100: 1.75
# Average over all episodes so far: 1.736
# epsilon: 0.01
# **** Episode  260 ****
# Recent average reward: 2.4
# Reward over last 100: 1.76
# Average over all episodes so far: 1.7615384615384615
# epsilon: 0.01
# **** Episode  270 ****
# Recent average reward: 2.1
# Reward over last 100: 1.86
# Average over all episodes so far: 1.7740740740740741
# epsilon: 0.01
# **** Episode  280 ****
# Recent average reward: 1.8
# Reward over last 100: 1.89
# Average over all episodes so far: 1.775
# epsilon: 0.01
# **** Episode  290 ****
# Recent average reward: 1.8
# Reward over last 100: 1.84
# Average over all episodes so far: 1.7758620689655173
# epsilon: 0.01
# **** Episode  300 ****
# Recent average reward: 1.5
# Reward over last 100: 1.81
# Average over all episodes so far: 1.7666666666666666
# epsilon: 0.01
# **** Episode  310 ****
# Recent average reward: 1.0
# Reward over last 100: 1.75
# Average over all episodes so far: 1.7419354838709677
# epsilon: 0.01
# **** Episode  320 ****
# Recent average reward: 2.6
# Reward over last 100: 1.87
# Average over all episodes so far: 1.76875
# epsilon: 0.01
# **** Episode  330 ****
# Recent average reward: 1.0
# Reward over last 100: 1.84
# Average over all episodes so far: 1.7454545454545454
# epsilon: 0.01
# **** Episode  340 ****
# Recent average reward: 1.8
# Reward over last 100: 1.81
# Average over all episodes so far: 1.7470588235294118
# epsilon: 0.01
# **** Episode  350 ****
# Recent average reward: 2.1
# Reward over last 100: 1.81
# Average over all episodes so far: 1.7571428571428571
# epsilon: 0.01
# **** Episode  360 ****
# Recent average reward: 1.5
# Reward over last 100: 1.72
# Average over all episodes so far: 1.75
# epsilon: 0.01
# **** Episode  370 ****
# Recent average reward: 3.0
# Reward over last 100: 1.81
# Average over all episodes so far: 1.7837837837837838
# epsilon: 0.01
# **** Episode  380 ****
# Recent average reward: 3.1
# Reward over last 100: 1.94
# Average over all episodes so far: 1.818421052631579
# epsilon: 0.01
# **** Episode  390 ****
# Recent average reward: 2.3
# Reward over last 100: 1.99
# Average over all episodes so far: 1.8307692307692307
# epsilon: 0.01
# **** Episode  400 ****
# Recent average reward: 2.4
# Reward over last 100: 2.08
# Average over all episodes so far: 1.845
# epsilon: 0.01
# **** Episode  410 ****
# Recent average reward: 2.0
# Reward over last 100: 2.18
# Average over all episodes so far: 1.8487804878048781
# epsilon: 0.01
# **** Episode  420 ****
# Recent average reward: 2.1
# Reward over last 100: 2.13
# Average over all episodes so far: 1.8547619047619048
# epsilon: 0.01
# **** Episode  430 ****
# Recent average reward: 1.1
# Reward over last 100: 2.14
# Average over all episodes so far: 1.8372093023255813
# epsilon: 0.01
# **** Episode  440 ****
# Recent average reward: 2.2
# Reward over last 100: 2.18
# Average over all episodes so far: 1.8454545454545455
# epsilon: 0.01
# **** Episode  450 ****
# Recent average reward: 2.0
# Reward over last 100: 2.17
# Average over all episodes so far: 1.8488888888888888
# epsilon: 0.01
# **** Episode  460 ****
# Recent average reward: 1.9
# Reward over last 100: 2.21
# Average over all episodes so far: 1.85
# epsilon: 0.01
# **** Episode  470 ****
# Recent average reward: 1.8
# Reward over last 100: 2.09
# Average over all episodes so far: 1.848936170212766
# epsilon: 0.01
# **** Episode  480 ****
# Recent average reward: 2.4
# Reward over last 100: 2.02
# Average over all episodes so far: 1.8604166666666666
# epsilon: 0.01
# **** Episode  490 ****
# Recent average reward: 2.9
# Reward over last 100: 2.08
# Average over all episodes so far: 1.8816326530612244
# epsilon: 0.01
# **** Episode  500 ****
# Recent average reward: 2.4
# Reward over last 100: 2.08
# Average over all episodes so far: 1.892
# epsilon: 0.01
# **** Episode  510 ****
# Recent average reward: 3.0
# Reward over last 100: 2.18
# Average over all episodes so far: 1.9137254901960785
# epsilon: 0.01
# **** Episode  520 ****
# Recent average reward: 1.8
# Reward over last 100: 2.15
# Average over all episodes so far: 1.9115384615384616
# epsilon: 0.01
# **** Episode  530 ****
# Recent average reward: 2.9
# Reward over last 100: 2.33
# Average over all episodes so far: 1.930188679245283
# epsilon: 0.01
# **** Episode  540 ****
# Recent average reward: 2.3
# Reward over last 100: 2.34
# Average over all episodes so far: 1.9370370370370371
# epsilon: 0.01
# **** Episode  550 ****
# Recent average reward: 2.9
# Reward over last 100: 2.43
# Average over all episodes so far: 1.9545454545454546
# epsilon: 0.01
# **** Episode  560 ****
# Recent average reward: 2.3
# Reward over last 100: 2.47
# Average over all episodes so far: 1.9607142857142856
# epsilon: 0.01
# **** Episode  570 ****
# Recent average reward: 1.5
# Reward over last 100: 2.44
# Average over all episodes so far: 1.9526315789473685
# epsilon: 0.01
# **** Episode  580 ****
# Recent average reward: 2.7
# Reward over last 100: 2.47
# Average over all episodes so far: 1.9655172413793103
# epsilon: 0.01
# **** Episode  590 ****
# Recent average reward: 1.6
# Reward over last 100: 2.34
# Average over all episodes so far: 1.959322033898305
# epsilon: 0.01
# **** Episode  600 ****
# Recent average reward: 1.7
# Reward over last 100: 2.27
# Average over all episodes so far: 1.955
# epsilon: 0.01
# **** Episode  610 ****
# Recent average reward: 1.4
# Reward over last 100: 2.11
# Average over all episodes so far: 1.9459016393442623
# epsilon: 0.01
# **** Episode  620 ****
# Recent average reward: 2.1
# Reward over last 100: 2.14
# Average over all episodes so far: 1.9483870967741936
# epsilon: 0.01
# **** Episode  630 ****
# Recent average reward: 1.3
# Reward over last 100: 1.98
# Average over all episodes so far: 1.938095238095238
# epsilon: 0.01
# **** Episode  640 ****
# Recent average reward: 1.5
# Reward over last 100: 1.9
# Average over all episodes so far: 1.93125
# epsilon: 0.01
# **** Episode  650 ****
# Recent average reward: 1.5
# Reward over last 100: 1.76
# Average over all episodes so far: 1.9246153846153846
# epsilon: 0.01
# **** Episode  660 ****
# Recent average reward: 2.3
# Reward over last 100: 1.76
# Average over all episodes so far: 1.9303030303030304
# epsilon: 0.01
# **** Episode  670 ****
# Recent average reward: 1.6
# Reward over last 100: 1.77
# Average over all episodes so far: 1.9253731343283582
# epsilon: 0.01
# **** Episode  680 ****
# Recent average reward: 2.6
# Reward over last 100: 1.76
# Average over all episodes so far: 1.9352941176470588
# epsilon: 0.01
# **** Episode  690 ****
# Recent average reward: 2.1
# Reward over last 100: 1.81
# Average over all episodes so far: 1.9376811594202898
# epsilon: 0.01
# **** Episode  700 ****
# Recent average reward: 2.1
# Reward over last 100: 1.85
# Average over all episodes so far: 1.94
# epsilon: 0.01
# **** Episode  710 ****
# Recent average reward: 2.6
# Reward over last 100: 1.97
# Average over all episodes so far: 1.9492957746478874
# epsilon: 0.01
# **** Episode  720 ****
# Recent average reward: 2.6
# Reward over last 100: 2.02
# Average over all episodes so far: 1.9583333333333333
# epsilon: 0.01
# **** Episode  730 ****
# Recent average reward: 2.6
# Reward over last 100: 2.15
# Average over all episodes so far: 1.9671232876712328
# epsilon: 0.01
# **** Episode  740 ****
# Recent average reward: 2.2
# Reward over last 100: 2.22
# Average over all episodes so far: 1.9702702702702704
# epsilon: 0.01
# **** Episode  750 ****
# Recent average reward: 2.3
# Reward over last 100: 2.3
# Average over all episodes so far: 1.9746666666666666
# epsilon: 0.01
# **** Episode  760 ****
# Recent average reward: 1.8
# Reward over last 100: 2.25
# Average over all episodes so far: 1.9723684210526315
# epsilon: 0.01
# **** Episode  770 ****
# Recent average reward: 2.8
# Reward over last 100: 2.37
# Average over all episodes so far: 1.983116883116883
# epsilon: 0.01
# **** Episode  780 ****
# Recent average reward: 3.5
# Reward over last 100: 2.46
# Average over all episodes so far: 2.0025641025641026
# epsilon: 0.01
# **** Episode  790 ****
# Recent average reward: 2.1
# Reward over last 100: 2.46
# Average over all episodes so far: 2.0037974683544304
# epsilon: 0.01
# **** Episode  800 ****
# Recent average reward: 2.4
# Reward over last 100: 2.49
# Average over all episodes so far: 2.00875
# epsilon: 0.01
# **** Episode  810 ****
# Recent average reward: 2.5
# Reward over last 100: 2.48
# Average over all episodes so far: 2.0148148148148146
# epsilon: 0.01
# **** Episode  820 ****
# Recent average reward: 2.3
# Reward over last 100: 2.45
# Average over all episodes so far: 2.018292682926829
# epsilon: 0.01
# **** Episode  830 ****
# Recent average reward: 2.0
# Reward over last 100: 2.39
# Average over all episodes so far: 2.0180722891566263
# epsilon: 0.01
# **** Episode  840 ****
# Recent average reward: 2.1
# Reward over last 100: 2.38
# Average over all episodes so far: 2.019047619047619
# epsilon: 0.01
# **** Episode  850 ****
# Recent average reward: 2.5
# Reward over last 100: 2.4
# Average over all episodes so far: 2.0247058823529414
# epsilon: 0.01
# **** Episode  860 ****
# Recent average reward: 2.6
# Reward over last 100: 2.48
# Average over all episodes so far: 2.031395348837209
# epsilon: 0.01
# **** Episode  870 ****
# Recent average reward: 3.0
# Reward over last 100: 2.5
# Average over all episodes so far: 2.042528735632184
# epsilon: 0.01
# **** Episode  880 ****
# Recent average reward: 2.5
# Reward over last 100: 2.4
# Average over all episodes so far: 2.047727272727273
# epsilon: 0.01
# **** Episode  890 ****
# Recent average reward: 1.9
# Reward over last 100: 2.38
# Average over all episodes so far: 2.046067415730337
# epsilon: 0.01
# **** Episode  900 ****
# Recent average reward: 2.8
# Reward over last 100: 2.42
# Average over all episodes so far: 2.0544444444444445
# epsilon: 0.01
# **** Episode  910 ****
# Recent average reward: 1.9
# Reward over last 100: 2.36
# Average over all episodes so far: 2.0527472527472526
# epsilon: 0.01
# **** Episode  920 ****
# Recent average reward: 2.3
# Reward over last 100: 2.36
# Average over all episodes so far: 2.0554347826086956
# epsilon: 0.01
# **** Episode  930 ****
# Recent average reward: 2.1
# Reward over last 100: 2.37
# Average over all episodes so far: 2.055913978494624
# epsilon: 0.01
# **** Episode  940 ****
# Recent average reward: 2.7
# Reward over last 100: 2.43
# Average over all episodes so far: 2.0627659574468087
# epsilon: 0.01
# **** Episode  950 ****
# Recent average reward: 2.4
# Reward over last 100: 2.42
# Average over all episodes so far: 2.066315789473684
# epsilon: 0.01
# **** Episode  960 ****
# Recent average reward: 3.2
# Reward over last 100: 2.48
# Average over all episodes so far: 2.078125
# epsilon: 0.01
# **** Episode  970 ****
# Recent average reward: 2.5
# Reward over last 100: 2.43
# Average over all episodes so far: 2.082474226804124
# epsilon: 0.01
# **** Episode  980 ****
# Recent average reward: 2.2
# Reward over last 100: 2.4
# Average over all episodes so far: 2.083673469387755
# epsilon: 0.01
# **** Episode  990 ****
# Recent average reward: 1.7
# Reward over last 100: 2.38
# Average over all episodes so far: 2.0797979797979798
# epsilon: 0.01
# **** Episode  1000 ****
# Recent average reward: 2.6
# Reward over last 100: 2.36
# Average over all episodes so far: 2.085
# epsilon: 0.01
# **** Episode  1010 ****
# Recent average reward: 2.1
# Reward over last 100: 2.38
# Average over all episodes so far: 2.0851485148514852
# epsilon: 0.01
# **** Episode  1020 ****
# Recent average reward: 3.5
# Reward over last 100: 2.5
# Average over all episodes so far: 2.0990196078431373
# epsilon: 0.01
# **** Episode  1030 ****
# Recent average reward: 2.7
# Reward over last 100: 2.56
# Average over all episodes so far: 2.1048543689320387
# epsilon: 0.01
# **** Episode  1040 ****
# Recent average reward: 4.4
# Reward over last 100: 2.73
# Average over all episodes so far: 2.126923076923077
# epsilon: 0.01
# **** Episode  1050 ****
# Recent average reward: 2.6
# Reward over last 100: 2.75
# Average over all episodes so far: 2.1314285714285712
# epsilon: 0.01
# **** Episode  1060 ****
# Recent average reward: 3.3
# Reward over last 100: 2.76
# Average over all episodes so far: 2.142452830188679
# epsilon: 0.01
# **** Episode  1070 ****
# Recent average reward: 2.5
# Reward over last 100: 2.76
# Average over all episodes so far: 2.1457943925233645
# epsilon: 0.01
# **** Episode  1080 ****
# Recent average reward: 3.2
# Reward over last 100: 2.86
# Average over all episodes so far: 2.1555555555555554
# epsilon: 0.01
# **** Episode  1090 ****
# Recent average reward: 3.3
# Reward over last 100: 3.02
# Average over all episodes so far: 2.1660550458715595
# epsilon: 0.01
# **** Episode  1100 ****
# Recent average reward: 3.3
# Reward over last 100: 3.09
# Average over all episodes so far: 2.1763636363636363
# epsilon: 0.01
# **** Episode  1110 ****
# Recent average reward: 2.3
# Reward over last 100: 3.11
# Average over all episodes so far: 2.1774774774774777
# epsilon: 0.01
# **** Episode  1120 ****
# Recent average reward: 2.3
# Reward over last 100: 2.99
# Average over all episodes so far: 2.1785714285714284
# epsilon: 0.01
# **** Episode  1130 ****
# Recent average reward: 1.9
# Reward over last 100: 2.91
# Average over all episodes so far: 2.1761061946902656
# epsilon: 0.01
# **** Episode  1140 ****
# Recent average reward: 2.0
# Reward over last 100: 2.67
# Average over all episodes so far: 2.174561403508772
# epsilon: 0.01
# **** Episode  1150 ****
# Recent average reward: 2.0
# Reward over last 100: 2.61
# Average over all episodes so far: 2.1730434782608694
# epsilon: 0.01
# **** Episode  1160 ****
# Recent average reward: 1.9
# Reward over last 100: 2.47
# Average over all episodes so far: 2.170689655172414
# epsilon: 0.01
# **** Episode  1170 ****
# Recent average reward: 2.5
# Reward over last 100: 2.47
# Average over all episodes so far: 2.1735042735042733
# epsilon: 0.01
# **** Episode  1180 ****
# Recent average reward: 1.2
# Reward over last 100: 2.27
# Average over all episodes so far: 2.1652542372881354
# epsilon: 0.01
# **** Episode  1190 ****
# Recent average reward: 2.5
# Reward over last 100: 2.19
# Average over all episodes so far: 2.168067226890756
# epsilon: 0.01
# **** Episode  1200 ****
# Recent average reward: 3.0
# Reward over last 100: 2.16
# Average over all episodes so far: 2.175
# epsilon: 0.01
# **** Episode  1210 ****
# Recent average reward: 2.3
# Reward over last 100: 2.16
# Average over all episodes so far: 2.1760330578512397
# epsilon: 0.01
# **** Episode  1220 ****
# Recent average reward: 3.3
# Reward over last 100: 2.26
# Average over all episodes so far: 2.185245901639344
# epsilon: 0.01
# **** Episode  1230 ****
# Recent average reward: 3.0
# Reward over last 100: 2.37
# Average over all episodes so far: 2.191869918699187
# epsilon: 0.01
# **** Episode  1240 ****
# Recent average reward: 2.7
# Reward over last 100: 2.44
# Average over all episodes so far: 2.1959677419354837
# epsilon: 0.01
# **** Episode  1250 ****
# Recent average reward: 3.6
# Reward over last 100: 2.6
# Average over all episodes so far: 2.2072
# epsilon: 0.01
# **** Episode  1260 ****
# Recent average reward: 2.6
# Reward over last 100: 2.67
# Average over all episodes so far: 2.2103174603174605
# epsilon: 0.01
# **** Episode  1270 ****
# Recent average reward: 2.4
# Reward over last 100: 2.66
# Average over all episodes so far: 2.2118110236220474
# epsilon: 0.01
# **** Episode  1280 ****
# Recent average reward: 2.5
# Reward over last 100: 2.79
# Average over all episodes so far: 2.2140625
# epsilon: 0.01
# **** Episode  1290 ****
# Recent average reward: 3.1
# Reward over last 100: 2.85
# Average over all episodes so far: 2.2209302325581395
# epsilon: 0.01
# **** Episode  1300 ****
# Recent average reward: 2.1
# Reward over last 100: 2.76
# Average over all episodes so far: 2.22
# epsilon: 0.01
# **** Episode  1310 ****
# Recent average reward: 3.3
# Reward over last 100: 2.86
# Average over all episodes so far: 2.2282442748091604
# epsilon: 0.01
# **** Episode  1320 ****
# Recent average reward: 2.1
# Reward over last 100: 2.74
# Average over all episodes so far: 2.227272727272727
# epsilon: 0.01
# **** Episode  1330 ****
# Recent average reward: 1.5
# Reward over last 100: 2.59
# Average over all episodes so far: 2.2218045112781954
# epsilon: 0.01
# **** Episode  1340 ****
# Recent average reward: 2.8
# Reward over last 100: 2.6
# Average over all episodes so far: 2.226119402985075
# epsilon: 0.01
# **** Episode  1350 ****
# Recent average reward: 3.1
# Reward over last 100: 2.55
# Average over all episodes so far: 2.2325925925925927
# epsilon: 0.01
# **** Episode  1360 ****
# Recent average reward: 2.9
# Reward over last 100: 2.58
# Average over all episodes so far: 2.2375
# epsilon: 0.01
# **** Episode  1370 ****
# Recent average reward: 2.7
# Reward over last 100: 2.61
# Average over all episodes so far: 2.240875912408759
# epsilon: 0.01
# **** Episode  1380 ****
# Recent average reward: 2.6
# Reward over last 100: 2.62
# Average over all episodes so far: 2.243478260869565
# epsilon: 0.01
# **** Episode  1390 ****
# Recent average reward: 3.2
# Reward over last 100: 2.63
# Average over all episodes so far: 2.2503597122302157
# epsilon: 0.01
# **** Episode  1400 ****
# Recent average reward: 2.3
# Reward over last 100: 2.65
# Average over all episodes so far: 2.250714285714286
# epsilon: 0.01
# **** Episode  1410 ****
# Recent average reward: 2.4
# Reward over last 100: 2.56
# Average over all episodes so far: 2.25177304964539
# epsilon: 0.01
# **** Episode  1420 ****
# Recent average reward: 2.8
# Reward over last 100: 2.63
# Average over all episodes so far: 2.2556338028169014
# epsilon: 0.01
# **** Episode  1430 ****
# Recent average reward: 2.7
# Reward over last 100: 2.75
# Average over all episodes so far: 2.2587412587412588
# epsilon: 0.01
# **** Episode  1440 ****
# Recent average reward: 2.8
# Reward over last 100: 2.75
# Average over all episodes so far: 2.2625
# epsilon: 0.01
# **** Episode  1450 ****
# Recent average reward: 3.2
# Reward over last 100: 2.76
# Average over all episodes so far: 2.268965517241379
# epsilon: 0.01
# **** Episode  1460 ****
# Recent average reward: 3.6
# Reward over last 100: 2.83
# Average over all episodes so far: 2.278082191780822
# epsilon: 0.01
# **** Episode  1470 ****
# Recent average reward: 2.9
# Reward over last 100: 2.85
# Average over all episodes so far: 2.2823129251700682
# epsilon: 0.01
# **** Episode  1480 ****
# Recent average reward: 2.1
# Reward over last 100: 2.8
# Average over all episodes so far: 2.281081081081081
# epsilon: 0.01
# **** Episode  1490 ****
# Recent average reward: 2.7
# Reward over last 100: 2.75
# Average over all episodes so far: 2.2838926174496645
# epsilon: 0.01
# **** Episode  1500 ****
# Recent average reward: 1.6
# Reward over last 100: 2.68
# Average over all episodes so far: 2.279333333333333
# epsilon: 0.01
# **** Episode  1510 ****
# Recent average reward: 1.9
# Reward over last 100: 2.63
# Average over all episodes so far: 2.27682119205298
# epsilon: 0.01
# **** Episode  1520 ****
# Recent average reward: 2.9
# Reward over last 100: 2.64
# Average over all episodes so far: 2.280921052631579
# epsilon: 0.01
# **** Episode  1530 ****
# Recent average reward: 2.4
# Reward over last 100: 2.61
# Average over all episodes so far: 2.2816993464052286
# epsilon: 0.01
# **** Episode  1540 ****
# Recent average reward: 2.4
# Reward over last 100: 2.57
# Average over all episodes so far: 2.2824675324675323
# epsilon: 0.01
# **** Episode  1550 ****
# Recent average reward: 2.9
# Reward over last 100: 2.54
# Average over all episodes so far: 2.286451612903226
# epsilon: 0.01
# **** Episode  1560 ****
# Recent average reward: 2.4
# Reward over last 100: 2.42
# Average over all episodes so far: 2.287179487179487
# epsilon: 0.01
# **** Episode  1570 ****
# Recent average reward: 3.2
# Reward over last 100: 2.45
# Average over all episodes so far: 2.2929936305732483
# epsilon: 0.01
# **** Episode  1580 ****
# Recent average reward: 3.0
# Reward over last 100: 2.54
# Average over all episodes so far: 2.2974683544303796
# epsilon: 0.01
# **** Episode  1590 ****
# Recent average reward: 2.8
# Reward over last 100: 2.55
# Average over all episodes so far: 2.30062893081761
# epsilon: 0.01
# **** Episode  1600 ****
# Recent average reward: 3.0
# Reward over last 100: 2.69
# Average over all episodes so far: 2.305
# epsilon: 0.01
# **** Episode  1610 ****
# Recent average reward: 2.9
# Reward over last 100: 2.79
# Average over all episodes so far: 2.3086956521739133
# epsilon: 0.01
# **** Episode  1620 ****
# Recent average reward: 2.6
# Reward over last 100: 2.76
# Average over all episodes so far: 2.310493827160494
# epsilon: 0.01
# **** Episode  1630 ****
# Recent average reward: 3.4
# Reward over last 100: 2.86
# Average over all episodes so far: 2.3171779141104296
# epsilon: 0.01
# **** Episode  1640 ****
# Recent average reward: 2.3
# Reward over last 100: 2.85
# Average over all episodes so far: 2.317073170731707
# epsilon: 0.01
# **** Episode  1650 ****
# Recent average reward: 2.5
# Reward over last 100: 2.81
# Average over all episodes so far: 2.3181818181818183
# epsilon: 0.01
# **** Episode  1660 ****
# Recent average reward: 4.1
# Reward over last 100: 2.98
# Average over all episodes so far: 2.3289156626506022
# epsilon: 0.01
# **** Episode  1670 ****
# Recent average reward: 2.2
# Reward over last 100: 2.88
# Average over all episodes so far: 2.32814371257485
# epsilon: 0.01
# **** Episode  1680 ****
# Recent average reward: 4.6
# Reward over last 100: 3.04
# Average over all episodes so far: 2.341666666666667
# epsilon: 0.01
# **** Episode  1690 ****
# Recent average reward: 2.8
# Reward over last 100: 3.04
# Average over all episodes so far: 2.344378698224852
# epsilon: 0.01
# **** Episode  1700 ****
# Recent average reward: 1.5
# Reward over last 100: 2.89
# Average over all episodes so far: 2.3394117647058823
# epsilon: 0.01
# **** Episode  1710 ****
# Recent average reward: 2.5
# Reward over last 100: 2.85
# Average over all episodes so far: 2.3403508771929826
# epsilon: 0.01
# **** Episode  1720 ****
# Recent average reward: 2.8
# Reward over last 100: 2.87
# Average over all episodes so far: 2.3430232558139537
# epsilon: 0.01
# **** Episode  1730 ****
# Recent average reward: 2.6
# Reward over last 100: 2.79
# Average over all episodes so far: 2.344508670520231
# epsilon: 0.01
# **** Episode  1740 ****
# Recent average reward: 2.8
# Reward over last 100: 2.84
# Average over all episodes so far: 2.3471264367816094
# epsilon: 0.01
# **** Episode  1750 ****
# Recent average reward: 3.2
# Reward over last 100: 2.91
# Average over all episodes so far: 2.352
# epsilon: 0.01
# **** Episode  1760 ****
# Recent average reward: 2.5
# Reward over last 100: 2.75
# Average over all episodes so far: 2.3528409090909093
# epsilon: 0.01
# **** Episode  1770 ****
# Recent average reward: 2.4
# Reward over last 100: 2.77
# Average over all episodes so far: 2.353107344632768
# epsilon: 0.01
# **** Episode  1780 ****
# Recent average reward: 2.3
# Reward over last 100: 2.54
# Average over all episodes so far: 2.352808988764045
# epsilon: 0.01
# **** Episode  1790 ****
# Recent average reward: 4.9
# Reward over last 100: 2.75
# Average over all episodes so far: 2.3670391061452514
# epsilon: 0.01
# **** Episode  1800 ****
# Recent average reward: 2.8
# Reward over last 100: 2.88
# Average over all episodes so far: 2.3694444444444445
# epsilon: 0.01
# **** Episode  1810 ****
# Recent average reward: 3.5
# Reward over last 100: 2.98
# Average over all episodes so far: 2.3756906077348066
# epsilon: 0.01
# **** Episode  1820 ****
# Recent average reward: 2.0
# Reward over last 100: 2.9
# Average over all episodes so far: 2.3736263736263736
# epsilon: 0.01
# **** Episode  1830 ****
# Recent average reward: 2.9
# Reward over last 100: 2.93
# Average over all episodes so far: 2.376502732240437
# epsilon: 0.01
# **** Episode  1840 ****
# Recent average reward: 2.4
# Reward over last 100: 2.89
# Average over all episodes so far: 2.3766304347826086
# epsilon: 0.01
# **** Episode  1850 ****
# Recent average reward: 2.9
# Reward over last 100: 2.86
# Average over all episodes so far: 2.3794594594594596
# epsilon: 0.01
# **** Episode  1860 ****
# Recent average reward: 2.6
# Reward over last 100: 2.87
# Average over all episodes so far: 2.3806451612903228
# epsilon: 0.01
# **** Episode  1870 ****
# Recent average reward: 4.4
# Reward over last 100: 3.07
# Average over all episodes so far: 2.39144385026738
# epsilon: 0.01
# **** Episode  1880 ****
# Recent average reward: 2.8
# Reward over last 100: 3.12
# Average over all episodes so far: 2.393617021276596
# epsilon: 0.01
# **** Episode  1890 ****
# Recent average reward: 2.6
# Reward over last 100: 2.89
# Average over all episodes so far: 2.394708994708995
# epsilon: 0.01
# **** Episode  1900 ****
# Recent average reward: 2.6
# Reward over last 100: 2.87
# Average over all episodes so far: 2.3957894736842107
# epsilon: 0.01
# **** Episode  1910 ****
# Recent average reward: 2.9
# Reward over last 100: 2.81
# Average over all episodes so far: 2.398429319371728
# epsilon: 0.01
# **** Episode  1920 ****
# Recent average reward: 3.8
# Reward over last 100: 2.99
# Average over all episodes so far: 2.4057291666666667
# epsilon: 0.01
# **** Episode  1930 ****
# Recent average reward: 2.9
# Reward over last 100: 2.99
# Average over all episodes so far: 2.4082901554404144
# epsilon: 0.01
# **** Episode  1940 ****
# Recent average reward: 3.2
# Reward over last 100: 3.07
# Average over all episodes so far: 2.4123711340206184
# epsilon: 0.01
# **** Episode  1950 ****
# Recent average reward: 3.2
# Reward over last 100: 3.1
# Average over all episodes so far: 2.4164102564102565
# epsilon: 0.01
# **** Episode  1960 ****
# Recent average reward: 3.3
# Reward over last 100: 3.17
# Average over all episodes so far: 2.420918367346939
# epsilon: 0.01
# **** Episode  1970 ****
# Recent average reward: 3.7
# Reward over last 100: 3.1
# Average over all episodes so far: 2.42741116751269
# epsilon: 0.01
# **** Episode  1980 ****
# Recent average reward: 2.4
# Reward over last 100: 3.06
# Average over all episodes so far: 2.4272727272727272
# epsilon: 0.01
# **** Episode  1990 ****
# Recent average reward: 1.7
# Reward over last 100: 2.97
# Average over all episodes so far: 2.4236180904522615
# epsilon: 0.01
# **** Episode  2000 ****
# Recent average reward: 1.7
# Reward over last 100: 2.88
# Average over all episodes so far: 2.42
# epsilon: 0.01
# **** Episode  2010 ****
# Recent average reward: 2.6
# Reward over last 100: 2.85
# Average over all episodes so far: 2.4208955223880597
# epsilon: 0.01
# **** Episode  2020 ****
# Recent average reward: 3.7
# Reward over last 100: 2.84
# Average over all episodes so far: 2.4272277227722774
# epsilon: 0.01
# **** Episode  2030 ****
# Recent average reward: 2.5
# Reward over last 100: 2.8
# Average over all episodes so far: 2.4275862068965517
# epsilon: 0.01
# **** Episode  2040 ****
# Recent average reward: 2.4
# Reward over last 100: 2.72
# Average over all episodes so far: 2.4274509803921567
# epsilon: 0.01
# **** Episode  2050 ****
# Recent average reward: 3.7
# Reward over last 100: 2.77
# Average over all episodes so far: 2.433658536585366
# epsilon: 0.01
# **** Episode  2060 ****
# Recent average reward: 3.8
# Reward over last 100: 2.82
# Average over all episodes so far: 2.4402912621359225
# epsilon: 0.01
# **** Episode  2070 ****
# Recent average reward: 2.2
# Reward over last 100: 2.67
# Average over all episodes so far: 2.4391304347826086
# epsilon: 0.01
# **** Episode  2080 ****
# Recent average reward: 2.9
# Reward over last 100: 2.72
# Average over all episodes so far: 2.441346153846154
# epsilon: 0.01
# **** Episode  2090 ****
# Recent average reward: 2.5
# Reward over last 100: 2.8
# Average over all episodes so far: 2.441626794258373
# epsilon: 0.01
# **** Episode  2100 ****
# Recent average reward: 2.0
# Reward over last 100: 2.83
# Average over all episodes so far: 2.4395238095238096
# epsilon: 0.01
# **** Episode  2110 ****
# Recent average reward: 4.9
# Reward over last 100: 3.06
# Average over all episodes so far: 2.451184834123223
# epsilon: 0.01
# **** Episode  2120 ****
# Recent average reward: 2.1
# Reward over last 100: 2.9
# Average over all episodes so far: 2.4495283018867924
# epsilon: 0.01
# **** Episode  2130 ****
# Recent average reward: 1.7
# Reward over last 100: 2.82
# Average over all episodes so far: 2.4460093896713615
# epsilon: 0.01
# **** Episode  2140 ****
# Recent average reward: 3.6
# Reward over last 100: 2.94
# Average over all episodes so far: 2.4514018691588784
# epsilon: 0.01
# **** Episode  2150 ****
# Recent average reward: 3.0
# Reward over last 100: 2.87
# Average over all episodes so far: 2.453953488372093
# epsilon: 0.01
# **** Episode  2160 ****
# Recent average reward: 1.5
# Reward over last 100: 2.64
# Average over all episodes so far: 2.449537037037037
# epsilon: 0.01
# **** Episode  2170 ****
# Recent average reward: 2.1
# Reward over last 100: 2.63
# Average over all episodes so far: 2.447926267281106
# epsilon: 0.01
# **** Episode  2180 ****
# Recent average reward: 3.2
# Reward over last 100: 2.66
# Average over all episodes so far: 2.451376146788991
# epsilon: 0.01
# **** Episode  2190 ****
# Recent average reward: 2.8
# Reward over last 100: 2.69
# Average over all episodes so far: 2.4529680365296804
# epsilon: 0.01
# **** Episode  2200 ****
# Recent average reward: 2.1
# Reward over last 100: 2.7
# Average over all episodes so far: 2.451363636363636
# epsilon: 0.01
# **** Episode  2210 ****
# Recent average reward: 2.3
# Reward over last 100: 2.44
# Average over all episodes so far: 2.4506787330316744
# epsilon: 0.01
# **** Episode  2220 ****
# Recent average reward: 3.1
# Reward over last 100: 2.54
# Average over all episodes so far: 2.4536036036036037
# epsilon: 0.01
# **** Episode  2230 ****
# Recent average reward: 3.7
# Reward over last 100: 2.74
# Average over all episodes so far: 2.459192825112108
# epsilon: 0.01
# **** Episode  2240 ****
# Recent average reward: 2.4
# Reward over last 100: 2.62
# Average over all episodes so far: 2.4589285714285714
# epsilon: 0.01
# **** Episode  2250 ****
# Recent average reward: 5.0
# Reward over last 100: 2.82
# Average over all episodes so far: 2.470222222222222
# epsilon: 0.01
# **** Episode  2260 ****
# Recent average reward: 7.9
# Reward over last 100: 3.46
# Average over all episodes so far: 2.4942477876106195
# epsilon: 0.01
# **** Episode  2270 ****
# Recent average reward: 6.1
# Reward over last 100: 3.86
# Average over all episodes so far: 2.5101321585903085
# epsilon: 0.01
# **** Episode  2280 ****
# Recent average reward: 7.5
# Reward over last 100: 4.29
# Average over all episodes so far: 2.532017543859649
# epsilon: 0.01
# **** Episode  2290 ****
# Recent average reward: 7.1
# Reward over last 100: 4.72
# Average over all episodes so far: 2.5519650655021833
# epsilon: 0.01
# **** Episode  2300 ****
# Recent average reward: 5.7
# Reward over last 100: 5.08
# Average over all episodes so far: 2.5656521739130436
# epsilon: 0.01
# **** Episode  2310 ****
# Recent average reward: 5.3
# Reward over last 100: 5.38
# Average over all episodes so far: 2.5774891774891775
# epsilon: 0.01
# **** Episode  2320 ****
# Recent average reward: 4.4
# Reward over last 100: 5.51
# Average over all episodes so far: 2.5853448275862068
# epsilon: 0.01
# **** Episode  2330 ****
# Recent average reward: 2.5
# Reward over last 100: 5.39
# Average over all episodes so far: 2.584978540772532
# epsilon: 0.01
# **** Episode  2340 ****
# Recent average reward: 2.7
# Reward over last 100: 5.42
# Average over all episodes so far: 2.5854700854700856
# epsilon: 0.01
# **** Episode  2350 ****
# Recent average reward: 3.2
# Reward over last 100: 5.24
# Average over all episodes so far: 2.588085106382979
# epsilon: 0.01
# **** Episode  2360 ****
# Recent average reward: 3.3
# Reward over last 100: 4.78
# Average over all episodes so far: 2.5911016949152543
# epsilon: 0.01
# **** Episode  2370 ****
# Recent average reward: 3.5
# Reward over last 100: 4.52
# Average over all episodes so far: 2.5949367088607596
# epsilon: 0.01
# **** Episode  2380 ****
# Recent average reward: 2.9
# Reward over last 100: 4.06
# Average over all episodes so far: 2.596218487394958
# epsilon: 0.01
# **** Episode  2390 ****
# Recent average reward: 4.1
# Reward over last 100: 3.76
# Average over all episodes so far: 2.602510460251046
# epsilon: 0.01
# **** Episode  2400 ****
# Recent average reward: 6.3
# Reward over last 100: 3.82
# Average over all episodes so far: 2.6179166666666664
# epsilon: 0.01
# **** Episode  2410 ****
# Recent average reward: 3.3
# Reward over last 100: 3.62
# Average over all episodes so far: 2.620746887966805
# epsilon: 0.01
# **** Episode  2420 ****
# Recent average reward: 3.3
# Reward over last 100: 3.51
# Average over all episodes so far: 2.6235537190082643
# epsilon: 0.01
# **** Episode  2430 ****
# Recent average reward: 2.4
# Reward over last 100: 3.5
# Average over all episodes so far: 2.622633744855967
# epsilon: 0.01
# **** Episode  2440 ****
# Recent average reward: 3.7
# Reward over last 100: 3.6
# Average over all episodes so far: 2.627049180327869
# epsilon: 0.01
# **** Episode  2450 ****
# Recent average reward: 4.7
# Reward over last 100: 3.75
# Average over all episodes so far: 2.6355102040816325
# epsilon: 0.01
# **** Episode  2460 ****
# Recent average reward: 5.1
# Reward over last 100: 3.93
# Average over all episodes so far: 2.645528455284553
# epsilon: 0.01
# **** Episode  2470 ****
# Recent average reward: 3.7
# Reward over last 100: 3.95
# Average over all episodes so far: 2.6497975708502026
# epsilon: 0.01
# **** Episode  2480 ****
# Recent average reward: 2.7
# Reward over last 100: 3.93
# Average over all episodes so far: 2.65
# epsilon: 0.01
# **** Episode  2490 ****
# Recent average reward: 3.6
# Reward over last 100: 3.88
# Average over all episodes so far: 2.6538152610441768
# epsilon: 0.01
# **** Episode  2500 ****
# Recent average reward: 2.9
# Reward over last 100: 3.54
# Average over all episodes so far: 2.6548
# epsilon: 0.01
# **** Episode  2510 ****
# Recent average reward: 2.4
# Reward over last 100: 3.45
# Average over all episodes so far: 2.653784860557769
# epsilon: 0.01
# **** Episode  2520 ****
# Recent average reward: 3.3
# Reward over last 100: 3.45
# Average over all episodes so far: 2.6563492063492062
# epsilon: 0.01
# **** Episode  2530 ****
# Recent average reward: 5.2
# Reward over last 100: 3.73
# Average over all episodes so far: 2.666403162055336
# epsilon: 0.01
# **** Episode  2540 ****
# Recent average reward: 4.0
# Reward over last 100: 3.76
# Average over all episodes so far: 2.6716535433070865
# epsilon: 0.01
# **** Episode  2550 ****
# Recent average reward: 1.6
# Reward over last 100: 3.45
# Average over all episodes so far: 2.667450980392157
# epsilon: 0.01
# **** Episode  2560 ****
# Recent average reward: 3.4
# Reward over last 100: 3.28
# Average over all episodes so far: 2.6703125
# epsilon: 0.01
# **** Episode  2570 ****
# Recent average reward: 3.3
# Reward over last 100: 3.24
# Average over all episodes so far: 2.6727626459143967
# epsilon: 0.01
# **** Episode  2580 ****
# Recent average reward: 4.1
# Reward over last 100: 3.38
# Average over all episodes so far: 2.6782945736434107
# epsilon: 0.01
# **** Episode  2590 ****
# Recent average reward: 3.7
# Reward over last 100: 3.39
# Average over all episodes so far: 2.6822393822393824
# epsilon: 0.01
# **** Episode  2600 ****
# Recent average reward: 3.2
# Reward over last 100: 3.42
# Average over all episodes so far: 2.684230769230769
# epsilon: 0.01
# **** Episode  2610 ****
# Recent average reward: 2.0
# Reward over last 100: 3.38
# Average over all episodes so far: 2.6816091954022987
# epsilon: 0.01
# **** Episode  2620 ****
# Recent average reward: 2.2
# Reward over last 100: 3.27
# Average over all episodes so far: 2.679770992366412
# epsilon: 0.01
# **** Episode  2630 ****
# Recent average reward: 1.8
# Reward over last 100: 2.93
# Average over all episodes so far: 2.676425855513308
# epsilon: 0.01
# **** Episode  2640 ****
# Recent average reward: 1.1
# Reward over last 100: 2.64
# Average over all episodes so far: 2.6704545454545454
# epsilon: 0.01
# **** Episode  2650 ****
# Recent average reward: 4.0
# Reward over last 100: 2.88
# Average over all episodes so far: 2.6754716981132076
# epsilon: 0.01
# **** Episode  2660 ****
# Recent average reward: 2.7
# Reward over last 100: 2.81
# Average over all episodes so far: 2.675563909774436
# epsilon: 0.01
# **** Episode  2670 ****
# Recent average reward: 2.1
# Reward over last 100: 2.69
# Average over all episodes so far: 2.6734082397003744
# epsilon: 0.01
# **** Episode  2680 ****
# Recent average reward: 3.5
# Reward over last 100: 2.63
# Average over all episodes so far: 2.676492537313433
# epsilon: 0.01
# **** Episode  2690 ****
# Recent average reward: 5.6
# Reward over last 100: 2.82
# Average over all episodes so far: 2.687360594795539
# epsilon: 0.01
# **** Episode  2700 ****
# Recent average reward: 2.5
# Reward over last 100: 2.75
# Average over all episodes so far: 2.6866666666666665
# epsilon: 0.01
# **** Episode  2710 ****
# Recent average reward: 3.5
# Reward over last 100: 2.9
# Average over all episodes so far: 2.6896678966789667
# epsilon: 0.01
# **** Episode  2720 ****
# Recent average reward: 1.6
# Reward over last 100: 2.84
# Average over all episodes so far: 2.6856617647058822
# epsilon: 0.01
# **** Episode  2730 ****
# Recent average reward: 3.5
# Reward over last 100: 3.01
# Average over all episodes so far: 2.688644688644689
# epsilon: 0.01
# **** Episode  2740 ****
# Recent average reward: 2.1
# Reward over last 100: 3.11
# Average over all episodes so far: 2.6864963503649637
# epsilon: 0.01
# **** Episode  2750 ****
# Recent average reward: 3.1
# Reward over last 100: 3.02
# Average over all episodes so far: 2.688
# epsilon: 0.01
# **** Episode  2760 ****
# Recent average reward: 4.6
# Reward over last 100: 3.21
# Average over all episodes so far: 2.694927536231884
# epsilon: 0.01
# **** Episode  2770 ****
# Recent average reward: 3.1
# Reward over last 100: 3.31
# Average over all episodes so far: 2.696389891696751
# epsilon: 0.01
# **** Episode  2780 ****
# Recent average reward: 2.4
# Reward over last 100: 3.2
# Average over all episodes so far: 2.6953237410071944
# epsilon: 0.01
# **** Episode  2790 ****
# Recent average reward: 2.7
# Reward over last 100: 2.91
# Average over all episodes so far: 2.695340501792115
# epsilon: 0.01
# **** Episode  2800 ****
# Recent average reward: 4.3
# Reward over last 100: 3.09
# Average over all episodes so far: 2.701071428571429
# epsilon: 0.01
# **** Episode  2810 ****
# Recent average reward: 5.2
# Reward over last 100: 3.26
# Average over all episodes so far: 2.709964412811388
# epsilon: 0.01
# **** Episode  2820 ****
# Recent average reward: 3.8
# Reward over last 100: 3.48
# Average over all episodes so far: 2.7138297872340424
# epsilon: 0.01
# **** Episode  2830 ****
# Recent average reward: 4.9
# Reward over last 100: 3.62
# Average over all episodes so far: 2.721554770318021
# epsilon: 0.01
# **** Episode  2840 ****
# Recent average reward: 5.7
# Reward over last 100: 3.98
# Average over all episodes so far: 2.7320422535211266
# epsilon: 0.01
# **** Episode  2850 ****
# Recent average reward: 4.7
# Reward over last 100: 4.14
# Average over all episodes so far: 2.738947368421053
# epsilon: 0.01
# **** Episode  2860 ****
# Recent average reward: 4.0
# Reward over last 100: 4.08
# Average over all episodes so far: 2.7433566433566434
# epsilon: 0.01
# **** Episode  2870 ****
# Recent average reward: 3.3
# Reward over last 100: 4.1
# Average over all episodes so far: 2.745296167247387
# epsilon: 0.01
# **** Episode  2880 ****
# Recent average reward: 4.0
# Reward over last 100: 4.26
# Average over all episodes so far: 2.749652777777778
# epsilon: 0.01
# **** Episode  2890 ****
# Recent average reward: 3.2
# Reward over last 100: 4.31
# Average over all episodes so far: 2.75121107266436
# epsilon: 0.01
# **** Episode  2900 ****
# Recent average reward: 2.8
# Reward over last 100: 4.16
# Average over all episodes so far: 2.7513793103448276
# epsilon: 0.01
# **** Episode  2910 ****
# Recent average reward: 3.0
# Reward over last 100: 3.94
# Average over all episodes so far: 2.752233676975945
# epsilon: 0.01
# **** Episode  2920 ****
# Recent average reward: 3.2
# Reward over last 100: 3.88
# Average over all episodes so far: 2.753767123287671
# epsilon: 0.01
# **** Episode  2930 ****
# Recent average reward: 2.9
# Reward over last 100: 3.68
# Average over all episodes so far: 2.7542662116040955
# epsilon: 0.01
# **** Episode  2940 ****
# Recent average reward: 2.4
# Reward over last 100: 3.35
# Average over all episodes so far: 2.753061224489796
# epsilon: 0.01
# **** Episode  2950 ****
# Recent average reward: 2.2
# Reward over last 100: 3.1
# Average over all episodes so far: 2.7511864406779662
# epsilon: 0.01
# **** Episode  2960 ****
# Recent average reward: 2.2
# Reward over last 100: 2.92
# Average over all episodes so far: 2.7493243243243244
# epsilon: 0.01
# **** Episode  2970 ****
# Recent average reward: 3.6
# Reward over last 100: 2.95
# Average over all episodes so far: 2.752188552188552
# epsilon: 0.01
# **** Episode  2980 ****
# Recent average reward: 3.2
# Reward over last 100: 2.87
# Average over all episodes so far: 2.7536912751677853
# epsilon: 0.01
# **** Episode  2990 ****
# Recent average reward: 2.4
# Reward over last 100: 2.79
# Average over all episodes so far: 2.7525083612040135
# epsilon: 0.01
# **** Episode  3000 ****
# Recent average reward: 3.8
# Reward over last 100: 2.89
# Average over all episodes so far: 2.756
# epsilon: 0.01
# **** Episode  3010 ****
# Recent average reward: 3.5
# Reward over last 100: 2.94
# Average over all episodes so far: 2.758471760797342
# epsilon: 0.01
# **** Episode  3020 ****
# Recent average reward: 3.2
# Reward over last 100: 2.94
# Average over all episodes so far: 2.7599337748344372
# epsilon: 0.01
# **** Episode  3030 ****
# Recent average reward: 2.8
# Reward over last 100: 2.93
# Average over all episodes so far: 2.76006600660066
# epsilon: 0.01
# **** Episode  3040 ****
# Recent average reward: 4.6
# Reward over last 100: 3.15
# Average over all episodes so far: 2.7661184210526315
# epsilon: 0.01
# **** Episode  3050 ****
# Recent average reward: 3.2
# Reward over last 100: 3.25
# Average over all episodes so far: 2.7675409836065574
# epsilon: 0.01
# **** Episode  3060 ****
# Recent average reward: 4.8
# Reward over last 100: 3.51
# Average over all episodes so far: 2.7741830065359476
# epsilon: 0.01
# **** Episode  3070 ****
# Recent average reward: 2.8
# Reward over last 100: 3.43
# Average over all episodes so far: 2.7742671009771986
# epsilon: 0.01
# **** Episode  3080 ****
# Recent average reward: 3.2
# Reward over last 100: 3.43
# Average over all episodes so far: 2.7756493506493505
# epsilon: 0.01
# **** Episode  3090 ****
# Recent average reward: 3.7
# Reward over last 100: 3.56
# Average over all episodes so far: 2.7786407766990293
# epsilon: 0.01
# **** Episode  3100 ****
# Recent average reward: 2.9
# Reward over last 100: 3.47
# Average over all episodes so far: 2.779032258064516
# epsilon: 0.01
# **** Episode  3110 ****
# Recent average reward: 5.0
# Reward over last 100: 3.62
# Average over all episodes so far: 2.7861736334405145
# epsilon: 0.01
# **** Episode  3120 ****
# Recent average reward: 4.3
# Reward over last 100: 3.73
# Average over all episodes so far: 2.791025641025641
# epsilon: 0.01
# **** Episode  3130 ****
# Recent average reward: 6.8
# Reward over last 100: 4.13
# Average over all episodes so far: 2.8038338658146964
# epsilon: 0.01
# **** Episode  3140 ****
# Recent average reward: 4.9
# Reward over last 100: 4.16
# Average over all episodes so far: 2.8105095541401273
# epsilon: 0.01
# **** Episode  3150 ****
# Recent average reward: 4.6
# Reward over last 100: 4.3
# Average over all episodes so far: 2.816190476190476
# epsilon: 0.01
# **** Episode  3160 ****
# Recent average reward: 4.3
# Reward over last 100: 4.25
# Average over all episodes so far: 2.820886075949367
# epsilon: 0.01
# **** Episode  3170 ****
# Recent average reward: 3.1
# Reward over last 100: 4.28
# Average over all episodes so far: 2.821766561514196
# epsilon: 0.01
# **** Episode  3180 ****
# Recent average reward: 3.5
# Reward over last 100: 4.31
# Average over all episodes so far: 2.8238993710691824
# epsilon: 0.01
# **** Episode  3190 ****
# Recent average reward: 5.1
# Reward over last 100: 4.45
# Average over all episodes so far: 2.831034482758621
# epsilon: 0.01
# **** Episode  3200 ****
# Recent average reward: 5.8
# Reward over last 100: 4.74
# Average over all episodes so far: 2.8403125
# epsilon: 0.01
# **** Episode  3210 ****
# Recent average reward: 3.3
# Reward over last 100: 4.57
# Average over all episodes so far: 2.8417445482866044
# epsilon: 0.01
# **** Episode  3220 ****
# Recent average reward: 5.6
# Reward over last 100: 4.7
# Average over all episodes so far: 2.850310559006211
# epsilon: 0.01
# **** Episode  3230 ****
# Recent average reward: 5.9
# Reward over last 100: 4.61
# Average over all episodes so far: 2.859752321981424
# epsilon: 0.01
# **** Episode  3240 ****
# Recent average reward: 6.1
# Reward over last 100: 4.73
# Average over all episodes so far: 2.869753086419753
# epsilon: 0.01
# **** Episode  3250 ****
# Recent average reward: 6.8
# Reward over last 100: 4.95
# Average over all episodes so far: 2.881846153846154
# epsilon: 0.01
# **** Episode  3260 ****
# Recent average reward: 6.9
# Reward over last 100: 5.21
# Average over all episodes so far: 2.894171779141104
# epsilon: 0.01
# **** Episode  3270 ****
# Recent average reward: 4.3
# Reward over last 100: 5.33
# Average over all episodes so far: 2.8984709480122324
# epsilon: 0.01
# **** Episode  3280 ****
# Recent average reward: 3.4
# Reward over last 100: 5.32
# Average over all episodes so far: 2.9
# epsilon: 0.01
# **** Episode  3290 ****
# Recent average reward: 5.1
# Reward over last 100: 5.32
# Average over all episodes so far: 2.9066869300911855
# epsilon: 0.01
# **** Episode  3300 ****
# Recent average reward: 4.1
# Reward over last 100: 5.15
# Average over all episodes so far: 2.91030303030303
# epsilon: 0.01
# **** Episode  3310 ****
# Recent average reward: 4.1
# Reward over last 100: 5.23
# Average over all episodes so far: 2.9138972809667676
# epsilon: 0.01
# **** Episode  3320 ****
# Recent average reward: 5.8
# Reward over last 100: 5.25
# Average over all episodes so far: 2.922590361445783
# epsilon: 0.01
# **** Episode  3330 ****
# Recent average reward: 3.2
# Reward over last 100: 4.98
# Average over all episodes so far: 2.9234234234234235
# epsilon: 0.01
# **** Episode  3340 ****
# Recent average reward: 2.2
# Reward over last 100: 4.59
# Average over all episodes so far: 2.92125748502994
# epsilon: 0.01
# **** Episode  3350 ****
# Recent average reward: 3.0
# Reward over last 100: 4.21
# ...
# epsilon: 0.01
# **** Episode  27350 ****
# Recent average reward: 2.1
# Reward over last 100: 3.71
# Average over all episodes so far: 3.9152468007312615
# epsilon: 0.01
# **** Episode  27360 ****
# Recent average reward: 4.0
# Reward over last 100: 3.87
# Average over all episodes so far: 3.915277777777778
# epsilon: 0.01
# **** Episode  27370 ****
# Recent average reward: 2.7
# Reward over last 100: 3.86
# Average over all episodes so far: 3.9148337595907927
# epsilon: 0.01
# **** Episode  27380 ****
# Recent average reward: 3.0
# Reward over last 100: 3.86
# Average over all episodes so far: 3.9144996347699053
# epsilon: 0.01
# **** Episode  27390 ****
# Recent average reward: 3.1
# Reward over last 100: 3.75
# Average over all episodes so far: 3.914202263599854
# epsilon: 0.01
# **** Episode  27400 ****
# Recent average reward: 4.1
# Reward over last 100: 3.89
# Average over all episodes so far: 3.914270072992701
# epsilon: 0.01
# **** Episode  27410 ****
# Recent average reward: 5.0
# Reward over last 100: 3.92
# Average over all episodes so far: 3.914666180226195
# epsilon: 0.01
# **** Episode  27420 ****
# Recent average reward: 7.3
# Reward over last 100: 4.1
# Average over all episodes so far: 3.915900802334063
# epsilon: 0.01
# **** Episode  27430 ****
# Recent average reward: 8.2
# Reward over last 100: 4.32
# Average over all episodes so far: 3.9174626321545754
# epsilon: 0.01
# **** Episode  27440 ****
# Recent average reward: 5.5
# Reward over last 100: 4.5
# Average over all episodes so far: 3.9180393586005833
# epsilon: 0.01
# **** Episode  27450 ****
# Recent average reward: 4.3
# Reward over last 100: 4.72
# Average over all episodes so far: 3.9181785063752277
# epsilon: 0.01
# **** Episode  27460 ****
# Recent average reward: 3.7
# Reward over last 100: 4.69
# Average over all episodes so far: 3.9180990531682447
# epsilon: 0.01
# **** Episode  27470 ****
# Recent average reward: 4.0
# Reward over last 100: 4.82
# Average over all episodes so far: 3.9181288678558426
# epsilon: 0.01
# **** Episode  27480 ****
# Recent average reward: 4.0
# Reward over last 100: 4.92
# Average over all episodes so far: 3.9181586608442505
# epsilon: 0.01
# **** Episode  27490 ****
# Recent average reward: 2.3
# Reward over last 100: 4.84
# Average over all episodes so far: 3.917570025463805
# epsilon: 0.01
# **** Episode  27500 ****
# Recent average reward: 3.8
# Reward over last 100: 4.81
# Average over all episodes so far: 3.9175272727272725
# epsilon: 0.01
# **** Episode  27510 ****
# Recent average reward: 4.9
# Reward over last 100: 4.8
# Average over all episodes so far: 3.9178844056706654
# epsilon: 0.01
# **** Episode  27520 ****
# Recent average reward: 6.8
# Reward over last 100: 4.75
# Average over all episodes so far: 3.9189316860465118
# epsilon: 0.01
# **** Episode  27530 ****
# Recent average reward: 5.4
# Reward over last 100: 4.47
# Average over all episodes so far: 3.9194696694515074
# epsilon: 0.01
# **** Episode  27540 ****
# Recent average reward: 3.8
# Reward over last 100: 4.3
# Average over all episodes so far: 3.9194262890341323
# epsilon: 0.01
# **** Episode  27550 ****
# Recent average reward: 4.5
# Reward over last 100: 4.32
# Average over all episodes so far: 3.9196370235934666
# epsilon: 0.01
# **** Episode  27560 ****
# Recent average reward: 3.0
# Reward over last 100: 4.25
# Average over all episodes so far: 3.9193033381712628
# epsilon: 0.01
# **** Episode  27570 ****
# Recent average reward: 4.2
# Reward over last 100: 4.27
# Average over all episodes so far: 3.919405150525934
# epsilon: 0.01
# **** Episode  27580 ****
# Recent average reward: 4.9
# Reward over last 100: 4.36
# Average over all episodes so far: 3.919760696156635
# epsilon: 0.01
# **** Episode  27590 ****
# Recent average reward: 3.8
# Reward over last 100: 4.51
# Average over all episodes so far: 3.91971728887278
# epsilon: 0.01
# **** Episode  27600 ****
# Recent average reward: 2.9
# Reward over last 100: 4.42
# Average over all episodes so far: 3.9193478260869563
# epsilon: 0.01
# **** Episode  27610 ****
# Recent average reward: 3.8
# Reward over last 100: 4.31
# Average over all episodes so far: 3.9193045997826874
# epsilon: 0.01
# **** Episode  27620 ****
# Recent average reward: 3.4
# Reward over last 100: 3.97
# Average over all episodes so far: 3.9191165821868212
# epsilon: 0.01
# **** Episode  27630 ****
# Recent average reward: 3.2
# Reward over last 100: 3.75
# Average over all episodes so far: 3.9188563155989864
# epsilon: 0.01
# **** Episode  27640 ****
# Recent average reward: 4.8
# Reward over last 100: 3.85
# Average over all episodes so far: 3.9191751085383504
# epsilon: 0.01
# **** Episode  27650 ****
# Recent average reward: 6.2
# Reward over last 100: 4.02
# Average over all episodes so far: 3.92
# epsilon: 0.01
# **** Episode  27660 ****
# Recent average reward: 3.3
# Reward over last 100: 4.05
# Average over all episodes so far: 3.919775849602314
# epsilon: 0.01
# **** Episode  27670 ****
# Recent average reward: 5.0
# Reward over last 100: 4.13
# Average over all episodes so far: 3.9201662450307193
# epsilon: 0.01
# **** Episode  27680 ****
# Recent average reward: 3.6
# Reward over last 100: 4.0
# Average over all episodes so far: 3.920050578034682
# epsilon: 0.01
# **** Episode  27690 ****
# Recent average reward: 4.5
# Reward over last 100: 4.07
# Average over all episodes so far: 3.920260021668472
# epsilon: 0.01
# **** Episode  27700 ****
# Recent average reward: 5.0
# Reward over last 100: 4.28
# Average over all episodes so far: 3.9206498194945847
# epsilon: 0.01
# **** Episode  27710 ****
# Recent average reward: 6.4
# Reward over last 100: 4.54
# Average over all episodes so far: 3.9215445687477444
# epsilon: 0.01
# **** Episode  27720 ****
# Recent average reward: 2.7
# Reward over last 100: 4.47
# Average over all episodes so far: 3.921103896103896
# epsilon: 0.01
# **** Episode  27730 ****
# Recent average reward: 3.9
# Reward over last 100: 4.54
# Average over all episodes so far: 3.9210962856112515
# epsilon: 0.01
# **** Episode  27740 ****
# Recent average reward: 2.1
# Reward over last 100: 4.27
# Average over all episodes so far: 3.9204397981254506
# epsilon: 0.01
# **** Episode  27750 ****
# Recent average reward: 4.4
# Reward over last 100: 4.09
# Average over all episodes so far: 3.9206126126126124
# epsilon: 0.01
# **** Episode  27760 ****
# Recent average reward: 3.3
# Reward over last 100: 4.09
# Average over all episodes so far: 3.9203890489913547
# epsilon: 0.01
# **** Episode  27770 ****
# Recent average reward: 4.5
# Reward over last 100: 4.04
# Average over all episodes so far: 3.920597767374865
# epsilon: 0.01
# **** Episode  27780 ****
# Recent average reward: 6.0
# Reward over last 100: 4.28
# Average over all episodes so far: 3.9213462922966165
# epsilon: 0.01
# **** Episode  27790 ****
# Recent average reward: 5.8
# Reward over last 100: 4.41
# Average over all episodes so far: 3.9220223101835194
# epsilon: 0.01
# **** Episode  27800 ****
# Recent average reward: 5.6
# Reward over last 100: 4.47
# Average over all episodes so far: 3.9226258992805754
# epsilon: 0.01
# **** Episode  27810 ****
# Recent average reward: 1.6
# Reward over last 100: 3.99
# Average over all episodes so far: 3.9217907227615965
# epsilon: 0.01
# **** Episode  27820 ****
# Recent average reward: 3.9
# Reward over last 100: 4.11
# Average over all episodes so far: 3.921782890007189
# epsilon: 0.01
# **** Episode  27830 ****
# Recent average reward: 4.4
# Reward over last 100: 4.16
# Average over all episodes so far: 3.9219547251167803
# epsilon: 0.01
# **** Episode  27840 ****
# Recent average reward: 4.0
# Reward over last 100: 4.35
# Average over all episodes so far: 3.9219827586206897
# epsilon: 0.01
# **** Episode  27850 ****
# Recent average reward: 4.4
# Reward over last 100: 4.35
# Average over all episodes so far: 3.9221543985637344
# epsilon: 0.01
# **** Episode  27860 ****
# Recent average reward: 5.6
# Reward over last 100: 4.58
# Average over all episodes so far: 3.92275664034458
# epsilon: 0.01
# **** Episode  27870 ****
# Recent average reward: 6.2
# Reward over last 100: 4.75
# Average over all episodes so far: 3.9235737351991387
# epsilon: 0.01
# **** Episode  27880 ****
# Recent average reward: 4.4
# Reward over last 100: 4.59
# Average over all episodes so far: 3.9237446197991392
# epsilon: 0.01
# **** Episode  27890 ****
# Recent average reward: 3.8
# Reward over last 100: 4.39
# Average over all episodes so far: 3.9237002509860166
# epsilon: 0.01
# **** Episode  27900 ****
# Recent average reward: 4.2
# Reward over last 100: 4.25
# Average over all episodes so far: 3.9237992831541217
# epsilon: 0.01
# **** Episode  27910 ****
# Recent average reward: 3.5
# Reward over last 100: 4.44
# Average over all episodes so far: 3.9236474381941955
# epsilon: 0.01
# **** Episode  27920 ****
# Recent average reward: 2.8
# Reward over last 100: 4.33
# Average over all episodes so far: 3.9232449856733522
# epsilon: 0.01
# **** Episode  27930 ****
# Recent average reward: 5.6
# Reward over last 100: 4.45
# Average over all episodes so far: 3.923845327604726
# epsilon: 0.01
# **** Episode  27940 ****
# Recent average reward: 2.5
# Reward over last 100: 4.3
# Average over all episodes so far: 3.9233357193987115
# epsilon: 0.01
# **** Episode  27950 ****
# Recent average reward: 3.6
# Reward over last 100: 4.22
# Average over all episodes so far: 3.9232200357781752
# epsilon: 0.01
# **** Episode  27960 ****
# Recent average reward: 2.9
# Reward over last 100: 3.95
# Average over all episodes so far: 3.922854077253219
# epsilon: 0.01
# **** Episode  27970 ****
# Recent average reward: 3.3
# Reward over last 100: 3.66
# Average over all episodes so far: 3.9226313907758312
# epsilon: 0.01
# **** Episode  27980 ****
# Recent average reward: 2.1
# Reward over last 100: 3.43
# Average over all episodes so far: 3.9219799857040742
# epsilon: 0.01
# **** Episode  27990 ****
# Recent average reward: 5.6
# Reward over last 100: 3.61
# Average over all episodes so far: 3.922579492675956
# epsilon: 0.01
# **** Episode  28000 ****
# Recent average reward: 4.0
# Reward over last 100: 3.59
# Average over all episodes so far: 3.9226071428571427
# epsilon: 0.01
# **** Episode  28010 ****
# Recent average reward: 2.7
# Reward over last 100: 3.51
# Average over all episodes so far: 3.9221706533380933
# epsilon: 0.01
# **** Episode  28020 ****
# Recent average reward: 3.2
# Reward over last 100: 3.55
# Average over all episodes so far: 3.921912919343326
# epsilon: 0.01
# **** Episode  28030 ****
# Recent average reward: 5.9
# Reward over last 100: 3.58
# Average over all episodes so far: 3.9226186229040314
# epsilon: 0.01
# **** Episode  28040 ****
# Recent average reward: 3.3
# Reward over last 100: 3.66
# Average over all episodes so far: 3.9223965763195436
# epsilon: 0.01
# **** Episode  28050 ****
# Recent average reward: 2.2
# Reward over last 100: 3.52
# Average over all episodes so far: 3.921782531194296
# epsilon: 0.01
# **** Episode  28060 ****
# Recent average reward: 4.3
# Reward over last 100: 3.66
# Average over all episodes so far: 3.9219173200285105
# epsilon: 0.01
# **** Episode  28070 ****
# Recent average reward: 4.5
# Reward over last 100: 3.78
# Average over all episodes so far: 3.9221232632703953
# epsilon: 0.01
# **** Episode  28080 ****
# Recent average reward: 3.0
# Reward over last 100: 3.87
# Average over all episodes so far: 3.9217948717948716
# epsilon: 0.01
# **** Episode  28090 ****
# Recent average reward: 5.5
# Reward over last 100: 3.86
# Average over all episodes so far: 3.922356710573158
# epsilon: 0.01
# **** Episode  28100 ****
# Recent average reward: 5.4
# Reward over last 100: 4.0
# Average over all episodes so far: 3.92288256227758
# epsilon: 0.01
# **** Episode  28110 ****
# Recent average reward: 6.2
# Reward over last 100: 4.35
# Average over all episodes so far: 3.923692636072572
# epsilon: 0.01
# **** Episode  28120 ****
# Recent average reward: 5.6
# Reward over last 100: 4.59
# Average over all episodes so far: 3.924288762446657
# epsilon: 0.01
# **** Episode  28130 ****
# Recent average reward: 4.7
# Reward over last 100: 4.47
# Average over all episodes so far: 3.92456452186278
# epsilon: 0.01
# **** Episode  28140 ****
# Recent average reward: 5.5
# Reward over last 100: 4.69
# Average over all episodes so far: 3.925124378109453
# epsilon: 0.01
# **** Episode  28150 ****
# Recent average reward: 3.7
# Reward over last 100: 4.84
# Average over all episodes so far: 3.925044404973357
# epsilon: 0.01
# **** Episode  28160 ****
# Recent average reward: 4.7
# Reward over last 100: 4.88
# Average over all episodes so far: 3.9253196022727272
# epsilon: 0.01
# **** Episode  28170 ****
# Recent average reward: 3.1
# Reward over last 100: 4.74
# Average over all episodes so far: 3.9250266240681575
# epsilon: 0.01
# **** Episode  28180 ****
# Recent average reward: 2.4
# Reward over last 100: 4.68
# Average over all episodes so far: 3.9244854506742373
# epsilon: 0.01
# **** Episode  28190 ****
# Recent average reward: 3.3
# Reward over last 100: 4.46
# Average over all episodes so far: 3.924263923377084
# epsilon: 0.01
# **** Episode  28200 ****
# Recent average reward: 3.7
# Reward over last 100: 4.29
# Average over all episodes so far: 3.9241843971631205
# epsilon: 0.01
# **** Episode  28210 ****
# Recent average reward: 2.2
# Reward over last 100: 3.89
# Average over all episodes so far: 3.9235732009925557
# epsilon: 0.01
# **** Episode  28220 ****
# Recent average reward: 2.6
# Reward over last 100: 3.59
# Average over all episodes so far: 3.9231041814316088
# epsilon: 0.01
# **** Episode  28230 ****
# Recent average reward: 2.9
# Reward over last 100: 3.41
# Average over all episodes so far: 3.922741764080765
# epsilon: 0.01
# **** Episode  28240 ****
# Recent average reward: 2.4
# Reward over last 100: 3.1
# Average over all episodes so far: 3.9222025495750708
# epsilon: 0.01
# **** Episode  28250 ****
# Recent average reward: 3.4
# Reward over last 100: 3.07
# Average over all episodes so far: 3.9220176991150444
# epsilon: 0.01
# **** Episode  28260 ****
# Recent average reward: 3.3
# Reward over last 100: 2.93
# Average over all episodes so far: 3.921797593772116
# epsilon: 0.01
# **** Episode  28270 ****
# Recent average reward: 3.1
# Reward over last 100: 2.93
# Average over all episodes so far: 3.921506897771489
# epsilon: 0.01
# **** Episode  28280 ****
# Recent average reward: 5.1
# Reward over last 100: 3.2
# Average over all episodes so far: 3.921923620933522
# epsilon: 0.01
# **** Episode  28290 ****
# Recent average reward: 4.2
# Reward over last 100: 3.29
# Average over all episodes so far: 3.9220219158713325
# epsilon: 0.01
# **** Episode  28300 ****
# Recent average reward: 6.7
# Reward over last 100: 3.59
# Average over all episodes so far: 3.9230035335689046
# epsilon: 0.01
# **** Episode  28310 ****
# Recent average reward: 7.5
# Reward over last 100: 4.12
# Average over all episodes so far: 3.924267043447545
# epsilon: 0.01
# **** Episode  28320 ****
# Recent average reward: 5.3
# Reward over last 100: 4.39
# Average over all episodes so far: 3.924752824858757
# epsilon: 0.01
# **** Episode  28330 ****
# Recent average reward: 7.8
# Reward over last 100: 4.88
# Average over all episodes so far: 3.926120720084716
# epsilon: 0.01
# **** Episode  28340 ****
# Recent average reward: 9.1
# Reward over last 100: 5.55
# Average over all episodes so far: 3.9279463655610445
# epsilon: 0.01
# **** Episode  28350 ****
# Recent average reward: 4.8
# Reward over last 100: 5.69
# Average over all episodes so far: 3.9282539682539683
# epsilon: 0.01
# **** Episode  28360 ****
# Recent average reward: 5.4
# Reward over last 100: 5.9
# Average over all episodes so far: 3.928772919605078
# epsilon: 0.01
# **** Episode  28370 ****
# Recent average reward: 3.7
# Reward over last 100: 5.96
# Average over all episodes so far: 3.9286922805780753
# epsilon: 0.01
# **** Episode  28380 ****
# Recent average reward: 2.0
# Reward over last 100: 5.65
# Average over all episodes so far: 3.928012684989429
# epsilon: 0.01
# **** Episode  28390 ****
# Recent average reward: 2.5
# Reward over last 100: 5.48
# Average over all episodes so far: 3.9275096865093344
# epsilon: 0.01
# **** Episode  28400 ****
# Recent average reward: 4.5
# Reward over last 100: 5.26
# Average over all episodes so far: 3.9277112676056336
# epsilon: 0.01
# **** Episode  28410 ****
# Recent average reward: 6.0
# Reward over last 100: 5.11
# Average over all episodes so far: 3.9284406898979234
# epsilon: 0.01
# **** Episode  28420 ****
# Recent average reward: 4.9
# Reward over last 100: 5.07
# Average over all episodes so far: 3.9287825475017595
# epsilon: 0.01
# **** Episode  28430 ****
# Recent average reward: 5.3
# Reward over last 100: 4.82
# Average over all episodes so far: 3.9292648610622583
# epsilon: 0.01

# %%
plt.figure(2,figsize=[12,5])
plt.title("Score at end of episode")
plt.plot(reward_total[:frames_total])
plt.show()

# %%
print("Average number of steps: {}". format(np.average(steps_total[:frames_total])))

# %%
print("Average number of steps=reward: {}". format(np.average(steps_total)))
print("Average reward in last 100 episodes: {}". format(np.average(reward_total[frames_total-100:frames_total])))

# %% [markdown]
# plt.figure(1,figsize=[12,5])
# plt.title("Rewards")
# plt.bar(torch.arange(len(rewards_total)), rewards_total,alpha=0.6, color='green')
# #plt.plot(rewards_total)
# plt.show()

# %%
plt.figure(2,figsize=[12,5])
plt.title("Steps to finish episode")
plt.plot(steps_total[:frames_total])
plt.show()
