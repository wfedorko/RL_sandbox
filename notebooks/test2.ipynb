# %%
import sys  
sys.path.insert(0, '../')
sys.path.insert(0, '../baselines')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from baselines.common.atari_wrappers import make_atari, wrap_deepmind

# %%
from datetime import datetime

# %%
import random

# %%
class CONFIG:
    pass

config=CONFIG()

config.use_cuda=True
config.device="cuda:5"

config.env_id="PongNoFrameskip-v4"
config.exp_name=config.env_id+"-"+datetime.now().strftime("%Y_%m_%d_%H:%M:%S")
config.result_path=%pwd 
config.result_path+= '/../results/'
print('result path is'+config.result_path)

config.learning_rate = 0.0001
config.num_episodes = 1000
config.gamma=0.99
#gamma=0.85
config.egreedy = 0.9
config.egreedy_final = 0.01
config.egreedy_decay = 10000

config.report_interval=10

config.score_to_solve = 18.0

config.hidden_layer_size=512

config.replay_memory_size=100000

config.batch_size=32

config.update_target_frequency = 5000

config.clip_error=True
config.normalize_image=True

config.double_dqn=True

config.save_movies=True

config.save_model_frequency=10000

config.resume_previous_training=False
# Out:
# result path is/home/wfedorko/RL_sandbox/notebooks/../results/

# %%
from utils.engine import Engine

# %%
my_engine=Engine(config)
# Out:
# Directory  /home/wfedorko/RL_sandbox/notebooks/../results//PongNoFrameskip-v4-2020_04_23_01:50:53  Created
# will save movies

# %%
# %load_ext line_profiler

# %%
from agents.QNet_Agent import QNet_Agent
from models.models import SimpleCNNDuelingAllMean
from utils.ExperienceReplay import ExperienceReplay

# %%
# %lprun -f Engine.train_agent -f QNet_Agent.optimize -f SimpleCNNDuelingAllMean.forward -f ExperienceReplay.push -f ExperienceReplay.sample my_engine.train_agent()
# Out:
# **** Episode  10 ****
# Recent average reward: -20.4
# Average over all episodes so far: -20.4
# epsilon: 0.3197053813156068
# Elapsed time:  00:03:13
# **** Episode  20 ****
# Recent average reward: -20.4
# Average over all episodes so far: -20.4
# epsilon: 0.13920773561356542
# Elapsed time:  00:05:52
# **** Episode  30 ****
# Recent average reward: -19.9
# Average over all episodes so far: -20.233333333333334
# epsilon: 0.06013009181071136
# Elapsed time:  00:08:48
# **** Episode  40 ****
# Recent average reward: -20.2
# Average over all episodes so far: -20.225
# epsilon: 0.0295196463347929
# Elapsed time:  00:11:44
# **** Episode  50 ****
# Recent average reward: -20.3
# Average over all episodes so far: -20.24
# epsilon: 0.01683544423851705
# Elapsed time:  00:14:58
# **** Episode  60 ****
# Recent average reward: -19.4
# Average over all episodes so far: -20.1
# epsilon: 0.011947451242929103
# Elapsed time:  00:18:55
# **** Episode  70 ****
# Recent average reward: -20.0
# Average over all episodes so far: -20.085714285714285
# epsilon: 0.010293587799696087
# Elapsed time:  00:24:48
# **** Episode  80 ****
# Recent average reward: -17.6
# Average over all episodes so far: -19.775
# epsilon: 0.010037187650922149
# Elapsed time:  00:31:22
# **** Episode  90 ****
# Recent average reward: -18.4
# Average over all episodes so far: -19.622222222222224
# epsilon: 0.010006285068504775
# Elapsed time:  00:36:53
# **** Episode  100 ****
# Recent average reward: -19.2
# Average over all episodes so far: -19.58
# epsilon: 0.01000083458285126
# Elapsed time:  00:43:12
# **** Episode  110 ****
# Recent average reward: -18.9
# Reward over last 100: -19.43
# Average over all episodes so far: -19.51818181818182
# epsilon: 0.010000122674195097
# Elapsed time:  00:49:07
# **** Episode  120 ****
# Recent average reward: -19.5
# Reward over last 100: -19.34
# Average over all episodes so far: -19.516666666666666
# epsilon: 0.010000019904225
# Elapsed time:  00:54:47
# **** Episode  130 ****
# Recent average reward: -18.0
# Reward over last 100: -19.15
# Average over all episodes so far: -19.4
# epsilon: 0.010000002608386994
# Elapsed time:  01:01:05
# **** Episode  140 ****
# Recent average reward: -16.9
# Reward over last 100: -18.82
# Average over all episodes so far: -19.22142857142857
# epsilon: 0.010000000294502443
# Elapsed time:  01:07:55
# **** Episode  150 ****
# Recent average reward: -16.0
# Reward over last 100: -18.39
# Average over all episodes so far: -19.006666666666668
# epsilon: 0.010000000030107892
# Elapsed time:  01:15:01
# **** Episode  160 ****
# Recent average reward: -16.6
# Reward over last 100: -18.11
# Average over all episodes so far: -18.85625
# epsilon: 0.010000000002842225
# Elapsed time:  01:22:19
# **** Episode  170 ****
# Recent average reward: -17.7
# Reward over last 100: -17.88
# Average over all episodes so far: -18.788235294117648
# epsilon: 0.010000000000282942
# Elapsed time:  01:29:28
# **** Episode  180 ****
# Recent average reward: -15.8
# Reward over last 100: -17.7
# Average over all episodes so far: -18.622222222222224
# epsilon: 0.010000000000031635
# Elapsed time:  01:36:06
# **** Episode  190 ****
# Recent average reward: -15.2
# Reward over last 100: -17.38
# Average over all episodes so far: -18.442105263157895
# epsilon: 0.010000000000003064
# Elapsed time:  01:42:54
# **** Episode  200 ****
# Recent average reward: -14.9
# Reward over last 100: -16.95
# Average over all episodes so far: -18.265
# epsilon: 0.010000000000000295
# Elapsed time:  01:49:57
# **** Episode  210 ****
# Recent average reward: -15.7
# Reward over last 100: -16.63
# Average over all episodes so far: -18.142857142857142
# epsilon: 0.010000000000000028
# Elapsed time:  01:57:15
# **** Episode  220 ****
# Recent average reward: -13.7
# Reward over last 100: -16.05
# Average over all episodes so far: -17.94090909090909
# epsilon: 0.010000000000000002
# Elapsed time:  02:05:03
# **** Episode  230 ****
# Recent average reward: -13.2
# Reward over last 100: -15.57
# Average over all episodes so far: -17.734782608695653
# epsilon: 0.01
# Elapsed time:  02:12:34
# **** Episode  240 ****
# Recent average reward: -10.6
# Reward over last 100: -14.94
# Average over all episodes so far: -17.4375
# epsilon: 0.01
# Elapsed time:  02:20:25
# **** Episode  250 ****
# Recent average reward: -13.2
# Reward over last 100: -14.66
# Average over all episodes so far: -17.268
# epsilon: 0.01
# Elapsed time:  02:27:45
# **** Episode  260 ****
# Recent average reward: -7.0
# Reward over last 100: -13.7
# Average over all episodes so far: -16.873076923076923
# epsilon: 0.01
# Elapsed time:  02:36:28
# **** Episode  270 ****
# Recent average reward: -10.3
# Reward over last 100: -12.96
# Average over all episodes so far: -16.62962962962963
# epsilon: 0.01
# Elapsed time:  02:44:52
# **** Episode  280 ****
# Recent average reward: -5.5
# Reward over last 100: -11.93
# Average over all episodes so far: -16.232142857142858
# epsilon: 0.01
# Elapsed time:  02:54:08
# **** Episode  290 ****
# Recent average reward: -7.2
# Reward over last 100: -11.13
# Average over all episodes so far: -15.920689655172414
# epsilon: 0.01
# Elapsed time:  03:03:10
# **** Episode  300 ****
# Recent average reward: -3.1
# Reward over last 100: -9.95
# Average over all episodes so far: -15.493333333333334
# epsilon: 0.01
# Elapsed time:  03:12:17
# **** Episode  310 ****
# Recent average reward: 1.4
# Reward over last 100: -8.24
# Average over all episodes so far: -14.948387096774194
# epsilon: 0.01
# Elapsed time:  03:21:12
# **** Episode  320 ****
# Recent average reward: 5.3
# Reward over last 100: -6.34
# Average over all episodes so far: -14.315625
# epsilon: 0.01
# Elapsed time:  03:29:09
# **** Episode  330 ****
# Recent average reward: 4.7
# Reward over last 100: -4.55
# Average over all episodes so far: -13.73939393939394
# epsilon: 0.01
# Elapsed time:  03:37:14
# **** Episode  340 ****
# Recent average reward: 9.8
# Reward over last 100: -2.51
# Average over all episodes so far: -13.047058823529412
# epsilon: 0.01
# Elapsed time:  03:44:54
# **** Episode  350 ****
# Recent average reward: 15.2
# Reward over last 100: 0.33
# Average over all episodes so far: -12.24
# epsilon: 0.01
# Elapsed time:  03:51:20
# **** Episode  360 ****
# Recent average reward: 17.2
# Reward over last 100: 2.75
# Average over all episodes so far: -11.422222222222222
# epsilon: 0.01
# Elapsed time:  03:57:01
# **** Episode  370 ****
# Recent average reward: 17.3
# Reward over last 100: 5.51
# Average over all episodes so far: -10.645945945945947
# epsilon: 0.01
# Elapsed time:  04:02:48
# **** Episode  380 ****
# Recent average reward: 16.8
# Reward over last 100: 7.74
# Average over all episodes so far: -9.923684210526316
# epsilon: 0.01
# Elapsed time:  04:08:31
# **** Episode  390 ****
# Recent average reward: 17.0
# Reward over last 100: 10.16
# Average over all episodes so far: -9.233333333333333
# epsilon: 0.01
# Elapsed time:  04:14:03
# **** Episode  400 ****
# Recent average reward: 18.0
# Reward over last 100: 12.27
# Average over all episodes so far: -8.5525
# epsilon: 0.01
# Elapsed time:  04:19:50
# **** Episode  410 ****
# Recent average reward: 18.5
# Reward over last 100: 13.98
# Average over all episodes so far: -7.892682926829268
# epsilon: 0.01
# Elapsed time:  04:25:30
# **** Episode  420 ****
# Recent average reward: 16.4
# Reward over last 100: 15.09
# Average over all episodes so far: -7.314285714285714
# epsilon: 0.01
# Elapsed time:  04:31:43
# **** Episode  430 ****
# Recent average reward: 16.6
# Reward over last 100: 16.28
# Average over all episodes so far: -6.758139534883721
# epsilon: 0.01
# Elapsed time:  04:37:54
# **** Episode  440 ****
# Recent average reward: 17.4
# Reward over last 100: 17.04
# Average over all episodes so far: -6.209090909090909
# epsilon: 0.01
# Elapsed time:  04:43:48
# **** Episode  450 ****
# Recent average reward: 18.0
# Reward over last 100: 17.32
# Average over all episodes so far: -5.671111111111111
# epsilon: 0.01
# Elapsed time:  04:49:43
# **** Episode  460 ****
# Recent average reward: 17.8
# Reward over last 100: 17.38
# Average over all episodes so far: -5.160869565217391
# epsilon: 0.01
# Elapsed time:  04:55:36
# **** Episode  470 ****
# Recent average reward: 19.0
# Reward over last 100: 17.55
# Average over all episodes so far: -4.646808510638298
# epsilon: 0.01
# Elapsed time:  05:01:10
# **** Episode  480 ****
# Recent average reward: 18.5
# Reward over last 100: 17.72
# Average over all episodes so far: -4.164583333333334
# epsilon: 0.01
# Elapsed time:  05:07:03
# **** Episode  490 ****
# Recent average reward: 18.0
# Reward over last 100: 17.82
# Average over all episodes so far: -3.7122448979591836
# epsilon: 0.01
# Elapsed time:  05:13:04
# **** Episode  500 ****
# Recent average reward: 17.4
# Reward over last 100: 17.76
# Average over all episodes so far: -3.29
# epsilon: 0.01
# Elapsed time:  05:18:38
# **** Episode  510 ****
# Recent average reward: 18.4
# Reward over last 100: 17.75
# Average over all episodes so far: -2.864705882352941
# epsilon: 0.01
# Elapsed time:  05:24:03
# SOLVED! After 518 episodes
# **** Episode  520 ****
# Recent average reward: 19.2
# Reward over last 100: 18.03
# Average over all episodes so far: -2.4403846153846156
# epsilon: 0.01
# Elapsed time:  05:29:17
# **** Episode  530 ****
# Recent average reward: 19.3
# Reward over last 100: 18.3
# Average over all episodes so far: -2.030188679245283
# epsilon: 0.01
# Elapsed time:  05:34:51
# **** Episode  540 ****
# Recent average reward: 17.9
# Reward over last 100: 18.35
# Average over all episodes so far: -1.6611111111111112
# epsilon: 0.01
# Elapsed time:  05:40:43
# **** Episode  550 ****
# Recent average reward: 17.8
# Reward over last 100: 18.33
# Average over all episodes so far: -1.3072727272727274
# epsilon: 0.01
# Elapsed time:  05:46:31
# **** Episode  560 ****
# Recent average reward: 18.5
# Reward over last 100: 18.4
# Average over all episodes so far: -0.9535714285714286
# epsilon: 0.01
# Elapsed time:  05:52:12
# **** Episode  570 ****
# Recent average reward: 18.8
# Reward over last 100: 18.38
# Average over all episodes so far: -0.6070175438596491
# epsilon: 0.01
# Elapsed time:  05:57:55
# **** Episode  580 ****
# Recent average reward: 18.9
# Reward over last 100: 18.42
# Average over all episodes so far: -0.2706896551724138
# epsilon: 0.01
# Elapsed time:  06:03:34
# **** Episode  590 ****
# Recent average reward: 18.9
# Reward over last 100: 18.51
# Average over all episodes so far: 0.05423728813559322
# epsilon: 0.01
# Elapsed time:  06:09:10
# **** Episode  600 ****
# Recent average reward: 18.4
# Reward over last 100: 18.61
# Average over all episodes so far: 0.36
# epsilon: 0.01
# Elapsed time:  06:14:58
# **** Episode  610 ****
# Recent average reward: 19.0
# Reward over last 100: 18.67
# Average over all episodes so far: 0.6655737704918033
# epsilon: 0.01
# Elapsed time:  06:20:31
# **** Episode  620 ****
# Recent average reward: 17.1
# Reward over last 100: 18.46
# Average over all episodes so far: 0.9306451612903226
# epsilon: 0.01
# Elapsed time:  06:26:38
# **** Episode  630 ****
# Recent average reward: 17.9
# Reward over last 100: 18.32
# Average over all episodes so far: 1.2
# epsilon: 0.01
# Elapsed time:  06:32:21
# **** Episode  640 ****
# Recent average reward: 17.9
# Reward over last 100: 18.32
# Average over all episodes so far: 1.4609375
# epsilon: 0.01
# Elapsed time:  06:38:11
# **** Episode  650 ****
# Recent average reward: 18.0
# Reward over last 100: 18.34
# Average over all episodes so far: 1.7153846153846153
# epsilon: 0.01
# Elapsed time:  06:43:54
# **** Episode  660 ****
# Recent average reward: 19.7
# Reward over last 100: 18.46
# Average over all episodes so far: 1.9878787878787878
# epsilon: 0.01
# Elapsed time:  06:49:13
# **** Episode  670 ****
# Recent average reward: 17.8
# Reward over last 100: 18.36
# Average over all episodes so far: 2.2238805970149254
# epsilon: 0.01
# Elapsed time:  06:55:08
# **** Episode  680 ****
# Recent average reward: 20.2
# Reward over last 100: 18.49
# Average over all episodes so far: 2.488235294117647
# epsilon: 0.01
# Elapsed time:  07:00:29
# **** Episode  690 ****
# Recent average reward: 17.8
# Reward over last 100: 18.38
# Average over all episodes so far: 2.710144927536232
# epsilon: 0.01
# Elapsed time:  07:06:32
# **** Episode  700 ****
# Recent average reward: 17.2
# Reward over last 100: 18.26
# Average over all episodes so far: 2.9171428571428573
# epsilon: 0.01
# Elapsed time:  07:12:26
# **** Episode  710 ****
# Recent average reward: 19.3
# Reward over last 100: 18.29
# Average over all episodes so far: 3.147887323943662
# epsilon: 0.01
# Elapsed time:  07:17:53
# **** Episode  720 ****
# Recent average reward: 19.3
# Reward over last 100: 18.51
# Average over all episodes so far: 3.3722222222222222
# epsilon: 0.01
# Elapsed time:  07:23:28
# **** Episode  730 ****
# Recent average reward: 19.7
# Reward over last 100: 18.69
# Average over all episodes so far: 3.595890410958904
# epsilon: 0.01
# Elapsed time:  07:28:47
# **** Episode  740 ****
# Recent average reward: 19.1
# Reward over last 100: 18.81
# Average over all episodes so far: 3.8054054054054056
# epsilon: 0.01
# Elapsed time:  07:34:03
# **** Episode  750 ****
# Recent average reward: 18.7
# Reward over last 100: 18.88
# Average over all episodes so far: 4.004
# epsilon: 0.01
# Elapsed time:  07:39:28
# **** Episode  760 ****
# Recent average reward: 18.7
# Reward over last 100: 18.78
# Average over all episodes so far: 4.197368421052632
# epsilon: 0.01
# Elapsed time:  07:44:55
# **** Episode  770 ****
# Recent average reward: 16.7
# Reward over last 100: 18.67
# Average over all episodes so far: 4.35974025974026
# epsilon: 0.01
# Elapsed time:  07:51:04
# **** Episode  780 ****
# Recent average reward: 16.8
# Reward over last 100: 18.33
# Average over all episodes so far: 4.519230769230769
# epsilon: 0.01
# Elapsed time:  07:57:00
# **** Episode  790 ****
# Recent average reward: 18.8
# Reward over last 100: 18.43
# Average over all episodes so far: 4.7
# epsilon: 0.01
# Elapsed time:  08:02:29
# **** Episode  800 ****
# Recent average reward: 19.9
# Reward over last 100: 18.7
# Average over all episodes so far: 4.89
# epsilon: 0.01
# Elapsed time:  08:07:45
# **** Episode  810 ****
# Recent average reward: 18.8
# Reward over last 100: 18.65
# Average over all episodes so far: 5.061728395061729
# epsilon: 0.01
# Elapsed time:  08:13:02
# **** Episode  820 ****
# Recent average reward: 18.3
# Reward over last 100: 18.55
# Average over all episodes so far: 5.2231707317073175
# epsilon: 0.01
# Elapsed time:  08:18:41
# **** Episode  830 ****
# Recent average reward: 18.4
# Reward over last 100: 18.42
# Average over all episodes so far: 5.381927710843374
# epsilon: 0.01
# Elapsed time:  08:24:09
# **** Episode  840 ****
# Recent average reward: 18.8
# Reward over last 100: 18.39
# Average over all episodes so far: 5.541666666666667
# epsilon: 0.01
# Elapsed time:  08:29:28
# **** Episode  850 ****
# Recent average reward: 19.1
# Reward over last 100: 18.43
# Average over all episodes so far: 5.701176470588235
# epsilon: 0.01
# Elapsed time:  08:35:02
# **** Episode  860 ****
# Recent average reward: 18.4
# Reward over last 100: 18.4
# Average over all episodes so far: 5.848837209302325
# epsilon: 0.01
# Elapsed time:  08:40:32
# **** Episode  870 ****
# Recent average reward: 15.2
# Reward over last 100: 18.25
# Average over all episodes so far: 5.95632183908046
# epsilon: 0.01
# Elapsed time:  08:47:07
# **** Episode  880 ****
# Recent average reward: 17.8
# Reward over last 100: 18.35
# Average over all episodes so far: 6.090909090909091
# epsilon: 0.01
# Elapsed time:  08:52:47
# **** Episode  890 ****
# Recent average reward: 18.6
# Reward over last 100: 18.33
# Average over all episodes so far: 6.2314606741573035
# epsilon: 0.01
# Elapsed time:  08:58:22
# **** Episode  900 ****
# Recent average reward: 18.9
# Reward over last 100: 18.23
# Average over all episodes so far: 6.372222222222222
# epsilon: 0.01
# Elapsed time:  09:04:08
# **** Episode  910 ****
# Recent average reward: 18.9
# Reward over last 100: 18.24
# Average over all episodes so far: 6.50989010989011
# epsilon: 0.01
# Elapsed time:  09:09:33
# **** Episode  920 ****
# Recent average reward: 17.9
# Reward over last 100: 18.2
# Average over all episodes so far: 6.633695652173913
# epsilon: 0.01
# Elapsed time:  09:15:08
# **** Episode  930 ****
# Recent average reward: 19.6
# Reward over last 100: 18.32
# Average over all episodes so far: 6.773118279569893
# epsilon: 0.01
# Elapsed time:  09:20:29
# **** Episode  940 ****
# Recent average reward: 17.8
# Reward over last 100: 18.22
# Average over all episodes so far: 6.890425531914894
# epsilon: 0.01
# Elapsed time:  09:26:15
# **** Episode  950 ****
# Recent average reward: 19.0
# Reward over last 100: 18.21
# Average over all episodes so far: 7.017894736842106
# epsilon: 0.01
# Elapsed time:  09:31:33
# **** Episode  960 ****
# Recent average reward: 19.9
# Reward over last 100: 18.36
# Average over all episodes so far: 7.152083333333334
# epsilon: 0.01
# Elapsed time:  09:36:44
# **** Episode  970 ****
# Recent average reward: 18.5
# Reward over last 100: 18.69
# Average over all episodes so far: 7.2690721649484535
# epsilon: 0.01
# Elapsed time:  09:42:04
# **** Episode  980 ****
# Recent average reward: 19.8
# Reward over last 100: 18.89
# Average over all episodes so far: 7.396938775510204
# epsilon: 0.01
# Elapsed time:  09:47:11
# **** Episode  990 ****
# Recent average reward: 18.9
# Reward over last 100: 18.92
# Average over all episodes so far: 7.513131313131313
# epsilon: 0.01
# Elapsed time:  09:52:39
# Solved after 518 episodes
