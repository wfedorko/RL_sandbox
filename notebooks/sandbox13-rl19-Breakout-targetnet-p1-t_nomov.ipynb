# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython import display

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
import numpy as np
import math
import random

# %%
import time

# %%
def show_state(env, episode,step, info=""):
    plt.figure(99999,figsize=[8,6])
    plt.clf()
    plt.imshow(env.render(mode='rgb_array'))
    plt.title("episode: {} step: {} ".format(episode,step))
    #plt.title("%s | Step: %d %s" % (env._spec.id,step, info))
    plt.axis('off')

    display.clear_output(wait=True)
    display.display(plt.gcf())

# %%
import gym

# %%
use_cuda = torch.cuda.is_available()
device=torch.device("cuda:5" if use_cuda else "cpu")

# %%
###### PARAMS ######
learning_rate = 0.001
num_episodes = 50000
gamma=0.999999
#gamma=0.85
egreedy = 0.9
egreedy_final = 0.01
egreedy_decay = 50000

report_interval=10

score_to_solve = 195

hidden_layer_size=64

replay_memory_size=500000

batch_size=32

update_target_frequency = 100000

clip_error=True

# %%
env = gym.make('Breakout-ramDeterministic-v4')

# %%
#env = gym.wrappers.Monitor(env, '../mp4/sandbox10',video_callable=lambda episode_id: True,force=True)
#env = gym.wrappers.Monitor(env, '../mp4/breakout_DQN_p1',video_callable=lambda episode_id: episode_id%100==0,force=True)

# %%
number_of_inputs=env.observation_space.shape[0]
number_of_outputs=env.action_space.n

# %%
def calculate_epsilon(steps_done):
    epsilon = egreedy_final + (egreedy - egreedy_final) * \
              math.exp(-1. * steps_done / egreedy_decay )
    return epsilon

# %%
class ExperienceReplay():
    def __init__(self, capacity):
        self.capacity=capacity
        self.memory=[]
        self.position=0
        
    
    def push(self, state,
             action, new_state,
             reward, done):
        
            transition=(state,action,new_state,reward,done)
            
            if self.position>=len(self.memory):
                self.memory.append(transition)
            else:
                self.memory[self.position]=transition
                
            self.position=(self.position+1)%self.capacity
        
    
    def sample(self,batch_size):
        return zip(*random.sample(self.memory, batch_size))
    
    def __len__(self):
        return len(self.memory)

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.linear1 = nn.Linear(number_of_inputs,hidden_layer_size)
        self.linear2 = nn.Linear(hidden_layer_size,number_of_outputs)
        
        self.activation=nn.Tanh()
        
    def forward(self, x):
        output1 = self.linear1(x)
        output1 = self.activation(output1)
        output2 = self.linear2(output1)
        
        return output2

# %%
class QNet_Agent():
    def __init__(self):
        
        self.nn = NeuralNetwork().to(device)
        self.target_nn = NeuralNetwork().to(device)
        
        self.loss_function = nn.MSELoss()
        self.optimizer = optim.Adam(params=self.nn.parameters(), lr=learning_rate)
        
        self.update_target_counter = 0
        
    def select_action(self,state,epsilon):
        
        random_for_egreedy=torch.rand(1).item()
        
        if random_for_egreedy>epsilon:
            self.nn.eval()
            with torch.no_grad():
                state=torch.Tensor(state).to(device)
                predicted_value_from_nn=self.nn(state)
                action=torch.argmax(predicted_value_from_nn).item()
        else:
            action=env.action_space.sample()
                
                
        return action
    
    def optimize(self):
        
        if len(memory)<batch_size:
            return
        
        state, action, new_state, reward, done = memory.sample(batch_size)
        
        state=torch.Tensor(state).to(device)
        new_state=torch.Tensor(new_state).to(device)
        reward=torch.Tensor(reward).to(device)
        
        #the view call below is to transform into column vector
        #so that it can be used in the gather call
        #i.e. we will use it to pick out from the computed value
        #tensor only values indexed by selected action
        action=(torch.Tensor(action).view(-1,1).long()).to(device)
        #print('action: ')
        #print(action)
        #print('contiguous?', action.is_contiguous())
        done=torch.Tensor(done).to(device)
        
        #print('shape of: state, new state, reward, action, done:')
        #print(state.shape)
        #print(new_state.shape)
        #print(reward.shape)
        #print(action.shape)
        #print(done.shape)
        
        
        self.nn.eval()
        self.target_nn.eval()
            
        new_state_values=self.target_nn(new_state).detach()
        #print('shape of: new_state_values')
        #print(new_state_values.shape)
        
        max_new_state_values=torch.max(new_state_values,dim=1)[0]
        #print('shape of: max_new_state_values')
        #print(max_new_state_values.shape)
        target_value=(reward + (1-done)*gamma*max_new_state_values).view(-1,1)
        
        #print('shape of: target_value')
        #print(target_value.shape)
        self.nn.train()
        
        #this will select only the values of the desired actions
        predicted_value=torch.gather(self.nn(state),1,action)
        #print('shape of: predicted_value')
        #print(predicted_value.shape)
        
        
        loss=self.loss_function(predicted_value,target_value)
        self.optimizer.zero_grad()
        loss.backward()
        
        if clip_error:
            for param in self.nn.parameters():
                param.grad.clamp_(-1.0,1.0)
        
        self.optimizer.step()
        
        if self.update_target_counter % update_target_frequency == 0:
            #print("***********************")
            #print("UPDATING TARGET NETWORK")
            #print("update counter: {}".format(self.update_target_counter))
            #print("***********************")
            self.target_nn.load_state_dict(self.nn.state_dict())
        
        self.update_target_counter+=1

# %%
a=torch.randn([3,3])
print(a)
# Out:
# tensor([[-1.6049, -1.0776,  0.2535],
#         [ 1.6732, -1.1906, -0.7068],
#         [ 1.3573, -0.8768, -1.5517]])

# %%
a.clamp_(-1.0,1.0)
# Out:
# tensor([[-1.0000, -1.0000,  0.2535],
#         [ 1.0000, -1.0000, -0.7068],
#         [ 1.0000, -0.8768, -1.0000]])

# %%
a
# Out:
# tensor([[-1.0000, -1.0000,  0.2535],
#         [ 1.0000, -1.0000, -0.7068],
#         [ 1.0000, -0.8768, -1.0000]])

# %%
memory=ExperienceReplay(replay_memory_size)

# %%
qnet_agent=QNet_Agent()

# %%
seed_value=23
env.seed(seed_value)
torch.manual_seed(seed_value)
random.seed(seed_value)

# %%
# %%time

steps_total=np.full([num_episodes],-999,dtype=np.int32)
reward_total=np.full([num_episodes],-999,dtype=np.int32)

frames_total=0

solved_after = 0
solved = False

start_time = time.time()

for i_episode in range(num_episodes):
    
    state = env.reset()
    #for step in range(100):
    step=0
    reward_total[i_episode]=0
    
    while True:
        
        step+=1
        frames_total += 1
        
        epsilon=calculate_epsilon(frames_total)
        
        #action=env.action_space.sample()
        action=qnet_agent.select_action(state,epsilon)
        
        new_state, reward, done, info = env.step(action)
        memory.push(state, action, new_state,
                     reward, done)
        
        reward_total[i_episode]+=reward
        
        qnet_agent.optimize()
        
        state=new_state
        
        if done:
            steps_total[i_episode]=step
            
            if i_episode>100:
                mean_reward_100 = np.sum(reward_total[i_episode-100:i_episode])/100
            
                if (mean_reward_100 > score_to_solve and solved == False):
                    print("SOLVED! After %i episodes " % i_episode)
                    solved_after = i_episode
                    solved = True
            
            if (i_episode % report_interval == 0 and i_episode>1):
                print("**** Episode  {} **** ".format(i_episode))
                recent_avg_reward=np.average(reward_total[i_episode-report_interval:i_episode])
                print("Recent average reward: {}".format(recent_avg_reward))
                if i_episode>100:
                    print("Reward over last 100: {}".format(mean_reward_100))
                full_avg_so_far=np.average(reward_total[:i_episode])
                print("Average over all episodes so far: {}".format(full_avg_so_far))
                print("epsilon: {}".format(epsilon))
            
                #print("Episode {} finished after: {}".format(i_episode,step))
            break
            
if solved:
    print("Solved after %i episodes" % solved_after)
# Out:
# **** Episode  10 ****
# Recent average reward: 0.9
# Average over all episodes so far: 0.9
# epsilon: 0.8668487906593241
# **** Episode  20 ****
# Recent average reward: 0.4
# Average over all episodes so far: 0.65
# epsilon: 0.8418078484171984
# **** Episode  30 ****
# Recent average reward: 1.2
# Average over all episodes so far: 0.8333333333333334
# epsilon: 0.8134230906913473
# **** Episode  40 ****
# Recent average reward: 0.9
# Average over all episodes so far: 0.85
# epsilon: 0.7868920917963156
# **** Episode  50 ****
# Recent average reward: 1.7
# Average over all episodes so far: 1.02
# epsilon: 0.7535391811224643
# **** Episode  60 ****
# Recent average reward: 1.3
# Average over all episodes so far: 1.0666666666666667
# epsilon: 0.7280372606275634
# **** Episode  70 ****
# Recent average reward: 2.0
# Average over all episodes so far: 1.2
# epsilon: 0.6977060286799767
# **** Episode  80 ****
# Recent average reward: 1.2
# Average over all episodes so far: 1.2
# epsilon: 0.6702123084260773
# **** Episode  90 ****
# Recent average reward: 1.0
# Average over all episodes so far: 1.1777777777777778
# epsilon: 0.6488319704309432
# **** Episode  100 ****
# Recent average reward: 1.9
# Average over all episodes so far: 1.25
# epsilon: 0.6216140600329639
# **** Episode  110 ****
# Recent average reward: 1.7
# Reward over last 100: 1.33
# Average over all episodes so far: 1.290909090909091
# epsilon: 0.5976558354800475
# **** Episode  120 ****
# Recent average reward: 2.0
# Reward over last 100: 1.49
# Average over all episodes so far: 1.35
# epsilon: 0.5727871331241786
# **** Episode  130 ****
# Recent average reward: 1.1
# Reward over last 100: 1.48
# Average over all episodes so far: 1.3307692307692307
# epsilon: 0.5534520415916828
# **** Episode  140 ****
# Recent average reward: 1.5
# Reward over last 100: 1.54
# Average over all episodes so far: 1.3428571428571427
# epsilon: 0.5322160873818126
# **** Episode  150 ****
# Recent average reward: 2.2
# Reward over last 100: 1.59
# Average over all episodes so far: 1.4
# epsilon: 0.5090675526924574
# **** Episode  160 ****
# Recent average reward: 0.9
# Reward over last 100: 1.55
# Average over all episodes so far: 1.36875
# epsilon: 0.49282847324673157
# **** Episode  170 ****
# Recent average reward: 1.5
# Reward over last 100: 1.5
# Average over all episodes so far: 1.3764705882352941
# epsilon: 0.4748531097752364
# **** Episode  180 ****
# Recent average reward: 1.3
# Reward over last 100: 1.51
# Average over all episodes so far: 1.3722222222222222
# epsilon: 0.45817396094568885
# **** Episode  190 ****
# Recent average reward: 0.9
# Reward over last 100: 1.5
# Average over all episodes so far: 1.3473684210526315
# epsilon: 0.44234395463045767
# **** Episode  200 ****
# Recent average reward: 1.3
# Reward over last 100: 1.44
# Average over all episodes so far: 1.345
# epsilon: 0.4263230255758135
# **** Episode  210 ****
# Recent average reward: 1.5
# Reward over last 100: 1.42
# Average over all episodes so far: 1.3523809523809525
# epsilon: 0.4096709017036948
# **** Episode  220 ****
# Recent average reward: 1.0
# Reward over last 100: 1.32
# Average over all episodes so far: 1.3363636363636364
# epsilon: 0.39567747481814947
# **** Episode  230 ****
# Recent average reward: 1.4
# Reward over last 100: 1.35
# Average over all episodes so far: 1.3391304347826087
# epsilon: 0.3814006736487462
# **** Episode  240 ****
# Recent average reward: 1.1
# Reward over last 100: 1.31
# Average over all episodes so far: 1.3291666666666666
# epsilon: 0.36756653715279375
# **** Episode  250 ****
# Recent average reward: 1.9
# Reward over last 100: 1.28
# Average over all episodes so far: 1.352
# epsilon: 0.352236309780164
# **** Episode  260 ****
# Recent average reward: 1.3
# Reward over last 100: 1.32
# Average over all episodes so far: 1.35
# epsilon: 0.3401745528761019
# **** Episode  270 ****
# Recent average reward: 2.0
# Reward over last 100: 1.37
# Average over all episodes so far: 1.374074074074074
# epsilon: 0.3255702951549343
# **** Episode  280 ****
# Recent average reward: 1.4
# Reward over last 100: 1.38
# Average over all episodes so far: 1.375
# epsilon: 0.31397378457167724
# **** Episode  290 ****
# Recent average reward: 1.5
# Reward over last 100: 1.44
# Average over all episodes so far: 1.3793103448275863
# epsilon: 0.3028209888433456
# **** Episode  300 ****
# Recent average reward: 1.4
# Reward over last 100: 1.45
# Average over all episodes so far: 1.38
# epsilon: 0.2910693575014101
# **** Episode  310 ****
# Recent average reward: 1.2
# Reward over last 100: 1.42
# Average over all episodes so far: 1.3741935483870968
# epsilon: 0.2805295846986527
# **** Episode  320 ****
# Recent average reward: 1.6
# Reward over last 100: 1.48
# Average over all episodes so far: 1.38125
# epsilon: 0.27040066464366547
# **** Episode  330 ****
# Recent average reward: 0.7
# Reward over last 100: 1.41
# Average over all episodes so far: 1.3606060606060606
# epsilon: 0.26141914900495544
# **** Episode  340 ****
# Recent average reward: 1.0
# Reward over last 100: 1.4
# Average over all episodes so far: 1.35
# epsilon: 0.2526843099506403
# **** Episode  350 ****
# Recent average reward: 1.8
# Reward over last 100: 1.39
# Average over all episodes so far: 1.3628571428571428
# epsilon: 0.24222377697925085
# **** Episode  360 ****
# Recent average reward: 1.0
# Reward over last 100: 1.36
# Average over all episodes so far: 1.3527777777777779
# epsilon: 0.2340527382424709
# **** Episode  370 ****
# Recent average reward: 1.6
# Reward over last 100: 1.32
# Average over all episodes so far: 1.3594594594594596
# epsilon: 0.2253320946559473
# **** Episode  380 ****
# Recent average reward: 1.5
# Reward over last 100: 1.33
# Average over all episodes so far: 1.3631578947368421
# epsilon: 0.21666548316345474
# **** Episode  390 ****
# Recent average reward: 2.3
# Reward over last 100: 1.41
# Average over all episodes so far: 1.3871794871794871
# epsilon: 0.20676723122009613
# **** Episode  400 ****
# Recent average reward: 2.3
# Reward over last 100: 1.5
# Average over all episodes so far: 1.41
# epsilon: 0.1982595249466542
# **** Episode  410 ****
# Recent average reward: 1.4
# Reward over last 100: 1.52
# Average over all episodes so far: 1.4097560975609755
# epsilon: 0.19091394255905283
# **** Episode  420 ****
# Recent average reward: 1.9
# Reward over last 100: 1.55
# Average over all episodes so far: 1.4214285714285715
# epsilon: 0.18334805686056055
# **** Episode  430 ****
# Recent average reward: 1.4
# Reward over last 100: 1.62
# Average over all episodes so far: 1.4209302325581394
# epsilon: 0.1762946912112285
# **** Episode  440 ****
# Recent average reward: 1.9
# Reward over last 100: 1.71
# Average over all episodes so far: 1.4318181818181819
# epsilon: 0.16903772889605817
# **** Episode  450 ****
# Recent average reward: 1.8
# Reward over last 100: 1.71
# Average over all episodes so far: 1.44
# epsilon: 0.16240195370030536
# **** Episode  460 ****
# Recent average reward: 1.9
# Reward over last 100: 1.8
# Average over all episodes so far: 1.45
# epsilon: 0.1561950169179398
# **** Episode  470 ****
# Recent average reward: 2.1
# Reward over last 100: 1.85
# Average over all episodes so far: 1.4638297872340424
# epsilon: 0.15005867790970384
# **** Episode  480 ****
# Recent average reward: 0.6
# Reward over last 100: 1.76
# Average over all episodes so far: 1.4458333333333333
# epsilon: 0.1454823620841269
# **** Episode  490 ****
# Recent average reward: 1.4
# Reward over last 100: 1.67
# Average over all episodes so far: 1.4448979591836735
# epsilon: 0.14022991466637424
# **** Episode  500 ****
# Recent average reward: 2.1
# Reward over last 100: 1.65
# Average over all episodes so far: 1.458
# epsilon: 0.13470631123171678
# **** Episode  510 ****
# Recent average reward: 1.6
# Reward over last 100: 1.67
# Average over all episodes so far: 1.4607843137254901
# epsilon: 0.12971350892665023
# **** Episode  520 ****
# Recent average reward: 1.5
# Reward over last 100: 1.63
# Average over all episodes so far: 1.4615384615384615
# epsilon: 0.1247231073336479
# **** Episode  530 ****
# Recent average reward: 1.5
# Reward over last 100: 1.64
# Average over all episodes so far: 1.4622641509433962
# epsilon: 0.12012999741737805
# **** Episode  540 ****
# Recent average reward: 1.7
# Reward over last 100: 1.62
# Average over all episodes so far: 1.4666666666666666
# epsilon: 0.11520822300821594
# **** Episode  550 ****
# Recent average reward: 1.8
# Reward over last 100: 1.62
# Average over all episodes so far: 1.4727272727272727
# epsilon: 0.1107116479378728
# **** Episode  560 ****
# Recent average reward: 1.6
# Reward over last 100: 1.59
# Average over all episodes so far: 1.475
# epsilon: 0.10672012152098473
# **** Episode  570 ****
# Recent average reward: 1.4
# Reward over last 100: 1.52
# Average over all episodes so far: 1.4736842105263157
# epsilon: 0.10279766359769003
# **** Episode  580 ****
# Recent average reward: 1.5
# Reward over last 100: 1.61
# Average over all episodes so far: 1.4741379310344827
# epsilon: 0.09892038890404693
# **** Episode  590 ****
# Recent average reward: 1.0
# Reward over last 100: 1.57
# Average over all episodes so far: 1.4661016949152543
# epsilon: 0.09547136971458488
# **** Episode  600 ****
# Recent average reward: 1.2
# Reward over last 100: 1.48
# Average over all episodes so far: 1.4616666666666667
# epsilon: 0.09220872686980197
# **** Episode  610 ****
# Recent average reward: 1.4
# Reward over last 100: 1.46
# Average over all episodes so far: 1.460655737704918
# epsilon: 0.0888448078446117
# **** Episode  620 ****
# Recent average reward: 1.9
# Reward over last 100: 1.5
# Average over all episodes so far: 1.467741935483871
# epsilon: 0.08508354768948673
# **** Episode  630 ****
# Recent average reward: 1.1
# Reward over last 100: 1.46
# Average over all episodes so far: 1.4619047619047618
# epsilon: 0.0822289881127075
# **** Episode  640 ****
# Recent average reward: 1.6
# Reward over last 100: 1.45
# Average over all episodes so far: 1.4640625
# epsilon: 0.07938713410054835
# **** Episode  650 ****
# Recent average reward: 1.7
# Reward over last 100: 1.44
# Average over all episodes so far: 1.4676923076923076
# epsilon: 0.07631004955649259
# **** Episode  660 ****
# Recent average reward: 0.5
# Reward over last 100: 1.33
# Average over all episodes so far: 1.4530303030303031
# epsilon: 0.07388735552700167
# **** Episode  670 ****
# Recent average reward: 1.4
# Reward over last 100: 1.33
# Average over all episodes so far: 1.4522388059701492
# epsilon: 0.07125720423835645
# **** Episode  680 ****
# Recent average reward: 1.5
# Reward over last 100: 1.33
# Average over all episodes so far: 1.4529411764705882
# epsilon: 0.06869305830735295
# **** Episode  690 ****
# Recent average reward: 1.7
# Reward over last 100: 1.4
# Average over all episodes so far: 1.4565217391304348
# epsilon: 0.06601959065742993
# **** Episode  700 ****
# Recent average reward: 2.1
# Reward over last 100: 1.49
# Average over all episodes so far: 1.4657142857142857
# epsilon: 0.06354173604304836
# **** Episode  710 ****
# Recent average reward: 2.0
# Reward over last 100: 1.55
# Average over all episodes so far: 1.4732394366197183
# epsilon: 0.061344686903043094
# **** Episode  720 ****
# Recent average reward: 1.4
# Reward over last 100: 1.5
# Average over all episodes so far: 1.4722222222222223
# epsilon: 0.05931860842772176
# **** Episode  730 ****
# Recent average reward: 1.5
# Reward over last 100: 1.54
# Average over all episodes so far: 1.4726027397260273
# epsilon: 0.05720413349133926
# **** Episode  740 ****
# Recent average reward: 1.4
# Reward over last 100: 1.52
# Average over all episodes so far: 1.4716216216216216
# epsilon: 0.05538953004607495
# **** Episode  750 ****
# Recent average reward: 1.0
# Reward over last 100: 1.45
# Average over all episodes so far: 1.4653333333333334
# epsilon: 0.05360978111635587
# **** Episode  760 ****
# Recent average reward: 1.6
# Reward over last 100: 1.56
# Average over all episodes so far: 1.4671052631578947
# epsilon: 0.05184454586877851
# **** Episode  770 ****
# Recent average reward: 1.1
# Reward over last 100: 1.53
# Average over all episodes so far: 1.4623376623376623
# epsilon: 0.05022390468203818
# **** Episode  780 ****
# Recent average reward: 1.1
# Reward over last 100: 1.49
# Average over all episodes so far: 1.4576923076923076
# epsilon: 0.04863047461294963
# **** Episode  790 ****
# Recent average reward: 1.4
# Reward over last 100: 1.46
# Average over all episodes so far: 1.4569620253164557
# epsilon: 0.04703640925526045
# **** Episode  800 ****
# Recent average reward: 1.0
# Reward over last 100: 1.35
# Average over all episodes so far: 1.45125
# epsilon: 0.045634043632591416
# **** Episode  810 ****
# Recent average reward: 1.5
# Reward over last 100: 1.3
# Average over all episodes so far: 1.451851851851852
# epsilon: 0.04413357359150626
# **** Episode  820 ****
# Recent average reward: 1.8
# Reward over last 100: 1.34
# Average over all episodes so far: 1.4560975609756097
# epsilon: 0.042722452488353505
# **** Episode  830 ****
# Recent average reward: 0.6
# Reward over last 100: 1.25
# Average over all episodes so far: 1.4457831325301205
# epsilon: 0.04158876320975775
# **** Episode  840 ****
# Recent average reward: 1.6
# Reward over last 100: 1.27
# Average over all episodes so far: 1.4476190476190476
# epsilon: 0.0401673876793835
# **** Episode  850 ****
# Recent average reward: 2.4
# Reward over last 100: 1.41
# Average over all episodes so far: 1.4588235294117646
# epsilon: 0.038722519387142655
# **** Episode  860 ****
# Recent average reward: 1.3
# Reward over last 100: 1.38
# Average over all episodes so far: 1.4569767441860466
# epsilon: 0.03752683818410898
# **** Episode  870 ****
# Recent average reward: 2.3
# Reward over last 100: 1.5
# Average over all episodes so far: 1.4666666666666666
# epsilon: 0.03629664758284854
# **** Episode  880 ****
# Recent average reward: 1.9
# Reward over last 100: 1.58
# Average over all episodes so far: 1.4715909090909092
# epsilon: 0.035144557278453746
# **** Episode  890 ****
# Recent average reward: 1.7
# Reward over last 100: 1.61
# Average over all episodes so far: 1.4741573033707864
# epsilon: 0.0340540038447378
# **** Episode  900 ****
# Recent average reward: 2.0
# Reward over last 100: 1.71
# Average over all episodes so far: 1.48
# epsilon: 0.032933104149179784
# **** Episode  910 ****
# Recent average reward: 1.8
# Reward over last 100: 1.74
# Average over all episodes so far: 1.4835164835164836
# epsilon: 0.03187581005680316
# **** Episode  920 ****
# Recent average reward: 1.8
# Reward over last 100: 1.74
# Average over all episodes so far: 1.4869565217391305
# epsilon: 0.03091991262841883
# **** Episode  930 ****
# Recent average reward: 1.4
# Reward over last 100: 1.82
# Average over all episodes so far: 1.4860215053763441
# epsilon: 0.030033010996651004
# **** Episode  940 ****
# Recent average reward: 1.9
# Reward over last 100: 1.85
# Average over all episodes so far: 1.4904255319148936
# epsilon: 0.029173736705808424
# **** Episode  950 ****
# Recent average reward: 2.1
# Reward over last 100: 1.82
# Average over all episodes so far: 1.496842105263158
# epsilon: 0.0282941523071849
# **** Episode  960 ****
# Recent average reward: 2.1
# Reward over last 100: 1.9
# Average over all episodes so far: 1.503125
# epsilon: 0.027455267450512105
# **** Episode  970 ****
# Recent average reward: 1.7
# Reward over last 100: 1.84
# Average over all episodes so far: 1.5051546391752577
# epsilon: 0.026712241297484715
# **** Episode  980 ****
# Recent average reward: 1.4
# Reward over last 100: 1.79
# Average over all episodes so far: 1.5040816326530613
# epsilon: 0.02603865045579252
# **** Episode  990 ****
# Recent average reward: 1.4
# Reward over last 100: 1.76
# Average over all episodes so far: 1.503030303030303
# epsilon: 0.02539467180287734
# **** Episode  1000 ****
# Recent average reward: 1.0
# Reward over last 100: 1.66
# Average over all episodes so far: 1.498
# epsilon: 0.02478246177270159
# **** Episode  1010 ****
# Recent average reward: 1.3
# Reward over last 100: 1.61
# Average over all episodes so far: 1.496039603960396
# epsilon: 0.024173038501593806
# **** Episode  1020 ****
# Recent average reward: 1.8
# Reward over last 100: 1.61
# Average over all episodes so far: 1.4990196078431373
# epsilon: 0.023580860192531
# **** Episode  1030 ****
# Recent average reward: 1.4
# Reward over last 100: 1.61
# Average over all episodes so far: 1.4980582524271844
# epsilon: 0.023007439496325027
# **** Episode  1040 ****
# Recent average reward: 1.2
# Reward over last 100: 1.54
# Average over all episodes so far: 1.4951923076923077
# epsilon: 0.022516421006765736
# **** Episode  1050 ****
# Recent average reward: 1.8
# Reward over last 100: 1.51
# Average over all episodes so far: 1.4980952380952381
# epsilon: 0.02199297980952088
# **** Episode  1060 ****
# Recent average reward: 1.7
# Reward over last 100: 1.47
# Average over all episodes so far: 1.5
# epsilon: 0.021458839750235527
# **** Episode  1070 ****
# Recent average reward: 2.3
# Reward over last 100: 1.53
# Average over all episodes so far: 1.5074766355140188
# epsilon: 0.02092989245520657
# **** Episode  1080 ****
# Recent average reward: 1.6
# Reward over last 100: 1.55
# Average over all episodes so far: 1.5083333333333333
# epsilon: 0.020432662010081523
# **** Episode  1090 ****
# Recent average reward: 2.0
# Reward over last 100: 1.61
# Average over all episodes so far: 1.5128440366972478
# epsilon: 0.019984575605165533
# **** Episode  1100 ****
# Recent average reward: 0.7
# Reward over last 100: 1.58
# Average over all episodes so far: 1.5054545454545454
# epsilon: 0.01961708748620693
# **** Episode  1110 ****
# Recent average reward: 1.3
# Reward over last 100: 1.58
# Average over all episodes so far: 1.5036036036036036
# epsilon: 0.019215634673689787
# **** Episode  1120 ****
# Recent average reward: 1.7
# Reward over last 100: 1.57
# Average over all episodes so far: 1.5053571428571428
# epsilon: 0.018831999763226852
# **** Episode  1130 ****
# Recent average reward: 1.5
# Reward over last 100: 1.58
# Average over all episodes so far: 1.5053097345132744
# epsilon: 0.018459257998395418
# **** Episode  1140 ****
# Recent average reward: 1.4
# Reward over last 100: 1.6
# Average over all episodes so far: 1.5043859649122806
# epsilon: 0.01811538353824268
# **** Episode  1150 ****
# Recent average reward: 1.5
# Reward over last 100: 1.57
# Average over all episodes so far: 1.5043478260869565
# epsilon: 0.017753012385344925
# **** Episode  1160 ****
# Recent average reward: 1.4
# Reward over last 100: 1.54
# Average over all episodes so far: 1.5034482758620689
# epsilon: 0.017429075795179008
# **** Episode  1170 ****
# Recent average reward: 1.4
# Reward over last 100: 1.45
# Average over all episodes so far: 1.5025641025641026
# epsilon: 0.017126651314399315
# **** Episode  1180 ****
# Recent average reward: 1.4
# Reward over last 100: 1.43
# Average over all episodes so far: 1.5016949152542374
# epsilon: 0.016833803928744853
# **** Episode  1190 ****
# Recent average reward: 2.1
# Reward over last 100: 1.44
# Average over all episodes so far: 1.5067226890756302
# epsilon: 0.01653466747923287
# **** Episode  1200 ****
# Recent average reward: 1.0
# Reward over last 100: 1.47
# Average over all episodes so far: 1.5025
# epsilon: 0.01627630519584094
# **** Episode  1210 ****
# Recent average reward: 1.5
# Reward over last 100: 1.49
# Average over all episodes so far: 1.5024793388429751
# epsilon: 0.01600685587492599
# **** Episode  1220 ****
# Recent average reward: 0.9
# Reward over last 100: 1.41
# Average over all episodes so far: 1.4975409836065574
# epsilon: 0.015767746575472155
# **** Episode  1230 ****
# Recent average reward: 2.3
# Reward over last 100: 1.49
# Average over all episodes so far: 1.5040650406504066
# epsilon: 0.01550557636266615
# **** Episode  1240 ****
# Recent average reward: 1.6
# Reward over last 100: 1.51
# Average over all episodes so far: 1.5048387096774194
# epsilon: 0.015273116018760148
# **** Episode  1250 ****
# Recent average reward: 1.7
# Reward over last 100: 1.53
# Average over all episodes so far: 1.5064
# epsilon: 0.015053704115965499
# **** Episode  1260 ****
# Recent average reward: 1.3
# Reward over last 100: 1.52
# Average over all episodes so far: 1.5047619047619047
# epsilon: 0.014832874681273808
# **** Episode  1270 ****
# Recent average reward: 1.5
# Reward over last 100: 1.53
# Average over all episodes so far: 1.5047244094488188
# epsilon: 0.014624931049912275
# **** Episode  1280 ****
# Recent average reward: 2.7
# Reward over last 100: 1.66
# Average over all episodes so far: 1.5140625
# epsilon: 0.014391634418631234
# **** Episode  1290 ****
# Recent average reward: 1.9
# Reward over last 100: 1.64
# Average over all episodes so far: 1.5170542635658915
# epsilon: 0.014203096277976274
# **** Episode  1300 ****
# Recent average reward: 1.6
# Reward over last 100: 1.7
# Average over all episodes so far: 1.5176923076923077
# epsilon: 0.01403046382636303
# **** Episode  1310 ****
# Recent average reward: 1.1
# Reward over last 100: 1.66
# Average over all episodes so far: 1.5145038167938931
# epsilon: 0.013869717328822882
# **** Episode  1320 ****
# Recent average reward: 1.1
# Reward over last 100: 1.68
# Average over all episodes so far: 1.5113636363636365
# epsilon: 0.013719247871365865
# **** Episode  1330 ****
# Recent average reward: 2.5
# Reward over last 100: 1.7
# Average over all episodes so far: 1.518796992481203
# epsilon: 0.013553885324909823
# **** Episode  1340 ****
# Recent average reward: 2.2
# Reward over last 100: 1.76
# Average over all episodes so far: 1.5238805970149254
# epsilon: 0.013388073472749106
# **** Episode  1350 ****
# Recent average reward: 2.4
# Reward over last 100: 1.83
# Average over all episodes so far: 1.5303703703703704
# epsilon: 0.013232841470443542
# **** Episode  1360 ****
# Recent average reward: 1.7
# Reward over last 100: 1.87
# Average over all episodes so far: 1.5316176470588236
# epsilon: 0.013096651798269634
# **** Episode  1370 ****
# Recent average reward: 1.7
# Reward over last 100: 1.89
# Average over all episodes so far: 1.532846715328467
# epsilon: 0.01296246432064973
# **** Episode  1380 ****
# Recent average reward: 1.4
# Reward over last 100: 1.76
# Average over all episodes so far: 1.5318840579710145
# epsilon: 0.0128355657113593
# **** Episode  1390 ****
# Recent average reward: 1.7
# Reward over last 100: 1.74
# Average over all episodes so far: 1.533093525179856
# epsilon: 0.012716166368323994
# **** Episode  1400 ****
# Recent average reward: 1.9
# Reward over last 100: 1.77
# Average over all episodes so far: 1.5357142857142858
# epsilon: 0.012595142589068447
# **** Episode  1410 ****
# Recent average reward: 1.5
# Reward over last 100: 1.81
# Average over all episodes so far: 1.5354609929078014
# epsilon: 0.012475943319818664
# **** Episode  1420 ****
# Recent average reward: 1.3
# Reward over last 100: 1.83
# Average over all episodes so far: 1.5338028169014084
# epsilon: 0.012375437100161502
# **** Episode  1430 ****
# Recent average reward: 1.4
# Reward over last 100: 1.72
# Average over all episodes so far: 1.5328671328671328
# epsilon: 0.012272638435046213
# **** Episode  1440 ****
# Recent average reward: 1.5
# Reward over last 100: 1.65
# Average over all episodes so far: 1.5326388888888889
# epsilon: 0.012178510666290686
# **** Episode  1450 ****
# Recent average reward: 1.7
# Reward over last 100: 1.58
# Average over all episodes so far: 1.533793103448276
# epsilon: 0.012081443123942128
# **** Episode  1460 ****
# Recent average reward: 1.9
# Reward over last 100: 1.6
# Average over all episodes so far: 1.5363013698630137
# epsilon: 0.011984330271951952
# **** Episode  1470 ****
# Recent average reward: 2.2
# Reward over last 100: 1.65
# Average over all episodes so far: 1.5408163265306123
# epsilon: 0.011893906188643947
# **** Episode  1480 ****
# Recent average reward: 1.2
# Reward over last 100: 1.63
# Average over all episodes so far: 1.5385135135135135
# epsilon: 0.011818008120971231
# **** Episode  1490 ****
# Recent average reward: 1.4
# Reward over last 100: 1.6
# Average over all episodes so far: 1.5375838926174497
# epsilon: 0.011744802663999146
# **** Episode  1500 ****
# Recent average reward: 1.4
# Reward over last 100: 1.55
# Average over all episodes so far: 1.5366666666666666
# epsilon: 0.011670664518792945
# **** Episode  1510 ****
# Recent average reward: 1.2
# Reward over last 100: 1.52
# Average over all episodes so far: 1.5344370860927152
# epsilon: 0.01160047660453959
# **** Episode  1520 ****
# Recent average reward: 1.4
# Reward over last 100: 1.53
# Average over all episodes so far: 1.5335526315789474
# epsilon: 0.011532409698409206
# **** Episode  1530 ****
# Recent average reward: 1.4
# Reward over last 100: 1.53
# Average over all episodes so far: 1.5326797385620916
# epsilon: 0.011471086822610386
# **** Episode  1540 ****
# Recent average reward: 1.3
# Reward over last 100: 1.51
# Average over all episodes so far: 1.5311688311688312
# epsilon: 0.011406186545462983
# **** Episode  1550 ****
# Recent average reward: 1.9
# Reward over last 100: 1.53
# Average over all episodes so far: 1.533548387096774
# epsilon: 0.011345305954602673
# **** Episode  1560 ****
# Recent average reward: 0.9
# Reward over last 100: 1.43
# Average over all episodes so far: 1.5294871794871794
# epsilon: 0.011291522122515659
# **** Episode  1570 ****
# Recent average reward: 1.9
# Reward over last 100: 1.4
# Average over all episodes so far: 1.5318471337579618
# epsilon: 0.01123624858915695
# **** Episode  1580 ****
# Recent average reward: 0.8
# Reward over last 100: 1.36
# Average over all episodes so far: 1.5272151898734176
# epsilon: 0.011188891621665545
# **** Episode  1590 ****
# Recent average reward: 2.0
# Reward over last 100: 1.42
# Average over all episodes so far: 1.530188679245283
# epsilon: 0.01113412503880809
# **** Episode  1600 ****
# Recent average reward: 1.6
# Reward over last 100: 1.44
# Average over all episodes so far: 1.530625
# epsilon: 0.011083548672706223
# **** Episode  1610 ****
# Recent average reward: 2.8
# Reward over last 100: 1.6
# Average over all episodes so far: 1.5385093167701864
# epsilon: 0.011030229365833586
# **** Episode  1620 ****
# Recent average reward: 1.6
# Reward over last 100: 1.62
# Average over all episodes so far: 1.538888888888889
# epsilon: 0.010983990991182812
# **** Episode  1630 ****
# Recent average reward: 1.8
# Reward over last 100: 1.66
# Average over all episodes so far: 1.5404907975460123
# epsilon: 0.010936862701583434
# **** Episode  1640 ****
# Recent average reward: 2.4
# Reward over last 100: 1.77
# Average over all episodes so far: 1.545731707317073
# epsilon: 0.010893437820915385
# **** Episode  1650 ****
# Recent average reward: 1.6
# Reward over last 100: 1.74
# Average over all episodes so far: 1.5460606060606061
# epsilon: 0.010854483114522799
# **** Episode  1660 ****
# Recent average reward: 1.9
# Reward over last 100: 1.84
# Average over all episodes so far: 1.5481927710843373
# epsilon: 0.010817733706730578
# **** Episode  1670 ****
# Recent average reward: 2.4
# Reward over last 100: 1.89
# Average over all episodes so far: 1.5532934131736527
# epsilon: 0.010779191420572126
# **** Episode  1680 ****
# Recent average reward: 1.2
# Reward over last 100: 1.93
# Average over all episodes so far: 1.5511904761904762
# epsilon: 0.010748070138561092
# **** Episode  1690 ****
# Recent average reward: 1.5
# Reward over last 100: 1.88
# Average over all episodes so far: 1.550887573964497
# epsilon: 0.010716112116296398
# **** Episode  1700 ****
# Recent average reward: 1.5
# Reward over last 100: 1.87
# Average over all episodes so far: 1.5505882352941176
# epsilon: 0.010685519360648328
# **** Episode  1710 ****
# Recent average reward: 1.9
# Reward over last 100: 1.78
# Average over all episodes so far: 1.5526315789473684
# epsilon: 0.010653025867430358
# **** Episode  1720 ****
# Recent average reward: 1.5
# Reward over last 100: 1.77
# Average over all episodes so far: 1.552325581395349
# epsilon: 0.01062407886194639
# **** Episode  1730 ****
# Recent average reward: 2.0
# Reward over last 100: 1.79
# Average over all episodes so far: 1.5549132947976878
# epsilon: 0.010596713286974408
# **** Episode  1740 ****
# Recent average reward: 1.6
# Reward over last 100: 1.71
# Average over all episodes so far: 1.5551724137931036
# epsilon: 0.010570661800997798
# **** Episode  1750 ****
# Recent average reward: 1.3
# Reward over last 100: 1.68
# Average over all episodes so far: 1.5537142857142856
# epsilon: 0.01054817618552497
# **** Episode  1760 ****
# Recent average reward: 1.4
# Reward over last 100: 1.63
# Average over all episodes so far: 1.552840909090909
# epsilon: 0.010525356322401253
# **** Episode  1770 ****
# Recent average reward: 1.6
# Reward over last 100: 1.55
# Average over all episodes so far: 1.5531073446327683
# epsilon: 0.010503697929271756
# **** Episode  1780 ****
# Recent average reward: 1.4
# Reward over last 100: 1.57
# Average over all episodes so far: 1.5522471910112359
# epsilon: 0.010480523791728676
# **** Episode  1790 ****
# Recent average reward: 2.5
# Reward over last 100: 1.67
# Average over all episodes so far: 1.5575418994413408
# epsilon: 0.010459094807816401
# **** Episode  1800 ****
# Recent average reward: 1.5
# Reward over last 100: 1.67
# Average over all episodes so far: 1.5572222222222223
# epsilon: 0.010440344221085696
# **** Episode  1810 ****
# Recent average reward: 0.9
# Reward over last 100: 1.57
# Average over all episodes so far: 1.5535911602209944
# epsilon: 0.010422866591048234
# **** Episode  1820 ****
# Recent average reward: 2.0
# Reward over last 100: 1.62
# Average over all episodes so far: 1.556043956043956
# epsilon: 0.010403435547636463
# **** Episode  1830 ****
# Recent average reward: 1.9
# Reward over last 100: 1.61
# Average over all episodes so far: 1.5579234972677596
# epsilon: 0.010385251644061002
# **** Episode  1840 ****
# Recent average reward: 1.6
# Reward over last 100: 1.61
# Average over all episodes so far: 1.5581521739130435
# epsilon: 0.010368218584594226
# **** Episode  1850 ****
# Recent average reward: 2.6
# Reward over last 100: 1.74
# Average over all episodes so far: 1.5637837837837838
# epsilon: 0.010348569188127541
# **** Episode  1860 ****
# Recent average reward: 2.6
# Reward over last 100: 1.86
# Average over all episodes so far: 1.5693548387096774
# epsilon: 0.010331211366713167
# **** Episode  1870 ****
# Recent average reward: 1.7
# Reward over last 100: 1.87
# Average over all episodes so far: 1.570053475935829
# epsilon: 0.01031610572856997
# **** Episode  1880 ****
# Recent average reward: 2.9
# Reward over last 100: 2.02
# Average over all episodes so far: 1.577127659574468
# epsilon: 0.010300238374769718
# **** Episode  1890 ****
# Recent average reward: 1.4
# Reward over last 100: 1.91
# Average over all episodes so far: 1.5761904761904761
# epsilon: 0.01028746949254162
# **** Episode  1900 ****
# Recent average reward: 1.1
# Reward over last 100: 1.87
# Average over all episodes so far: 1.5736842105263158
# epsilon: 0.010276374475587423
# **** Episode  1910 ****
# Recent average reward: 1.7
# Reward over last 100: 1.95
# Average over all episodes so far: 1.57434554973822
# epsilon: 0.010264002016588072
# **** Episode  1920 ****
# Recent average reward: 1.4
# Reward over last 100: 1.89
# Average over all episodes so far: 1.5734375
# epsilon: 0.010252910770742746
# **** Episode  1930 ****
# Recent average reward: 1.2
# Reward over last 100: 1.82
# Average over all episodes so far: 1.5715025906735751
# epsilon: 0.010243188470554386
# **** Episode  1940 ****
# Recent average reward: 1.3
# Reward over last 100: 1.79
# Average over all episodes so far: 1.5701030927835051
# epsilon: 0.010233550129564282
# **** Episode  1950 ****
# Recent average reward: 1.1
# Reward over last 100: 1.64
# Average over all episodes so far: 1.5676923076923077
# epsilon: 0.010224882207232779
# **** Episode  1960 ****
# Recent average reward: 2.0
# Reward over last 100: 1.58
# Average over all episodes so far: 1.5698979591836735
# epsilon: 0.010214441450208797
# **** Episode  1970 ****
# Recent average reward: 1.0
# Reward over last 100: 1.51
# Average over all episodes so far: 1.567005076142132
# epsilon: 0.010205325544539472
# **** Episode  1980 ****
# Recent average reward: 2.0
# Reward over last 100: 1.42
# Average over all episodes so far: 1.5691919191919192
# epsilon: 0.010196008248339205
# **** Episode  1990 ****
# Recent average reward: 2.1
# Reward over last 100: 1.49
# Average over all episodes so far: 1.571859296482412
# epsilon: 0.010186986559830661
# **** Episode  2000 ****
# Recent average reward: 1.7
# Reward over last 100: 1.55
# Average over all episodes so far: 1.5725
# epsilon: 0.01017888743292996
# **** Episode  2010 ****
# Recent average reward: 2.2
# Reward over last 100: 1.6
# Average over all episodes so far: 1.5756218905472636
# epsilon: 0.010170265118305767
# **** Episode  2020 ****
# Recent average reward: 2.2
# Reward over last 100: 1.68
# Average over all episodes so far: 1.5787128712871288
# epsilon: 0.010162561556896304
# **** Episode  2030 ****
# Recent average reward: 2.0
# Reward over last 100: 1.76
# Average over all episodes so far: 1.5807881773399015
# epsilon: 0.010154998701847743
# **** Episode  2040 ****
# Recent average reward: 1.9
# Reward over last 100: 1.82
# Average over all episodes so far: 1.5823529411764705
# epsilon: 0.010148113184513197
# **** Episode  2050 ****
# Recent average reward: 1.6
# Reward over last 100: 1.87
# Average over all episodes so far: 1.582439024390244
# epsilon: 0.010141559021290252
# **** Episode  2060 ****
# Recent average reward: 2.2
# Reward over last 100: 1.89
# Average over all episodes so far: 1.5854368932038836
# epsilon: 0.010134859937748894
# **** Episode  2070 ****
# Recent average reward: 2.2
# Reward over last 100: 2.01
# Average over all episodes so far: 1.5884057971014494
# epsilon: 0.010128799475532371
# **** Episode  2080 ****
# Recent average reward: 1.4
# Reward over last 100: 1.95
# Average over all episodes so far: 1.5875
# epsilon: 0.010123573576735025
# **** Episode  2090 ****
# Recent average reward: 2.2
# Reward over last 100: 1.96
# Average over all episodes so far: 1.5904306220095694
# epsilon: 0.010117699732520238
# **** Episode  2100 ****
# Recent average reward: 1.2
# Reward over last 100: 1.91
# Average over all episodes so far: 1.5885714285714285
# epsilon: 0.010113152531151807
# **** Episode  2110 ****
# Recent average reward: 1.4
# Reward over last 100: 1.83
# Average over all episodes so far: 1.5876777251184835
# epsilon: 0.010108158391609341
# **** Episode  2120 ****
# Recent average reward: 1.4
# Reward over last 100: 1.75
# Average over all episodes so far: 1.5867924528301887
# epsilon: 0.01010377620875429
# **** Episode  2130 ****
# Recent average reward: 1.7
# Reward over last 100: 1.72
# Average over all episodes so far: 1.587323943661972
# epsilon: 0.010099309053658967
# **** Episode  2140 ****
# Recent average reward: 2.3
# Reward over last 100: 1.76
# Average over all episodes so far: 1.5906542056074766
# epsilon: 0.010094325988140477
# **** Episode  2150 ****
# Recent average reward: 0.9
# Reward over last 100: 1.69
# Average over all episodes so far: 1.5874418604651164
# epsilon: 0.010090533209727524
# **** Episode  2160 ****
# Recent average reward: 1.8
# Reward over last 100: 1.65
# Average over all episodes so far: 1.588425925925926
# epsilon: 0.010086889460489258
# **** Episode  2170 ****
# Recent average reward: 0.9
# Reward over last 100: 1.52
# Average over all episodes so far: 1.5852534562211982
# epsilon: 0.010083785230229401
# **** Episode  2180 ****
# Recent average reward: 1.9
# Reward over last 100: 1.57
# Average over all episodes so far: 1.586697247706422
# epsilon: 0.010080154557671198
# **** Episode  2190 ****
# Recent average reward: 1.5
# Reward over last 100: 1.5
# Average over all episodes so far: 1.5863013698630137
# epsilon: 0.010076865469288682
# **** Episode  2200 ****
# Recent average reward: 1.7
# Reward over last 100: 1.55
# Average over all episodes so far: 1.586818181818182
# epsilon: 0.010073525827695308
# **** Episode  2210 ****
# Recent average reward: 1.5
# Reward over last 100: 1.56
# Average over all episodes so far: 1.5864253393665158
# epsilon: 0.010070435453813888
# **** Episode  2220 ****
# Recent average reward: 1.6
# Reward over last 100: 1.58
# Average over all episodes so far: 1.5864864864864865
# epsilon: 0.010067041829247189
# **** Episode  2230 ****
# Recent average reward: 1.1
# Reward over last 100: 1.52
# Average over all episodes so far: 1.584304932735426
# epsilon: 0.010064578190259861
# **** Episode  2240 ****
# Recent average reward: 1.2
# Reward over last 100: 1.41
# Average over all episodes so far: 1.5825892857142858
# epsilon: 0.010061743996104761
# **** Episode  2250 ****
# Recent average reward: 2.5
# Reward over last 100: 1.57
# Average over all episodes so far: 1.5866666666666667
# epsilon: 0.010058705695049368
# **** Episode  2260 ****
# Recent average reward: 1.7
# Reward over last 100: 1.56
# Average over all episodes so far: 1.5871681415929204
# epsilon: 0.010056107906684108
# **** Episode  2270 ****
# Recent average reward: 1.5
# Reward over last 100: 1.62
# Average over all episodes so far: 1.586784140969163
# epsilon: 0.010053570403480873
# **** Episode  2280 ****
# Recent average reward: 1.8
# Reward over last 100: 1.61
# Average over all episodes so far: 1.587719298245614
# epsilon: 0.010051278765658894
# **** Episode  2290 ****
# Recent average reward: 1.4
# Reward over last 100: 1.6
# Average over all episodes so far: 1.5868995633187772
# epsilon: 0.010048967496521425
# **** Episode  2300 ****
# Recent average reward: 1.3
# Reward over last 100: 1.56
# Average over all episodes so far: 1.5856521739130436
# epsilon: 0.010046991970265918
# **** Episode  2310 ****
# Recent average reward: 1.9
# Reward over last 100: 1.6
# Average over all episodes so far: 1.587012987012987
# epsilon: 0.010045006941872596
# **** Episode  2320 ****
# Recent average reward: 1.3
# Reward over last 100: 1.57
# Average over all episodes so far: 1.5857758620689655
# epsilon: 0.010043224036531495
# **** Episode  2330 ****
# Recent average reward: 1.3
# Reward over last 100: 1.59
# Average over all episodes so far: 1.584549356223176
# epsilon: 0.010041270862467155
# **** Episode  2340 ****
# Recent average reward: 1.5
# Reward over last 100: 1.62
# Average over all episodes so far: 1.584188034188034
# epsilon: 0.010039578131928798
# **** Episode  2350 ****
# Recent average reward: 1.0
# Reward over last 100: 1.47
# Average over all episodes so far: 1.5817021276595744
# epsilon: 0.010037932062917362
# **** Episode  2360 ****
# Recent average reward: 1.8
# Reward over last 100: 1.48
# Average over all episodes so far: 1.5826271186440677
# epsilon: 0.010036319570989794
# **** Episode  2370 ****
# Recent average reward: 1.8
# Reward over last 100: 1.51
# Average over all episodes so far: 1.5835443037974684
# epsilon: 0.010034656896593153
# **** Episode  2380 ****
# Recent average reward: 1.7
# Reward over last 100: 1.5
# Average over all episodes so far: 1.584033613445378
# epsilon: 0.010033256716333906
# **** Episode  2390 ****
# Recent average reward: 1.2
# Reward over last 100: 1.48
# Average over all episodes so far: 1.5824267782426777
# epsilon: 0.010031930981383046
# **** Episode  2400 ****
# Recent average reward: 1.7
# Reward over last 100: 1.52
# Average over all episodes so far: 1.5829166666666667
# epsilon: 0.010030598064083391
# **** Episode  2410 ****
# Recent average reward: 1.4
# Reward over last 100: 1.47
# Average over all episodes so far: 1.5821576763485476
# epsilon: 0.010029320201273399
# **** Episode  2420 ****
# Recent average reward: 1.6
# Reward over last 100: 1.5
# Average over all episodes so far: 1.5822314049586776
# epsilon: 0.010028078291736388
# **** Episode  2430 ****
# Recent average reward: 2.0
# Reward over last 100: 1.57
# Average over all episodes so far: 1.5839506172839506
# epsilon: 0.010026721720637424
# **** Episode  2440 ****
# Recent average reward: 1.6
# Reward over last 100: 1.58
# Average over all episodes so far: 1.584016393442623
# epsilon: 0.010025681136696083
# **** Episode  2450 ****
# Recent average reward: 1.6
# Reward over last 100: 1.64
# Average over all episodes so far: 1.5840816326530611
# epsilon: 0.010024646545328171
# **** Episode  2460 ****
# Recent average reward: 1.3
# Reward over last 100: 1.59
# Average over all episodes so far: 1.5829268292682928
# epsilon: 0.010023549315205297
# **** Episode  2470 ****
# Recent average reward: 1.7
# Reward over last 100: 1.58
# Average over all episodes so far: 1.5834008097165992
# epsilon: 0.010022496882447204
# **** Episode  2480 ****
# Recent average reward: 1.8
# Reward over last 100: 1.59
# Average over all episodes so far: 1.584274193548387
# epsilon: 0.010021486755922232
# **** Episode  2490 ****
# Recent average reward: 1.4
# Reward over last 100: 1.61
# Average over all episodes so far: 1.5835341365461848
# epsilon: 0.010020590231034864
# **** Episode  2500 ****
# Recent average reward: 1.8
# Reward over last 100: 1.62
# Average over all episodes so far: 1.5844
# epsilon: 0.01001963388189081
# **** Episode  2510 ****
# Recent average reward: 2.1
# Reward over last 100: 1.69
# Average over all episodes so far: 1.5864541832669323
# epsilon: 0.01001876731403833
# **** Episode  2520 ****
# Recent average reward: 1.1
# Reward over last 100: 1.64
# Average over all episodes so far: 1.5845238095238094
# epsilon: 0.010018019179919959
# **** Episode  2530 ****
# Recent average reward: 2.0
# Reward over last 100: 1.64
# Average over all episodes so far: 1.5861660079051383
# epsilon: 0.010017232837862513
# **** Episode  2540 ****
# Recent average reward: 1.7
# Reward over last 100: 1.65
# Average over all episodes so far: 1.5866141732283465
# epsilon: 0.01001644919832051
# **** Episode  2550 ****
# Recent average reward: 2.0
# Reward over last 100: 1.69
# Average over all episodes so far: 1.588235294117647
# epsilon: 0.0100156839318889
# **** Episode  2560 ****
# Recent average reward: 1.6
# Reward over last 100: 1.72
# Average over all episodes so far: 1.58828125
# epsilon: 0.01001495875491848
# **** Episode  2570 ****
# Recent average reward: 1.5
# Reward over last 100: 1.7
# Average over all episodes so far: 1.5879377431906614
# epsilon: 0.01001433833531637
# **** Episode  2580 ****
# Recent average reward: 2.1
# Reward over last 100: 1.73
# Average over all episodes so far: 1.589922480620155
# epsilon: 0.010013693164157574
# **** Episode  2590 ****
# Recent average reward: 1.7
# Reward over last 100: 1.76
# Average over all episodes so far: 1.5903474903474903
# epsilon: 0.010013096129672513
# **** Episode  2600 ****
# Recent average reward: 1.5
# Reward over last 100: 1.73
# Average over all episodes so far: 1.59
# epsilon: 0.010012503851810838
# **** Episode  2610 ****
# Recent average reward: 2.4
# Reward over last 100: 1.76
# Average over all episodes so far: 1.5931034482758621
# epsilon: 0.01001192642756678
# **** Episode  2620 ****
# Recent average reward: 2.1
# Reward over last 100: 1.86
# Average over all episodes so far: 1.5950381679389314
# epsilon: 0.010011361117065716
# **** Episode  2630 ****
# Recent average reward: 2.2
# Reward over last 100: 1.88
# Average over all episodes so far: 1.5973384030418252
# epsilon: 0.010010835380387988
# **** Episode  2640 ****
# Recent average reward: 0.8
# Reward over last 100: 1.79
# Average over all episodes so far: 1.5943181818181817
# epsilon: 0.01001044075336979
# **** Episode  2650 ****
# Recent average reward: 2.3
# Reward over last 100: 1.82
# Average over all episodes so far: 1.5969811320754717
# epsilon: 0.01000992857280063
# **** Episode  2660 ****
# Recent average reward: 2.0
# Reward over last 100: 1.86
# Average over all episodes so far: 1.5984962406015037
# epsilon: 0.010009479359414828
# **** Episode  2670 ****
# Recent average reward: 1.8
# Reward over last 100: 1.89
# Average over all episodes so far: 1.599250936329588
# epsilon: 0.010009078388888735
# **** Episode  2680 ****
# Recent average reward: 1.5
# Reward over last 100: 1.83
# Average over all episodes so far: 1.5988805970149254
# epsilon: 0.010008677701953413
# **** Episode  2690 ****
# Recent average reward: 3.0
# Reward over last 100: 1.96
# Average over all episodes so far: 1.604089219330855
# epsilon: 0.010008217423702117
# **** Episode  2700 ****
# Recent average reward: 2.3
# Reward over last 100: 2.04
# Average over all episodes so far: 1.6066666666666667
# epsilon: 0.010007848455349817
# **** Episode  2710 ****
# Recent average reward: 1.4
# Reward over last 100: 1.94
# Average over all episodes so far: 1.6059040590405904
# epsilon: 0.010007512713672414
# **** Episode  2720 ****
# Recent average reward: 2.0
# Reward over last 100: 1.93
# Average over all episodes so far: 1.6073529411764707
# epsilon: 0.010007189608658774
# **** Episode  2730 ****
# Recent average reward: 2.3
# Reward over last 100: 1.94
# Average over all episodes so far: 1.60989010989011
# epsilon: 0.010006841566608284
# **** Episode  2740 ****
# Recent average reward: 1.5
# Reward over last 100: 2.01
# Average over all episodes so far: 1.6094890510948905
# epsilon: 0.010006538166285725
# **** Episode  2750 ****
# Recent average reward: 1.6
# Reward over last 100: 1.94
# Average over all episodes so far: 1.6094545454545455
# epsilon: 0.01000626361028496
# **** Episode  2760 ****
# Recent average reward: 1.8
# Reward over last 100: 1.92
# Average over all episodes so far: 1.6101449275362318
# epsilon: 0.010005983925206668
# **** Episode  2770 ****
# Recent average reward: 2.0
# Reward over last 100: 1.94
# Average over all episodes so far: 1.6115523465703971
# epsilon: 0.010005704850293604
# **** Episode  2780 ****
# Recent average reward: 2.5
# Reward over last 100: 2.04
# Average over all episodes so far: 1.614748201438849
# epsilon: 0.010005431073116175
# **** Episode  2790 ****
# Recent average reward: 1.6
# Reward over last 100: 1.9
# Average over all episodes so far: 1.614695340501792
# epsilon: 0.010005193961712403
# **** Episode  2800 ****
# Recent average reward: 1.2
# Reward over last 100: 1.79
# Average over all episodes so far: 1.6132142857142857
# epsilon: 0.010004991201896126
# **** Episode  2810 ****
# Recent average reward: 2.6
# Reward over last 100: 1.91
# Average over all episodes so far: 1.6167259786476869
# epsilon: 0.010004725704931683
# **** Episode  2820 ****
# Recent average reward: 2.0
# Reward over last 100: 1.91
# Average over all episodes so far: 1.6180851063829786
# epsilon: 0.010004524543742621
# **** Episode  2830 ****
# Recent average reward: 1.7
# Reward over last 100: 1.85
# Average over all episodes so far: 1.6183745583038869
# epsilon: 0.010004325019900775
# **** Episode  2840 ****
# Recent average reward: 2.2
# Reward over last 100: 1.92
# Average over all episodes so far: 1.6204225352112676
# epsilon: 0.010004130823334513
# **** Episode  2850 ****
# Recent average reward: 2.0
# Reward over last 100: 1.96
# Average over all episodes so far: 1.6217543859649122
# epsilon: 0.01000393494435886
# **** Episode  2860 ****
# Recent average reward: 1.2
# Reward over last 100: 1.9
# Average over all episodes so far: 1.6202797202797203
# epsilon: 0.01000378867646986
# **** Episode  2870 ****
# Recent average reward: 1.9
# Reward over last 100: 1.89
# Average over all episodes so far: 1.6212543554006968
# epsilon: 0.01000360894953227
# **** Episode  2880 ****
# Recent average reward: 1.4
# Reward over last 100: 1.78
# Average over all episodes so far: 1.620486111111111
# epsilon: 0.01000345504935326
# **** Episode  2890 ****
# Recent average reward: 1.4
# Reward over last 100: 1.76
# Average over all episodes so far: 1.6197231833910035
# epsilon: 0.010003319176605272
# **** Episode  2900 ****
# Recent average reward: 1.7
# Reward over last 100: 1.81
# Average over all episodes so far: 1.62
# epsilon: 0.010003176743900982
# **** Episode  2910 ****
# Recent average reward: 1.4
# Reward over last 100: 1.69
# Average over all episodes so far: 1.6192439862542956
# epsilon: 0.010003052792488401
# **** Episode  2920 ****
# Recent average reward: 0.8
# Reward over last 100: 1.57
# Average over all episodes so far: 1.6164383561643836
# epsilon: 0.010002927991642357
# **** Episode  2930 ****
# Recent average reward: 2.0
# Reward over last 100: 1.6
# Average over all episodes so far: 1.6177474402730376
# epsilon: 0.010002797697455929
# **** Episode  2940 ****
# Recent average reward: 1.6
# Reward over last 100: 1.54
# Average over all episodes so far: 1.617687074829932
# epsilon: 0.01000267592935304
# **** Episode  2950 ****
# Recent average reward: 2.1
# Reward over last 100: 1.55
# Average over all episodes so far: 1.619322033898305
# epsilon: 0.010002549294723023
# **** Episode  2960 ****
# Recent average reward: 2.0
# Reward over last 100: 1.63
# Average over all episodes so far: 1.620608108108108
# epsilon: 0.010002436095960463
# **** Episode  2970 ****
# Recent average reward: 1.1
# Reward over last 100: 1.55
# Average over all episodes so far: 1.6188552188552188
# epsilon: 0.010002339826407311
# **** Episode  2980 ****
# Recent average reward: 1.5
# Reward over last 100: 1.56
# Average over all episodes so far: 1.618456375838926
# epsilon: 0.01000224206371195
# **** Episode  2990 ****
# Recent average reward: 1.5
# Reward over last 100: 1.57
# Average over all episodes so far: 1.6180602006688962
# epsilon: 0.010002145423012814
# **** Episode  3000 ****
# Recent average reward: 2.1
# Reward over last 100: 1.61
# Average over all episodes so far: 1.6196666666666666
# epsilon: 0.010002050731875158
# **** Episode  3010 ****
# Recent average reward: 2.2
# Reward over last 100: 1.69
# Average over all episodes so far: 1.6215946843853821
# epsilon: 0.010001952590088431
# **** Episode  3020 ****
# Recent average reward: 1.5
# Reward over last 100: 1.76
# Average over all episodes so far: 1.6211920529801325
# epsilon: 0.010001872541767138
# **** Episode  3030 ****
# Recent average reward: 2.2
# Reward over last 100: 1.78
# Average over all episodes so far: 1.6231023102310231
# epsilon: 0.010001780077213454
# **** Episode  3040 ****
# ...
# epsilon: 0.01
# **** Episode  48340 ****
# Recent average reward: 1.1
# Reward over last 100: 1.53
# Average over all episodes so far: 1.746131568059578
# epsilon: 0.01
# **** Episode  48350 ****
# Recent average reward: 1.2
# Reward over last 100: 1.57
# Average over all episodes so far: 1.746018614270941
# epsilon: 0.01
# **** Episode  48360 ****
# Recent average reward: 1.0
# Reward over last 100: 1.53
# Average over all episodes so far: 1.7458643507030605
# epsilon: 0.01
# **** Episode  48370 ****
# Recent average reward: 1.3
# Reward over last 100: 1.53
# Average over all episodes so far: 1.7457721728344016
# epsilon: 0.01
# **** Episode  48380 ****
# Recent average reward: 1.5
# Reward over last 100: 1.58
# Average over all episodes so far: 1.7457213724679619
# epsilon: 0.01
# **** Episode  48390 ****
# Recent average reward: 1.4
# Reward over last 100: 1.58
# Average over all episodes so far: 1.7456499276710065
# epsilon: 0.01
# **** Episode  48400 ****
# Recent average reward: 1.2
# Reward over last 100: 1.46
# Average over all episodes so far: 1.7455371900826446
# epsilon: 0.01
# **** Episode  48410 ****
# Recent average reward: 1.9
# Reward over last 100: 1.54
# Average over all episodes so far: 1.7455690972939475
# epsilon: 0.01
# **** Episode  48420 ****
# Recent average reward: 1.4
# Reward over last 100: 1.44
# Average over all episodes so far: 1.745497728211483
# epsilon: 0.01
# **** Episode  48430 ****
# Recent average reward: 1.7
# Reward over last 100: 1.37
# Average over all episodes so far: 1.7454883336774727
# epsilon: 0.01
# **** Episode  48440 ****
# Recent average reward: 2.3
# Reward over last 100: 1.49
# Average over all episodes so far: 1.7456028075970274
# epsilon: 0.01
# **** Episode  48450 ****
# Recent average reward: 1.4
# Reward over last 100: 1.51
# Average over all episodes so far: 1.7455314757481941
# epsilon: 0.01
# **** Episode  48460 ****
# Recent average reward: 1.7
# Reward over last 100: 1.58
# Average over all episodes so far: 1.7455220800660338
# epsilon: 0.01
# **** Episode  48470 ****
# Recent average reward: 1.4
# Reward over last 100: 1.59
# Average over all episodes so far: 1.7454507943057562
# epsilon: 0.01
# **** Episode  48480 ****
# Recent average reward: 1.6
# Reward over last 100: 1.6
# Average over all episodes so far: 1.745420792079208
# epsilon: 0.01
# **** Episode  48490 ****
# Recent average reward: 1.8
# Reward over last 100: 1.64
# Average over all episodes so far: 1.7454320478449166
# epsilon: 0.01
# **** Episode  48500 ****
# Recent average reward: 1.4
# Reward over last 100: 1.66
# Average over all episodes so far: 1.745360824742268
# epsilon: 0.01
# **** Episode  48510 ****
# Recent average reward: 1.3
# Reward over last 100: 1.6
# Average over all episodes so far: 1.7452690166975882
# epsilon: 0.01
# **** Episode  48520 ****
# Recent average reward: 1.4
# Reward over last 100: 1.6
# Average over all episodes so far: 1.7451978565539983
# epsilon: 0.01
# **** Episode  48530 ****
# Recent average reward: 1.8
# Reward over last 100: 1.61
# Average over all episodes so far: 1.7452091489800123
# epsilon: 0.01
# **** Episode  48540 ****
# Recent average reward: 1.4
# Reward over last 100: 1.52
# Average over all episodes so far: 1.7451380304903172
# epsilon: 0.01
# **** Episode  48550 ****
# Recent average reward: 2.5
# Reward over last 100: 1.63
# Average over all episodes so far: 1.7452935118434603
# epsilon: 0.01
# **** Episode  48560 ****
# Recent average reward: 1.6
# Reward over last 100: 1.62
# Average over all episodes so far: 1.7452635914332784
# epsilon: 0.01
# **** Episode  48570 ****
# Recent average reward: 2.3
# Reward over last 100: 1.71
# Average over all episodes so far: 1.7453778052295656
# epsilon: 0.01
# **** Episode  48580 ****
# Recent average reward: 1.5
# Reward over last 100: 1.7
# Average over all episodes so far: 1.745327295183203
# epsilon: 0.01
# **** Episode  48590 ****
# Recent average reward: 1.8
# Reward over last 100: 1.7
# Average over all episodes so far: 1.745338547026137
# epsilon: 0.01
# **** Episode  48600 ****
# Recent average reward: 1.9
# Reward over last 100: 1.75
# Average over all episodes so far: 1.7453703703703705
# epsilon: 0.01
# **** Episode  48610 ****
# Recent average reward: 2.3
# Reward over last 100: 1.85
# Average over all episodes so far: 1.7454844682164163
# epsilon: 0.01
# **** Episode  48620 ****
# Recent average reward: 1.3
# Reward over last 100: 1.84
# Average over all episodes so far: 1.745392842451666
# epsilon: 0.01
# **** Episode  48630 ****
# Recent average reward: 1.4
# Reward over last 100: 1.8
# Average over all episodes so far: 1.7453218178079375
# epsilon: 0.01
# **** Episode  48640 ****
# Recent average reward: 0.8
# Reward over last 100: 1.74
# Average over all episodes so far: 1.7451274671052632
# epsilon: 0.01
# **** Episode  48650 ****
# Recent average reward: 2.1
# Reward over last 100: 1.7
# Average over all episodes so far: 1.7452004110996917
# epsilon: 0.01
# **** Episode  48660 ****
# Recent average reward: 1.6
# Reward over last 100: 1.7
# Average over all episodes so far: 1.7451705713111385
# epsilon: 0.01
# **** Episode  48670 ****
# Recent average reward: 2.1
# Reward over last 100: 1.68
# Average over all episodes so far: 1.7452434764742142
# epsilon: 0.01
# **** Episode  48680 ****
# Recent average reward: 1.8
# Reward over last 100: 1.71
# Average over all episodes so far: 1.74525472473295
# epsilon: 0.01
# **** Episode  48690 ****
# Recent average reward: 1.8
# Reward over last 100: 1.71
# Average over all episodes so far: 1.7452659683713287
# epsilon: 0.01
# **** Episode  48700 ****
# Recent average reward: 1.6
# Reward over last 100: 1.68
# Average over all episodes so far: 1.7452361396303901
# epsilon: 0.01
# **** Episode  48710 ****
# Recent average reward: 1.9
# Reward over last 100: 1.64
# Average over all episodes so far: 1.7452679121330323
# epsilon: 0.01
# **** Episode  48720 ****
# Recent average reward: 1.5
# Reward over last 100: 1.66
# Average over all episodes so far: 1.7452175697865353
# epsilon: 0.01
# **** Episode  48730 ****
# Recent average reward: 2.2
# Reward over last 100: 1.74
# Average over all episodes so far: 1.7453108967781654
# epsilon: 0.01
# **** Episode  48740 ****
# Recent average reward: 2.0
# Reward over last 100: 1.86
# Average over all episodes so far: 1.745363151415675
# epsilon: 0.01
# **** Episode  48750 ****
# Recent average reward: 2.1
# Reward over last 100: 1.86
# Average over all episodes so far: 1.7454358974358974
# epsilon: 0.01
# **** Episode  48760 ****
# Recent average reward: 1.4
# Reward over last 100: 1.84
# Average over all episodes so far: 1.7453650533223954
# epsilon: 0.01
# **** Episode  48770 ****
# Recent average reward: 1.7
# Reward over last 100: 1.8
# Average over all episodes so far: 1.7453557514865696
# epsilon: 0.01
# **** Episode  48780 ****
# Recent average reward: 1.6
# Reward over last 100: 1.78
# Average over all episodes so far: 1.7453259532595327
# epsilon: 0.01
# **** Episode  48790 ****
# Recent average reward: 2.1
# Reward over last 100: 1.81
# Average over all episodes so far: 1.7453986472637835
# epsilon: 0.01
# **** Episode  48800 ****
# Recent average reward: 2.5
# Reward over last 100: 1.9
# Average over all episodes so far: 1.7455532786885246
# epsilon: 0.01
# **** Episode  48810 ****
# Recent average reward: 2.2
# Reward over last 100: 1.93
# Average over all episodes so far: 1.7456463839377176
# epsilon: 0.01
# **** Episode  48820 ****
# Recent average reward: 2.1
# Reward over last 100: 1.99
# Average over all episodes so far: 1.7457189676362146
# epsilon: 0.01
# **** Episode  48830 ****
# Recent average reward: 1.7
# Reward over last 100: 1.94
# Average over all episodes so far: 1.7457096047511775
# epsilon: 0.01
# **** Episode  48840 ****
# Recent average reward: 1.5
# Reward over last 100: 1.89
# Average over all episodes so far: 1.7456592956592956
# epsilon: 0.01
# **** Episode  48850 ****
# Recent average reward: 2.0
# Reward over last 100: 1.88
# Average over all episodes so far: 1.7457113613101332
# epsilon: 0.01
# **** Episode  48860 ****
# Recent average reward: 1.7
# Reward over last 100: 1.91
# Average over all episodes so far: 1.745702005730659
# epsilon: 0.01
# **** Episode  48870 ****
# Recent average reward: 2.1
# Reward over last 100: 1.95
# Average over all episodes so far: 1.7457745037855534
# epsilon: 0.01
# **** Episode  48880 ****
# Recent average reward: 1.9
# Reward over last 100: 1.98
# Average over all episodes so far: 1.7458060556464812
# epsilon: 0.01
# **** Episode  48890 ****
# Recent average reward: 1.9
# Reward over last 100: 1.96
# Average over all episodes so far: 1.7458375946001228
# epsilon: 0.01
# **** Episode  48900 ****
# Recent average reward: 1.3
# Reward over last 100: 1.84
# Average over all episodes so far: 1.7457464212678937
# epsilon: 0.01
# **** Episode  48910 ****
# Recent average reward: 1.8
# Reward over last 100: 1.8
# Average over all episodes so far: 1.7457575138008588
# epsilon: 0.01
# **** Episode  48920 ****
# Recent average reward: 1.5
# Reward over last 100: 1.74
# Average over all episodes so far: 1.7457072771872444
# epsilon: 0.01
# **** Episode  48930 ****
# Recent average reward: 1.8
# Reward over last 100: 1.75
# Average over all episodes so far: 1.7457183731861843
# epsilon: 0.01
# **** Episode  48940 ****
# Recent average reward: 1.3
# Reward over last 100: 1.73
# Average over all episodes so far: 1.7456272987331427
# epsilon: 0.01
# **** Episode  48950 ****
# Recent average reward: 1.1
# Reward over last 100: 1.64
# Average over all episodes so far: 1.7454954034729315
# epsilon: 0.01
# **** Episode  48960 ****
# Recent average reward: 2.0
# Reward over last 100: 1.67
# Average over all episodes so far: 1.745547385620915
# epsilon: 0.01
# **** Episode  48970 ****
# Recent average reward: 2.0
# Reward over last 100: 1.66
# Average over all episodes so far: 1.7455993465386972
# epsilon: 0.01
# **** Episode  48980 ****
# Recent average reward: 1.8
# Reward over last 100: 1.65
# Average over all episodes so far: 1.7456104532462229
# epsilon: 0.01
# **** Episode  48990 ****
# Recent average reward: 1.8
# Reward over last 100: 1.64
# Average over all episodes so far: 1.7456215554194734
# epsilon: 0.01
# **** Episode  49000 ****
# Recent average reward: 2.0
# Reward over last 100: 1.71
# Average over all episodes so far: 1.7456734693877551
# epsilon: 0.01
# **** Episode  49010 ****
# Recent average reward: 1.7
# Reward over last 100: 1.7
# Average over all episodes so far: 1.745664150173434
# epsilon: 0.01
# **** Episode  49020 ****
# Recent average reward: 1.9
# Reward over last 100: 1.74
# Average over all episodes so far: 1.7456956344349246
# epsilon: 0.01
# **** Episode  49030 ****
# Recent average reward: 1.2
# Reward over last 100: 1.68
# Average over all episodes so far: 1.7455843361207424
# epsilon: 0.01
# **** Episode  49040 ****
# Recent average reward: 2.2
# Reward over last 100: 1.77
# Average over all episodes so far: 1.7456769983686786
# epsilon: 0.01
# **** Episode  49050 ****
# Recent average reward: 1.5
# Reward over last 100: 1.81
# Average over all episodes so far: 1.7456269113149847
# epsilon: 0.01
# **** Episode  49060 ****
# Recent average reward: 1.4
# Reward over last 100: 1.75
# Average over all episodes so far: 1.745556461475744
# epsilon: 0.01
# **** Episode  49070 ****
# Recent average reward: 1.5
# Reward over last 100: 1.7
# Average over all episodes so far: 1.7455064194008558
# epsilon: 0.01
# **** Episode  49080 ****
# Recent average reward: 1.6
# Reward over last 100: 1.68
# Average over all episodes so far: 1.7454767726161369
# epsilon: 0.01
# **** Episode  49090 ****
# Recent average reward: 2.0
# Reward over last 100: 1.7
# Average over all episodes so far: 1.745528620900387
# epsilon: 0.01
# **** Episode  49100 ****
# Recent average reward: 2.1
# Reward over last 100: 1.71
# Average over all episodes so far: 1.7456008146639512
# epsilon: 0.01
# **** Episode  49110 ****
# Recent average reward: 2.4
# Reward over last 100: 1.78
# Average over all episodes so far: 1.7457340663815923
# epsilon: 0.01
# **** Episode  49120 ****
# Recent average reward: 1.3
# Reward over last 100: 1.72
# Average over all episodes so far: 1.74564332247557
# epsilon: 0.01
# **** Episode  49130 ****
# Recent average reward: 1.5
# Reward over last 100: 1.75
# Average over all episodes so far: 1.745593323834724
# epsilon: 0.01
# **** Episode  49140 ****
# Recent average reward: 1.8
# Reward over last 100: 1.71
# Average over all episodes so far: 1.7456043956043956
# epsilon: 0.01
# **** Episode  49150 ****
# Recent average reward: 2.0
# Reward over last 100: 1.76
# Average over all episodes so far: 1.7456561546286877
# epsilon: 0.01
# **** Episode  49160 ****
# Recent average reward: 1.6
# Reward over last 100: 1.78
# Average over all episodes so far: 1.745626525630594
# epsilon: 0.01
# **** Episode  49170 ****
# Recent average reward: 2.2
# Reward over last 100: 1.85
# Average over all episodes so far: 1.7457189343095383
# epsilon: 0.01
# **** Episode  49180 ****
# Recent average reward: 1.5
# Reward over last 100: 1.84
# Average over all episodes so far: 1.7456689711264741
# epsilon: 0.01
# **** Episode  49190 ****
# Recent average reward: 1.6
# Reward over last 100: 1.8
# Average over all episodes so far: 1.7456393575930067
# epsilon: 0.01
# **** Episode  49200 ****
# Recent average reward: 1.7
# Reward over last 100: 1.76
# Average over all episodes so far: 1.745630081300813
# epsilon: 0.01
# **** Episode  49210 ****
# Recent average reward: 1.7
# Reward over last 100: 1.69
# Average over all episodes so far: 1.7456208087787035
# epsilon: 0.01
# **** Episode  49220 ****
# Recent average reward: 2.5
# Reward over last 100: 1.81
# Average over all episodes so far: 1.745774075579033
# epsilon: 0.01
# **** Episode  49230 ****
# Recent average reward: 1.3
# Reward over last 100: 1.79
# Average over all episodes so far: 1.7456835263050985
# epsilon: 0.01
# **** Episode  49240 ****
# Recent average reward: 2.4
# Reward over last 100: 1.85
# Average over all episodes so far: 1.7458164094232331
# epsilon: 0.01
# **** Episode  49250 ****
# Recent average reward: 2.2
# Reward over last 100: 1.87
# Average over all episodes so far: 1.7459086294416244
# epsilon: 0.01
# **** Episode  49260 ****
# Recent average reward: 1.3
# Reward over last 100: 1.84
# Average over all episodes so far: 1.745818107998376
# epsilon: 0.01
# **** Episode  49270 ****
# Recent average reward: 1.5
# Reward over last 100: 1.77
# Average over all episodes so far: 1.7457682159529124
# epsilon: 0.01
# **** Episode  49280 ****
# Recent average reward: 2.2
# Reward over last 100: 1.84
# Average over all episodes so far: 1.7458603896103897
# epsilon: 0.01
# **** Episode  49290 ****
# Recent average reward: 1.8
# Reward over last 100: 1.86
# Average over all episodes so far: 1.7458713735037532
# epsilon: 0.01
# **** Episode  49300 ****
# Recent average reward: 1.8
# Reward over last 100: 1.87
# Average over all episodes so far: 1.7458823529411764
# epsilon: 0.01
# **** Episode  49310 ****
# Recent average reward: 1.4
# Reward over last 100: 1.84
# Average over all episodes so far: 1.7458122084769823
# epsilon: 0.01
# **** Episode  49320 ****
# Recent average reward: 1.6
# Reward over last 100: 1.75
# Average over all episodes so far: 1.7457826439578263
# epsilon: 0.01
# **** Episode  49330 ****
# Recent average reward: 2.0
# Reward over last 100: 1.82
# Average over all episodes so far: 1.745834177984999
# epsilon: 0.01
# **** Episode  49340 ****
# Recent average reward: 1.6
# Reward over last 100: 1.74
# Average over all episodes so far: 1.7458046209971625
# epsilon: 0.01
# **** Episode  49350 ****
# Recent average reward: 1.7
# Reward over last 100: 1.69
# Average over all episodes so far: 1.7457953394123606
# epsilon: 0.01
# **** Episode  49360 ****
# Recent average reward: 1.3
# Reward over last 100: 1.69
# Average over all episodes so far: 1.7457050243111831
# epsilon: 0.01
# **** Episode  49370 ****
# Recent average reward: 1.4
# Reward over last 100: 1.68
# Average over all episodes so far: 1.7456350010127608
# epsilon: 0.01
# **** Episode  49380 ****
# Recent average reward: 2.0
# Reward over last 100: 1.66
# Average over all episodes so far: 1.7456865127582017
# epsilon: 0.01
# **** Episode  49390 ****
# Recent average reward: 1.7
# Reward over last 100: 1.65
# Average over all episodes so far: 1.745677262603766
# epsilon: 0.01
# **** Episode  49400 ****
# Recent average reward: 1.5
# Reward over last 100: 1.62
# Average over all episodes so far: 1.7456275303643725
# epsilon: 0.01
# **** Episode  49410 ****
# Recent average reward: 1.8
# Reward over last 100: 1.66
# Average over all episodes so far: 1.7456385347095729
# epsilon: 0.01
# **** Episode  49420 ****
# Recent average reward: 1.1
# Reward over last 100: 1.61
# Average over all episodes so far: 1.7455078915418858
# epsilon: 0.01

# %%
plt.figure(2,figsize=[12,5])
plt.title("Score at end of episode")
plt.plot(reward_total[:frames_total])
plt.show()

# %%
print("Average number of steps: {}". format(np.average(steps_total[:frames_total])))

# %%
print("Average number of steps=reward: {}". format(np.average(steps_total)))
print("Average reward in last 100 episodes: {}". format(np.average(reward_total[frames_total-100:frames_total])))

# %% [markdown]
# plt.figure(1,figsize=[12,5])
# plt.title("Rewards")
# plt.bar(torch.arange(len(rewards_total)), rewards_total,alpha=0.6, color='green')
# #plt.plot(rewards_total)
# plt.show()

# %%
plt.figure(2,figsize=[12,5])
plt.title("Steps to finish episode")
plt.plot(steps_total[:frames_total])
plt.show()
