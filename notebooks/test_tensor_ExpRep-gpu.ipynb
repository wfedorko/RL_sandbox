# %%
import sys  
sys.path.insert(0, '../')
sys.path.insert(0, '../baselines')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from datetime import datetime

# %%
import random

# %%
class CONFIG:
    pass

config=CONFIG()

config.use_cuda=True
config.device="cuda:4"

config.env_id="PongNoFrameskip-v4"
config.exp_name=config.env_id+"-"+datetime.now().strftime("%Y_%m_%d_%H:%M:%S")
config.result_path=%pwd 
config.result_path+= '/../results/'
print('result path is'+config.result_path)

config.learning_rate = 0.0001
config.num_episodes = 1000
config.gamma=0.99
#gamma=0.85
config.egreedy = 0.9
config.egreedy_final = 0.01
config.egreedy_decay = 10000

config.report_interval=10

config.score_to_solve = 18.0

config.hidden_layer_size=512

config.replay_memory_size=100000
#config.replay_memory_size=100

config.batch_size=32

config.update_target_frequency = 5000

config.clip_error=True
config.normalize_image=True

config.double_dqn=True

config.save_movies=True

config.save_model_frequency=10000

config.resume_previous_training=False

config.memory_device=config.device
#config.memory_device='cpu'
# Out:
# result path is/home/wfedorko/RL_sandbox/notebooks/../results/

# %%
from utils.engine import Engine

# %%
my_engine=Engine(config)
# Out:
# devices: compute: cuda:4; Experience Replay: cuda:4
# Directory  /home/wfedorko/RL_sandbox/notebooks/../results//PongNoFrameskip-v4-2020_04_27_17:07:34  Created
# will save movies
# creating state memory with shape: [100000, 1, 84, 84]

# %%
# %load_ext line_profiler

# %%
from agents.QNet_Agent import QNet_Agent
from models.models import SimpleCNNDuelingAllMean
from utils.ExperienceReplay import ExperienceReplay

# %%
# %lprun -f Engine.train_agent -f QNet_Agent.optimize -f SimpleCNNDuelingAllMean.forward -f ExperienceReplay.push -f ExperienceReplay.sample my_engine.train_agent()
# Out:
# training the agent
# **** Episode  10 ****
# Recent average reward: -20.5
# Average over all episodes so far: -20.5
# epsilon: 0.3477214565641336
# Elapsed time:  00:02:04
# **** Episode  20 ****
# Recent average reward: -20.2
# Average over all episodes so far: -20.35
# epsilon: 0.13483857000638916
# Elapsed time:  00:04:21
# **** Episode  30 ****
# Recent average reward: -20.5
# Average over all episodes so far: -20.4
# epsilon: 0.06031591671448777
# Elapsed time:  00:06:27
# **** Episode  40 ****
# Recent average reward: -20.2
# Average over all episodes so far: -20.35
# epsilon: 0.02862717363565547
# Elapsed time:  00:08:47
# **** Episode  50 ****
# Recent average reward: -20.1
# Average over all episodes so far: -20.3
# epsilon: 0.017494140606405098
# Elapsed time:  00:10:52
# **** Episode  60 ****
# Recent average reward: -18.0
# Average over all episodes so far: -19.916666666666668
# epsilon: 0.011968204021515843
# Elapsed time:  00:13:57
# **** Episode  70 ****
# Recent average reward: -18.0
# Average over all episodes so far: -19.642857142857142
# epsilon: 0.010372962076058109
# Elapsed time:  00:17:42
# **** Episode  80 ****
# Recent average reward: -15.9
# Average over all episodes so far: -19.175
# epsilon: 0.010056496389966245
# Elapsed time:  00:22:03
# **** Episode  90 ****
# Recent average reward: -15.7
# Average over all episodes so far: -18.788888888888888
# epsilon: 0.010006323524594482
# Elapsed time:  00:27:07
# **** Episode  100 ****
# Recent average reward: -16.0
# Average over all episodes so far: -18.51
# epsilon: 0.010000663634814945
# Elapsed time:  00:32:19
# **** Episode  110 ****
# Recent average reward: -14.0
# Reward over last 100: -17.86
# Average over all episodes so far: -18.1
# epsilon: 0.01000006140750265
# Elapsed time:  00:37:48
# **** Episode  120 ****
# Recent average reward: -17.6
# Reward over last 100: -17.6
# Average over all episodes so far: -18.058333333333334
# epsilon: 0.010000008706170445
# Elapsed time:  00:42:24
# **** Episode  130 ****
# Recent average reward: -15.3
# Reward over last 100: -17.08
# Average over all episodes so far: -17.846153846153847
# epsilon: 0.010000000864271798
# Elapsed time:  00:47:43
# **** Episode  140 ****
# Recent average reward: -15.9
# Reward over last 100: -16.65
# Average over all episodes so far: -17.707142857142856
# epsilon: 0.010000000089620788
# Elapsed time:  00:52:53
# **** Episode  150 ****
# Recent average reward: -14.0
# Reward over last 100: -16.04
# Average over all episodes so far: -17.46
# epsilon: 0.01000000000728114
# Elapsed time:  00:58:36
# **** Episode  160 ****
# Recent average reward: -15.8
# Reward over last 100: -15.82
# Average over all episodes so far: -17.35625
# epsilon: 0.01000000000077576
# Elapsed time:  01:03:42
# **** Episode  170 ****
# Recent average reward: -13.2
# Reward over last 100: -15.34
# Average over all episodes so far: -17.111764705882354
# epsilon: 0.01000000000007292
# Elapsed time:  01:09:06
# **** Episode  180 ****
# Recent average reward: -12.2
# Reward over last 100: -14.97
# Average over all episodes so far: -16.83888888888889
# epsilon: 0.010000000000004821
# Elapsed time:  01:15:18
# **** Episode  190 ****
# Recent average reward: -11.5
# Reward over last 100: -14.55
# Average over all episodes so far: -16.557894736842105
# epsilon: 0.010000000000000286
# Elapsed time:  01:21:46
# **** Episode  200 ****
# Recent average reward: -8.5
# Reward over last 100: -13.8
# Average over all episodes so far: -16.155
# epsilon: 0.010000000000000014
# Elapsed time:  01:28:37
# **** Episode  210 ****
# Recent average reward: -6.0
# Reward over last 100: -13.0
# Average over all episodes so far: -15.67142857142857
# epsilon: 0.01
# Elapsed time:  01:35:56
# **** Episode  220 ****
# Recent average reward: -5.1
# Reward over last 100: -11.75
# Average over all episodes so far: -15.190909090909091
# epsilon: 0.01
# Elapsed time:  01:42:55
# **** Episode  230 ****
# Recent average reward: 4.7
# Reward over last 100: -9.75
# Average over all episodes so far: -14.326086956521738
# epsilon: 0.01
# Elapsed time:  01:49:48
# **** Episode  250 ****
# Recent average reward: 10.5
# Reward over last 100: -5.27
# Average over all episodes so far: -12.584
# epsilon: 0.01
# Elapsed time:  02:03:38
# **** Episode  260 ****
# Recent average reward: 12.7
# Reward over last 100: -2.42
# Average over all episodes so far: -11.611538461538462
# epsilon: 0.01
# Elapsed time:  02:08:50
# **** Episode  270 ****
# Recent average reward: 17.7
# Reward over last 100: 0.67
# Average over all episodes so far: -10.525925925925925
# epsilon: 0.01
# Elapsed time:  02:13:25
# **** Episode  280 ****
# Recent average reward: 16.5
# Reward over last 100: 3.54
# Average over all episodes so far: -9.560714285714285
# epsilon: 0.01
# Elapsed time:  02:18:11
# **** Episode  290 ****
# Recent average reward: 15.9
# Reward over last 100: 6.28
# Average over all episodes so far: -8.682758620689656
# epsilon: 0.01
# Elapsed time:  02:23:03
# **** Episode  300 ****
# Recent average reward: 17.0
# Reward over last 100: 8.83
# Average over all episodes so far: -7.826666666666667
# epsilon: 0.01
# Elapsed time:  02:27:37
# **** Episode  310 ****
# Recent average reward: 18.5
# Reward over last 100: 11.28
# Average over all episodes so far: -6.97741935483871
# epsilon: 0.01
# Elapsed time:  02:31:46
# **** Episode  320 ****
# Recent average reward: 18.0
# Reward over last 100: 13.59
# Average over all episodes so far: -6.196875
# epsilon: 0.01
# Elapsed time:  02:36:01
# **** Episode  330 ****
# Recent average reward: 18.3
# Reward over last 100: 14.95
# Average over all episodes so far: -5.454545454545454
# epsilon: 0.01
# Elapsed time:  02:40:11
# **** Episode  340 ****
# Recent average reward: 16.9
# Reward over last 100: 16.2
# Average over all episodes so far: -4.797058823529412
# epsilon: 0.01
# Elapsed time:  02:44:54
# **** Episode  350 ****
# Recent average reward: 17.1
# Reward over last 100: 16.86
# Average over all episodes so far: -4.171428571428572
# epsilon: 0.01
# Elapsed time:  02:49:12
# **** Episode  360 ****
# Recent average reward: 19.3
# Reward over last 100: 17.52
# Average over all episodes so far: -3.5194444444444444
# epsilon: 0.01
# Elapsed time:  02:53:19
# SOLVED! After 380 episodes
# **** Episode  380 ****
# Recent average reward: 19.3
# Reward over last 100: 18.01
# Average over all episodes so far: -2.305263157894737
# epsilon: 0.01
# Elapsed time:  03:01:03
# **** Episode  390 ****
# Recent average reward: 19.5
# Reward over last 100: 18.37
# Average over all episodes so far: -1.7461538461538462
# epsilon: 0.01
# Elapsed time:  03:05:05
# **** Episode  400 ****
# Recent average reward: 17.5
# Reward over last 100: 18.42
# Average over all episodes so far: -1.265
# epsilon: 0.01
# Elapsed time:  03:09:20
# **** Episode  410 ****
# Recent average reward: 17.3
# Reward over last 100: 18.3
# Average over all episodes so far: -0.8121951219512196
# epsilon: 0.01
# Elapsed time:  03:13:28
# **** Episode  420 ****
# Recent average reward: 19.2
# Reward over last 100: 18.42
# Average over all episodes so far: -0.3357142857142857
# epsilon: 0.01
# Elapsed time:  03:17:16
# **** Episode  430 ****
# Recent average reward: 17.8
# Reward over last 100: 18.37
# Average over all episodes so far: 0.08604651162790698
# epsilon: 0.01
# Elapsed time:  03:21:39
# **** Episode  440 ****
# Recent average reward: 18.5
# Reward over last 100: 18.53
# Average over all episodes so far: 0.5045454545454545
# epsilon: 0.01
# Elapsed time:  03:25:49
# **** Episode  450 ****
# Recent average reward: 19.2
# Reward over last 100: 18.74
# Average over all episodes so far: 0.92
# epsilon: 0.01
# Elapsed time:  03:29:52
# **** Episode  460 ****
# Recent average reward: 18.5
# Reward over last 100: 18.66
# Average over all episodes so far: 1.3021739130434782
# epsilon: 0.01
# Elapsed time:  03:34:04
# **** Episode  470 ****
# Recent average reward: 19.0
# Reward over last 100: 18.58
# Average over all episodes so far: 1.6787234042553192
# epsilon: 0.01
# Elapsed time:  03:38:01
# **** Episode  480 ****
# Recent average reward: 19.3
# Reward over last 100: 18.58
# Average over all episodes so far: 2.0458333333333334
# epsilon: 0.01
# Elapsed time:  03:42:01
# **** Episode  490 ****
# Recent average reward: 19.9
# Reward over last 100: 18.62
# Average over all episodes so far: 2.410204081632653
# epsilon: 0.01
# Elapsed time:  03:45:51
# **** Episode  500 ****
# Recent average reward: 19.0
# Reward over last 100: 18.77
# Average over all episodes so far: 2.742
# epsilon: 0.01
# Elapsed time:  03:49:46
# **** Episode  510 ****
# Recent average reward: 19.2
# Reward over last 100: 18.96
# Average over all episodes so far: 3.0647058823529414
# epsilon: 0.01
# Elapsed time:  03:53:37
# **** Episode  520 ****
# Recent average reward: 19.4
# Reward over last 100: 18.98
# Average over all episodes so far: 3.378846153846154
# epsilon: 0.01
# Elapsed time:  03:57:32
# **** Episode  530 ****
# Recent average reward: 18.7
# Reward over last 100: 19.07
# Average over all episodes so far: 3.667924528301887
# epsilon: 0.01
# Elapsed time:  04:01:36
# **** Episode  540 ****
# Recent average reward: 20.4
# Reward over last 100: 19.26
# Average over all episodes so far: 3.977777777777778
# epsilon: 0.01
# Elapsed time:  04:05:20
# **** Episode  550 ****
# Recent average reward: 19.9
# Reward over last 100: 19.33
# Average over all episodes so far: 4.2672727272727276
# epsilon: 0.01
# Elapsed time:  04:09:13
# **** Episode  560 ****
# Recent average reward: 19.7
# Reward over last 100: 19.45
# Average over all episodes so far: 4.542857142857143
# epsilon: 0.01
# Elapsed time:  04:13:04
# **** Episode  570 ****
# Recent average reward: 19.7
# Reward over last 100: 19.52
# Average over all episodes so far: 4.8087719298245615
# epsilon: 0.01
# Elapsed time:  04:16:54
# **** Episode  580 ****
# Recent average reward: 18.7
# Reward over last 100: 19.46
# Average over all episodes so far: 5.048275862068966
# epsilon: 0.01
# Elapsed time:  04:21:06
# **** Episode  590 ****
# Recent average reward: 18.9
# Reward over last 100: 19.36
# Average over all episodes so far: 5.283050847457627
# epsilon: 0.01
# Elapsed time:  04:25:06
# **** Episode  600 ****
# Recent average reward: 18.5
# Reward over last 100: 19.31
# Average over all episodes so far: 5.503333333333333
# epsilon: 0.01
# Elapsed time:  04:29:17
# **** Episode  610 ****
# Recent average reward: 17.8
# Reward over last 100: 19.17
# Average over all episodes so far: 5.704918032786885
# epsilon: 0.01
# Elapsed time:  04:33:29
# **** Episode  620 ****
# Recent average reward: 17.9
# Reward over last 100: 19.02
# Average over all episodes so far: 5.901612903225806
# epsilon: 0.01
# Elapsed time:  04:37:46
# **** Episode  630 ****
# Recent average reward: 18.9
# Reward over last 100: 19.04
# Average over all episodes so far: 6.1079365079365076
# epsilon: 0.01
# Elapsed time:  04:41:40
# **** Episode  640 ****
# Recent average reward: 19.1
# Reward over last 100: 18.91
# Average over all episodes so far: 6.3109375
# epsilon: 0.01
# Elapsed time:  04:45:49
# **** Episode  650 ****
# Recent average reward: 18.3
# Reward over last 100: 18.75
# Average over all episodes so far: 6.495384615384616
# epsilon: 0.01
# Elapsed time:  04:49:46
# **** Episode  660 ****
# Recent average reward: 19.1
# Reward over last 100: 18.69
# Average over all episodes so far: 6.6863636363636365
# epsilon: 0.01
# Elapsed time:  04:53:48
# **** Episode  670 ****
# Recent average reward: 19.9
# Reward over last 100: 18.71
# Average over all episodes so far: 6.883582089552239
# epsilon: 0.01
# Elapsed time:  04:57:41
# **** Episode  680 ****
# Recent average reward: 19.7
# Reward over last 100: 18.81
# Average over all episodes so far: 7.072058823529412
# epsilon: 0.01
# Elapsed time:  05:01:33
# **** Episode  690 ****
# Recent average reward: 20.5
# Reward over last 100: 18.97
# Average over all episodes so far: 7.266666666666667
# epsilon: 0.01
# Elapsed time:  05:05:18
# **** Episode  700 ****
# Recent average reward: 19.4
# Reward over last 100: 19.06
# Average over all episodes so far: 7.44
# epsilon: 0.01
# Elapsed time:  05:09:10
# **** Episode  710 ****
# Recent average reward: 20.5
# Reward over last 100: 19.33
# Average over all episodes so far: 7.623943661971831
# epsilon: 0.01
# Elapsed time:  05:12:57
# **** Episode  720 ****
# Recent average reward: 19.5
# Reward over last 100: 19.49
# Average over all episodes so far: 7.788888888888889
# epsilon: 0.01
# Elapsed time:  05:16:47
# **** Episode  730 ****
# Recent average reward: 19.1
# Reward over last 100: 19.51
# Average over all episodes so far: 7.943835616438356
# epsilon: 0.01
# Elapsed time:  05:20:43
# **** Episode  740 ****
# Recent average reward: 19.0
# Reward over last 100: 19.5
# Average over all episodes so far: 8.093243243243244
# epsilon: 0.01
# Elapsed time:  05:24:39
# **** Episode  750 ****
# Recent average reward: 19.0
# Reward over last 100: 19.57
# Average over all episodes so far: 8.238666666666667
# epsilon: 0.01
# Elapsed time:  05:28:52
# **** Episode  760 ****
# Recent average reward: 19.9
# Reward over last 100: 19.65
# Average over all episodes so far: 8.392105263157895
# epsilon: 0.01
# Elapsed time:  05:32:38
# **** Episode  770 ****
# Recent average reward: 19.1
# Reward over last 100: 19.57
# Average over all episodes so far: 8.53116883116883
# epsilon: 0.01
# Elapsed time:  05:36:32
# **** Episode  780 ****
# Recent average reward: 19.8
# Reward over last 100: 19.58
# Average over all episodes so far: 8.675641025641026
# epsilon: 0.01
# Elapsed time:  05:40:22
# **** Episode  790 ****
# Recent average reward: 19.8
# Reward over last 100: 19.51
# Average over all episodes so far: 8.816455696202532
# epsilon: 0.01
# Elapsed time:  05:44:13
# **** Episode  800 ****
# Recent average reward: 19.7
# Reward over last 100: 19.54
# Average over all episodes so far: 8.9525
# epsilon: 0.01
# Elapsed time:  05:48:08
# **** Episode  810 ****
# Recent average reward: 19.8
# Reward over last 100: 19.47
# Average over all episodes so far: 9.08641975308642
# epsilon: 0.01
# Elapsed time:  05:51:56
# **** Episode  820 ****
# Recent average reward: 19.7
# Reward over last 100: 19.49
# Average over all episodes so far: 9.215853658536586
# epsilon: 0.01
# Elapsed time:  05:55:54
# **** Episode  830 ****
# Recent average reward: 19.6
# Reward over last 100: 19.54
# Average over all episodes so far: 9.340963855421688
# epsilon: 0.01
# Elapsed time:  05:59:40
# **** Episode  840 ****
# Recent average reward: 19.7
# Reward over last 100: 19.61
# Average over all episodes so far: 9.464285714285714
# epsilon: 0.01
# Elapsed time:  06:03:31
# **** Episode  850 ****
# Recent average reward: 19.1
# Reward over last 100: 19.62
# Average over all episodes so far: 9.57764705882353
# epsilon: 0.01
# Elapsed time:  06:07:26
# **** Episode  860 ****
# Recent average reward: 19.5
# Reward over last 100: 19.58
# Average over all episodes so far: 9.693023255813953
# epsilon: 0.01
# Elapsed time:  06:11:21
# **** Episode  870 ****
# Recent average reward: 20.0
# Reward over last 100: 19.67
# Average over all episodes so far: 9.811494252873564
# epsilon: 0.01
# Elapsed time:  06:15:01
# **** Episode  880 ****
# Recent average reward: 20.0
# Reward over last 100: 19.69
# Average over all episodes so far: 9.927272727272728
# epsilon: 0.01
# Elapsed time:  06:18:50
# **** Episode  890 ****
# Recent average reward: 18.9
# Reward over last 100: 19.6
# Average over all episodes so far: 10.02808988764045
# epsilon: 0.01
# Elapsed time:  06:22:41
# **** Episode  900 ****
# Recent average reward: 20.0
# Reward over last 100: 19.63
# Average over all episodes so far: 10.13888888888889
# epsilon: 0.01
# Elapsed time:  06:26:25
# **** Episode  910 ****
# Recent average reward: 19.2
# Reward over last 100: 19.57
# Average over all episodes so far: 10.238461538461538
# epsilon: 0.01
# Elapsed time:  06:30:11
# **** Episode  920 ****
# Recent average reward: 20.0
# Reward over last 100: 19.6
# Average over all episodes so far: 10.344565217391304
# epsilon: 0.01
# Elapsed time:  06:33:54
# **** Episode  930 ****
# Recent average reward: 17.8
# Reward over last 100: 19.42
# Average over all episodes so far: 10.424731182795698
# epsilon: 0.01
# Elapsed time:  06:37:53
# **** Episode  940 ****
# Recent average reward: 19.6
# Reward over last 100: 19.41
# Average over all episodes so far: 10.522340425531915
# epsilon: 0.01
# Elapsed time:  06:41:34
# **** Episode  950 ****
# Recent average reward: 19.8
# Reward over last 100: 19.48
# Average over all episodes so far: 10.62
# epsilon: 0.01
# Elapsed time:  06:45:15
# **** Episode  960 ****
# Recent average reward: 19.6
# Reward over last 100: 19.49
# Average over all episodes so far: 10.713541666666666
# epsilon: 0.01
# Elapsed time:  06:48:53
# **** Episode  970 ****
# Recent average reward: 20.1
# Reward over last 100: 19.5
# Average over all episodes so far: 10.810309278350516
# epsilon: 0.01
# Elapsed time:  06:52:32
# **** Episode  980 ****
# Recent average reward: 18.9
# Reward over last 100: 19.39
# Average over all episodes so far: 10.892857142857142
# epsilon: 0.01
# Elapsed time:  06:56:40
# **** Episode  990 ****
# Recent average reward: 19.2
# Reward over last 100: 19.42
# Average over all episodes so far: 10.976767676767677
# epsilon: 0.01
# Elapsed time:  07:00:41
# Solved after 380 episodes

# %%
## %debug my_engine.train_agent()
