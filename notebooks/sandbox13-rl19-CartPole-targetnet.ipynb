# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython import display

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
import numpy as np
import math
import random

# %%
import time

# %%
def show_state(env, episode,step, info=""):
    plt.figure(99999,figsize=[8,6])
    plt.clf()
    plt.imshow(env.render(mode='rgb_array'))
    plt.title("episode: {} step: {} ".format(episode,step))
    #plt.title("%s | Step: %d %s" % (env._spec.id,step, info))
    plt.axis('off')

    display.clear_output(wait=True)
    display.display(plt.gcf())

# %%
import gym

# %%
use_cuda = torch.cuda.is_available()
device=torch.device("cuda:4" if use_cuda else "cpu")

# %%
###### PARAMS ######
learning_rate = 0.01
num_episodes = 1000
gamma=1
#gamma=0.85
egreedy = 0.9
egreedy_final = 0.01
egreedy_decay = 500

report_interval=10

score_to_solve = 195

hidden_layer_size=64

replay_memory_size=50000

batch_size=32

update_target_frequency = 100

clip_error=False

# %%
env = gym.make('CartPole-v1')

# %%
#env = gym.wrappers.Monitor(env, '../mp4/sandbox10',video_callable=lambda episode_id: True,force=True)
#env = gym.wrappers.Monitor(env, '../mp4/cartpole-5',video_callable=lambda episode_id: episode_id%10==0)

# %%
number_of_inputs=env.observation_space.shape[0]
number_of_outputs=env.action_space.n

# %%
def calculate_epsilon(steps_done):
    epsilon = egreedy_final + (egreedy - egreedy_final) * \
              math.exp(-1. * steps_done / egreedy_decay )
    return epsilon

# %%
class ExperienceReplay():
    def __init__(self, capacity):
        self.capacity=capacity
        self.memory=[]
        self.position=0
        
    
    def push(self, state,
             action, new_state,
             reward, done):
        
            transition=(state,action,new_state,reward,done)
            
            if self.position>=len(self.memory):
                self.memory.append(transition)
            else:
                self.memory[self.position]=transition
                
            self.position=(self.position+1)%self.capacity
        
    
    def sample(self,batch_size):
        return zip(*random.sample(self.memory, batch_size))
    
    def __len__(self):
        return len(self.memory)

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.linear1 = nn.Linear(number_of_inputs,hidden_layer_size)
        self.linear2 = nn.Linear(hidden_layer_size,number_of_outputs)
        
        self.activation=nn.Tanh()
        
    def forward(self, x):
        output1 = self.linear1(x)
        output1 = self.activation(output1)
        output2 = self.linear2(output1)
        
        return output2

# %%
class QNet_Agent():
    def __init__(self):
        
        self.nn = NeuralNetwork().to(device)
        self.target_nn = NeuralNetwork().to(device)
        
        self.loss_function = nn.MSELoss()
        self.optimizer = optim.Adam(params=self.nn.parameters(), lr=learning_rate)
        
        self.update_target_counter = 0
        
    def select_action(self,state,epsilon):
        
        random_for_egreedy=torch.rand(1).item()
        
        if random_for_egreedy>epsilon:
            self.nn.eval()
            with torch.no_grad():
                state=torch.Tensor(state).to(device)
                predicted_value_from_nn=self.nn(state)
                action=torch.argmax(predicted_value_from_nn).item()
        else:
            action=env.action_space.sample()
                
                
        return action
    
    def optimize(self):
        
        if len(memory)<batch_size:
            return
        
        state, action, new_state, reward, done = memory.sample(batch_size)
        
        state=torch.Tensor(state).to(device)
        new_state=torch.Tensor(new_state).to(device)
        reward=torch.Tensor(reward).to(device)
        
        #the view call below is to transform into column vector
        #so that it can be used in the gather call
        #i.e. we will use it to pick out from the computed value
        #tensor only values indexed by selected action
        action=(torch.Tensor(action).view(-1,1).long()).to(device)
        #print('action: ')
        #print(action)
        #print('contiguous?', action.is_contiguous())
        done=torch.Tensor(done).to(device)
        
        #print('shape of: state, new state, reward, action, done:')
        #print(state.shape)
        #print(new_state.shape)
        #print(reward.shape)
        #print(action.shape)
        #print(done.shape)
        
        
        self.nn.eval()
        self.target_nn.eval()
            
        new_state_values=self.target_nn(new_state).detach()
        #print('shape of: new_state_values')
        #print(new_state_values.shape)
        
        max_new_state_values=torch.max(new_state_values,dim=1)[0]
        #print('shape of: max_new_state_values')
        #print(max_new_state_values.shape)
        target_value=(reward + (1-done)*gamma*max_new_state_values).view(-1,1)
        
        #print('shape of: target_value')
        #print(target_value.shape)
        self.nn.train()
        
        #this will select only the values of the desired actions
        predicted_value=torch.gather(self.nn(state),1,action)
        #print('shape of: predicted_value')
        #print(predicted_value.shape)
        
        
        loss=self.loss_function(predicted_value,target_value)
        self.optimizer.zero_grad()
        loss.backward()
        
        if clip_error:
            for param in self.nn.parameters():
                param.grad.clamp_(-1.0,1.0)
        
        self.optimizer.step()
        
        if self.update_target_counter % update_target_frequency == 0:
            #print("***********************")
            #print("UPDATING TARGET NETWORK")
            #print("update counter: {}".format(self.update_target_counter))
            #print("***********************")
            self.target_nn.load_state_dict(self.nn.state_dict())
        
        self.update_target_counter+=1

# %%
a=torch.randn([3,3])
print(a)
# Out:
# tensor([[-0.4486, -0.1330,  2.4628],
#         [ 0.4545,  0.7303, -0.7722],
#         [ 1.1659, -1.4919, -1.6301]])

# %%
a.clamp_(-1.0,1.0)
# Out:
# tensor([[-0.4486, -0.1330,  1.0000],
#         [ 0.4545,  0.7303, -0.7722],
#         [ 1.0000, -1.0000, -1.0000]])

# %%
a
# Out:
# tensor([[-0.4486, -0.1330,  1.0000],
#         [ 0.4545,  0.7303, -0.7722],
#         [ 1.0000, -1.0000, -1.0000]])

# %%
memory=ExperienceReplay(replay_memory_size)

# %%
qnet_agent=QNet_Agent()

# %%
seed_value=23
env.seed(seed_value)
torch.manual_seed(seed_value)
random.seed(seed_value)

# %%
# %%time

steps_total=np.full([num_episodes],-999,dtype=np.int32)

frames_total=0

solved_after = 0
solved = False

start_time = time.time()

for i_episode in range(num_episodes):
    
    state = env.reset()
    #for step in range(100):
    step=0
    while True:
        
        step+=1
        frames_total += 1
        
        epsilon=calculate_epsilon(frames_total)
        
        #action=env.action_space.sample()
        action=qnet_agent.select_action(state,epsilon)
        
        new_state, reward, done, info = env.step(action)
        memory.push(state, action, new_state,
                     reward, done)
        
        qnet_agent.optimize()
        
        state=new_state
        
        if done:
            steps_total[i_episode]=step
            
            if i_episode>100:
                mean_reward_100 = np.sum(steps_total[i_episode-100:i_episode])/100
            
                if (mean_reward_100 > score_to_solve and solved == False):
                    print("SOLVED! After %i episodes " % i_episode)
                    solved_after = i_episode
                    solved = True
            
            if (i_episode % report_interval == 0 and i_episode>1):
                print("**** Episode  {} **** ".format(i_episode))
                recent_avg_reward=np.average(steps_total[i_episode-report_interval:i_episode])
                print("Recent average reward: {}".format(recent_avg_reward))
                if i_episode>100:
                    print("Reward over last 100: {}".format(mean_reward_100))
                full_avg_so_far=np.average(steps_total[:i_episode])
                print("Average over all episodes so far: {}".format(full_avg_so_far))
                print("epsilon: {}".format(epsilon))
            
                #print("Episode {} finished after: {}".format(i_episode,step))
            break
            
if solved:
    print("Solved after %i episodes" % solved_after)
# Out:
# **** Episode  10 ****
# Recent average reward: 19.1
# Average over all episodes so far: 19.1
# epsilon: 0.5994686056863888
# **** Episode  20 ****
# Recent average reward: 15.7
# Average over all episodes so far: 17.4
# epsilon: 0.44234395463045767
# **** Episode  30 ****
# Recent average reward: 37.0
# Average over all episodes so far: 23.933333333333334
# epsilon: 0.17291383847331343
# **** Episode  40 ****
# Recent average reward: 172.7
# Average over all episodes so far: 61.125
# epsilon: 0.014068284707070632
# **** Episode  50 ****
# Recent average reward: 206.6
# Average over all episodes so far: 90.22
# epsilon: 0.010075412778871525
# **** Episode  60 ****
# Recent average reward: 189.5
# Average over all episodes so far: 106.76666666666667
# epsilon: 0.010001630646793122
# **** Episode  70 ****
# Recent average reward: 224.9
# Average over all episodes so far: 123.64285714285714
# epsilon: 0.010000018223865398
# **** Episode  80 ****
# Recent average reward: 212.4
# Average over all episodes so far: 134.7375
# epsilon: 0.010000000246777545
# **** Episode  90 ****
# Recent average reward: 224.1
# Average over all episodes so far: 144.66666666666666
# epsilon: 0.010000000002864768
# **** Episode  100 ****
# Recent average reward: 242.3
# Average over all episodes so far: 154.43
# epsilon: 0.010000000000023624
# **** Episode  110 ****
# Recent average reward: 216.4
# Reward over last 100: 174.16
# Average over all episodes so far: 160.06363636363636
# epsilon: 0.010000000000000302
# SOLVED! After 119 episodes
# **** Episode  120 ****
# Recent average reward: 250.0
# Reward over last 100: 197.59
# Average over all episodes so far: 167.55833333333334
# epsilon: 0.010000000000000002
# **** Episode  130 ****
# Recent average reward: 332.2
# Reward over last 100: 227.11
# Average over all episodes so far: 180.22307692307692
# epsilon: 0.01
# **** Episode  140 ****
# Recent average reward: 245.0
# Reward over last 100: 234.34
# Average over all episodes so far: 184.85
# epsilon: 0.01
# **** Episode  150 ****
# Recent average reward: 280.7
# Reward over last 100: 241.75
# Average over all episodes so far: 191.24
# epsilon: 0.01
# **** Episode  160 ****
# Recent average reward: 421.5
# Reward over last 100: 264.95
# Average over all episodes so far: 205.63125
# epsilon: 0.01
# **** Episode  170 ****
# Recent average reward: 500.0
# Reward over last 100: 292.46
# Average over all episodes so far: 222.9470588235294
# epsilon: 0.01
# **** Episode  180 ****
# Recent average reward: 408.8
# Reward over last 100: 312.1
# Average over all episodes so far: 233.2722222222222
# epsilon: 0.01
# **** Episode  190 ****
# Recent average reward: 458.8
# Reward over last 100: 335.57
# Average over all episodes so far: 245.1421052631579
# epsilon: 0.01
# **** Episode  200 ****
# Recent average reward: 480.3
# Reward over last 100: 359.37
# Average over all episodes so far: 256.9
# epsilon: 0.01
# **** Episode  210 ****
# Recent average reward: 500.0
# Reward over last 100: 387.73
# Average over all episodes so far: 268.4761904761905
# epsilon: 0.01
# **** Episode  220 ****
# Recent average reward: 500.0
# Reward over last 100: 412.73
# Average over all episodes so far: 279.0
# epsilon: 0.01
# **** Episode  230 ****
# Recent average reward: 491.2
# Reward over last 100: 428.63
# Average over all episodes so far: 288.2260869565217
# epsilon: 0.01
# **** Episode  240 ****
# Recent average reward: 381.4
# Reward over last 100: 442.27
# Average over all episodes so far: 292.10833333333335
# epsilon: 0.01
# **** Episode  250 ****
# Recent average reward: 389.8
# Reward over last 100: 453.18
# Average over all episodes so far: 296.016
# epsilon: 0.01
# **** Episode  260 ****
# Recent average reward: 500.0
# Reward over last 100: 461.03
# Average over all episodes so far: 303.8615384615385
# epsilon: 0.01
# **** Episode  270 ****
# Recent average reward: 500.0
# Reward over last 100: 461.03
# Average over all episodes so far: 311.1259259259259
# epsilon: 0.01
# **** Episode  280 ****
# Recent average reward: 470.8
# Reward over last 100: 467.23
# Average over all episodes so far: 316.8285714285714
# epsilon: 0.01
# **** Episode  290 ****
# Recent average reward: 500.0
# Reward over last 100: 471.35
# Average over all episodes so far: 323.1448275862069
# epsilon: 0.01
# **** Episode  300 ****
# Recent average reward: 500.0
# Reward over last 100: 473.32
# Average over all episodes so far: 329.04
# epsilon: 0.01
# **** Episode  310 ****
# Recent average reward: 481.2
# Reward over last 100: 471.44
# Average over all episodes so far: 333.9483870967742
# epsilon: 0.01
# **** Episode  320 ****
# Recent average reward: 468.5
# Reward over last 100: 468.29
# Average over all episodes so far: 338.153125
# epsilon: 0.01
# **** Episode  330 ****
# Recent average reward: 476.1
# Reward over last 100: 466.78
# Average over all episodes so far: 342.3333333333333
# epsilon: 0.01
# **** Episode  340 ****
# Recent average reward: 500.0
# Reward over last 100: 478.64
# Average over all episodes so far: 346.97058823529414
# epsilon: 0.01
# **** Episode  350 ****
# Recent average reward: 500.0
# Reward over last 100: 489.66
# Average over all episodes so far: 351.34285714285716
# epsilon: 0.01
# **** Episode  360 ****
# Recent average reward: 458.8
# Reward over last 100: 485.54
# Average over all episodes so far: 354.3277777777778
# epsilon: 0.01
# **** Episode  370 ****
# Recent average reward: 500.0
# Reward over last 100: 485.54
# Average over all episodes so far: 358.2648648648649
# epsilon: 0.01
# **** Episode  380 ****
# Recent average reward: 500.0
# Reward over last 100: 488.46
# Average over all episodes so far: 361.9947368421053
# epsilon: 0.01
# **** Episode  390 ****
# Recent average reward: 500.0
# Reward over last 100: 488.46
# Average over all episodes so far: 365.53333333333336
# epsilon: 0.01
# **** Episode  400 ****
# Recent average reward: 500.0
# Reward over last 100: 488.46
# Average over all episodes so far: 368.895
# epsilon: 0.01
# **** Episode  410 ****
# Recent average reward: 500.0
# Reward over last 100: 490.34
# Average over all episodes so far: 372.09268292682924
# epsilon: 0.01
# **** Episode  420 ****
# Recent average reward: 500.0
# Reward over last 100: 493.49
# Average over all episodes so far: 375.1380952380952
# epsilon: 0.01
# **** Episode  430 ****
# Recent average reward: 349.1
# Reward over last 100: 480.79
# Average over all episodes so far: 374.5325581395349
# epsilon: 0.01
# **** Episode  440 ****
# Recent average reward: 500.0
# Reward over last 100: 480.79
# Average over all episodes so far: 377.3840909090909
# epsilon: 0.01
# **** Episode  450 ****
# Recent average reward: 500.0
# Reward over last 100: 480.79
# Average over all episodes so far: 380.1088888888889
# epsilon: 0.01
# **** Episode  460 ****
# Recent average reward: 500.0
# Reward over last 100: 484.91
# Average over all episodes so far: 382.71521739130435
# epsilon: 0.01
# **** Episode  470 ****
# Recent average reward: 500.0
# Reward over last 100: 484.91
# Average over all episodes so far: 385.2106382978723
# epsilon: 0.01
# **** Episode  480 ****
# Recent average reward: 500.0
# Reward over last 100: 484.91
# Average over all episodes so far: 387.6020833333333
# epsilon: 0.01
# **** Episode  490 ****
# Recent average reward: 500.0
# Reward over last 100: 484.91
# Average over all episodes so far: 389.89591836734695
# epsilon: 0.01
# **** Episode  500 ****
# Recent average reward: 473.6
# Reward over last 100: 482.27
# Average over all episodes so far: 391.57
# epsilon: 0.01
# **** Episode  510 ****
# Recent average reward: 500.0
# Reward over last 100: 482.27
# Average over all episodes so far: 393.69607843137254
# epsilon: 0.01
# **** Episode  520 ****
# Recent average reward: 444.3
# Reward over last 100: 476.7
# Average over all episodes so far: 394.66923076923075
# epsilon: 0.01
# **** Episode  530 ****
# Recent average reward: 500.0
# Reward over last 100: 491.79
# Average over all episodes so far: 396.6566037735849
# epsilon: 0.01
# **** Episode  540 ****
# Recent average reward: 500.0
# Reward over last 100: 491.79
# Average over all episodes so far: 398.57037037037037
# epsilon: 0.01
# **** Episode  550 ****
# Recent average reward: 500.0
# Reward over last 100: 491.79
# Average over all episodes so far: 400.4145454545455
# epsilon: 0.01
# **** Episode  560 ****
# Recent average reward: 500.0
# Reward over last 100: 491.79
# Average over all episodes so far: 402.1928571428571
# epsilon: 0.01
# **** Episode  570 ****
# Recent average reward: 500.0
# Reward over last 100: 491.79
# Average over all episodes so far: 403.9087719298246
# epsilon: 0.01
# **** Episode  580 ****
# Recent average reward: 500.0
# Reward over last 100: 491.79
# Average over all episodes so far: 405.5655172413793
# epsilon: 0.01
# **** Episode  590 ****
# Recent average reward: 500.0
# Reward over last 100: 491.79
# Average over all episodes so far: 407.16610169491526
# epsilon: 0.01
# **** Episode  600 ****
# Recent average reward: 500.0
# Reward over last 100: 494.43
# Average over all episodes so far: 408.7133333333333
# epsilon: 0.01
# **** Episode  610 ****
# Recent average reward: 500.0
# Reward over last 100: 494.43
# Average over all episodes so far: 410.20983606557377
# epsilon: 0.01
# **** Episode  620 ****
# Recent average reward: 500.0
# Reward over last 100: 500.0
# Average over all episodes so far: 411.65806451612906
# epsilon: 0.01
# **** Episode  630 ****
# Recent average reward: 500.0
# Reward over last 100: 500.0
# Average over all episodes so far: 413.06031746031744
# epsilon: 0.01
# **** Episode  640 ****
# Recent average reward: 500.0
# Reward over last 100: 500.0
# Average over all episodes so far: 414.41875
# epsilon: 0.01
# **** Episode  650 ****
# Recent average reward: 500.0
# Reward over last 100: 500.0
# Average over all episodes so far: 415.7353846153846
# epsilon: 0.01
# **** Episode  660 ****
# Recent average reward: 500.0
# Reward over last 100: 500.0
# Average over all episodes so far: 417.0121212121212
# epsilon: 0.01
# **** Episode  670 ****
# Recent average reward: 500.0
# Reward over last 100: 500.0
# Average over all episodes so far: 418.2507462686567
# epsilon: 0.01
# **** Episode  680 ****
# Recent average reward: 500.0
# Reward over last 100: 500.0
# Average over all episodes so far: 419.4529411764706
# epsilon: 0.01
# **** Episode  690 ****
# Recent average reward: 500.0
# Reward over last 100: 500.0
# Average over all episodes so far: 420.6202898550725
# epsilon: 0.01
# **** Episode  700 ****
# Recent average reward: 500.0
# Reward over last 100: 500.0
# Average over all episodes so far: 421.7542857142857
# epsilon: 0.01
# **** Episode  710 ****
# Recent average reward: 500.0
# Reward over last 100: 500.0
# Average over all episodes so far: 422.85633802816903
# epsilon: 0.01
# **** Episode  720 ****
# Recent average reward: 500.0
# Reward over last 100: 500.0
# Average over all episodes so far: 423.9277777777778
# epsilon: 0.01
# **** Episode  730 ****
# Recent average reward: 500.0
# Reward over last 100: 500.0
# Average over all episodes so far: 424.9698630136986
# epsilon: 0.01
# **** Episode  740 ****
# Recent average reward: 342.0
# Reward over last 100: 484.2
# Average over all episodes so far: 423.84864864864863
# epsilon: 0.01
# **** Episode  750 ****
# Recent average reward: 304.2
# Reward over last 100: 464.62
# Average over all episodes so far: 422.25333333333333
# epsilon: 0.01
# **** Episode  760 ****
# Recent average reward: 175.6
# Reward over last 100: 432.18
# Average over all episodes so far: 419.0078947368421
# epsilon: 0.01
# **** Episode  770 ****
# Recent average reward: 476.8
# Reward over last 100: 429.86
# Average over all episodes so far: 419.7584415584416
# epsilon: 0.01
# **** Episode  780 ****
# Recent average reward: 181.0
# Reward over last 100: 397.96
# Average over all episodes so far: 416.6974358974359
# epsilon: 0.01
# **** Episode  790 ****
# Recent average reward: 163.3
# Reward over last 100: 364.29
# Average over all episodes so far: 413.4898734177215
# epsilon: 0.01
# **** Episode  800 ****
# Recent average reward: 168.7
# Reward over last 100: 331.16
# Average over all episodes so far: 410.43
# epsilon: 0.01
# **** Episode  810 ****
# Recent average reward: 298.4
# Reward over last 100: 311.0
# Average over all episodes so far: 409.0469135802469
# epsilon: 0.01
# **** Episode  820 ****
# Recent average reward: 409.5
# Reward over last 100: 301.95
# Average over all episodes so far: 409.05243902439025
# epsilon: 0.01
# **** Episode  830 ****
# Recent average reward: 500.0
# Reward over last 100: 301.95
# Average over all episodes so far: 410.1481927710843
# epsilon: 0.01
# **** Episode  840 ****
# Recent average reward: 500.0
# Reward over last 100: 317.75
# Average over all episodes so far: 411.21785714285716
# epsilon: 0.01
# **** Episode  850 ****
# Recent average reward: 500.0
# Reward over last 100: 337.33
# Average over all episodes so far: 412.26235294117646
# epsilon: 0.01
# **** Episode  860 ****
# Recent average reward: 476.4
# Reward over last 100: 367.41
# Average over all episodes so far: 413.0081395348837
# epsilon: 0.01
# **** Episode  870 ****
# Recent average reward: 500.0
# Reward over last 100: 369.73
# Average over all episodes so far: 414.0080459770115
# epsilon: 0.01
# **** Episode  880 ****
# Recent average reward: 500.0
# Reward over last 100: 401.63
# Average over all episodes so far: 414.9852272727273
# epsilon: 0.01
# **** Episode  890 ****
# Recent average reward: 500.0
# Reward over last 100: 435.3
# Average over all episodes so far: 415.9404494382022
# epsilon: 0.01
# **** Episode  900 ****
# Recent average reward: 482.7
# Reward over last 100: 466.7
# Average over all episodes so far: 416.6822222222222
# epsilon: 0.01
# **** Episode  910 ****
# Recent average reward: 500.0
# Reward over last 100: 486.86
# Average over all episodes so far: 417.5978021978022
# epsilon: 0.01
# **** Episode  920 ****
# Recent average reward: 500.0
# Reward over last 100: 495.91
# Average over all episodes so far: 418.49347826086955
# epsilon: 0.01
# **** Episode  930 ****
# Recent average reward: 500.0
# Reward over last 100: 495.91
# Average over all episodes so far: 419.3698924731183
# epsilon: 0.01
# **** Episode  940 ****
# Recent average reward: 500.0
# Reward over last 100: 495.91
# Average over all episodes so far: 420.2276595744681
# epsilon: 0.01
# **** Episode  950 ****
# Recent average reward: 500.0
# Reward over last 100: 495.91
# Average over all episodes so far: 421.0673684210526
# epsilon: 0.01
# **** Episode  960 ****
# Recent average reward: 500.0
# Reward over last 100: 498.27
# Average over all episodes so far: 421.88958333333335
# epsilon: 0.01
# **** Episode  970 ****
# Recent average reward: 500.0
# Reward over last 100: 498.27
# Average over all episodes so far: 422.69484536082473
# epsilon: 0.01
# **** Episode  980 ****
# Recent average reward: 500.0
# Reward over last 100: 498.27
# Average over all episodes so far: 423.4836734693878
# epsilon: 0.01
# **** Episode  990 ****
# Recent average reward: 389.8
# Reward over last 100: 487.25
# Average over all episodes so far: 423.14343434343436
# epsilon: 0.01
# Solved after 119 episodes
# CPU times: user 18min 28s, sys: 16.1 s, total: 18min 44s
# Wall time: 18min 47s

# %%
plt.plot(steps_total)
plt.show()

# %%
print("Average number of steps: {}". format(np.average(steps_total)))
# Out:
# Average number of steps: 423.912

# %%
print("Average number of steps=reward: {}". format(np.average(steps_total)))
print("Average number of steps=reward in last 100 episodes: {}". format(np.average(steps_total[-100:])))
# Out:
# Average number of steps=reward: 423.912
# Average number of steps=reward in last 100 episodes: 488.98

# %% [markdown]
# plt.figure(1,figsize=[12,5])
# plt.title("Rewards")
# plt.bar(torch.arange(len(rewards_total)), rewards_total,alpha=0.6, color='green')
# #plt.plot(rewards_total)
# plt.show()

# %%
plt.figure(2,figsize=[12,5])
plt.title("Steps to finish episode")
plt.plot(steps_total)
plt.show()
