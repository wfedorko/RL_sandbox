# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython import display

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
import numpy as np
import math
import random

# %%
import time

# %%
def show_state(env, episode,step, info=""):
    plt.figure(99999,figsize=[8,6])
    plt.clf()
    plt.imshow(env.render(mode='rgb_array'))
    plt.title("episode: {} step: {} ".format(episode,step))
    #plt.title("%s | Step: %d %s" % (env._spec.id,step, info))
    plt.axis('off')

    display.clear_output(wait=True)
    display.display(plt.gcf())

# %%
import gym

# %%
use_cuda = torch.cuda.is_available()
device=torch.device("cuda:5" if use_cuda else "cpu")

# %%
###### PARAMS ######
learning_rate = 0.01
num_episodes = 1000
gamma=0.99
#gamma=0.85
egreedy = 0.9
egreedy_final = 0.02
egreedy_decay = 500

report_interval=10

score_to_solve = 195

hidden_layer_size=256

replay_memory_size=50000

batch_size=32

# %%
env = gym.make('CartPole-v1')

# %%
#env = gym.wrappers.Monitor(env, '../mp4/sandbox10',video_callable=lambda episode_id: True,force=True)
#env = gym.wrappers.Monitor(env, '../mp4/cartpole-5',video_callable=lambda episode_id: episode_id%10==0)

# %%
number_of_inputs=env.observation_space.shape[0]
number_of_outputs=env.action_space.n

# %%
def calculate_epsilon(steps_done):
    epsilon = egreedy_final + (egreedy - egreedy_final) * \
              math.exp(-1. * steps_done / egreedy_decay )
    return epsilon

# %%
class ExperienceReplay():
    def __init__(self, capacity):
        self.capacity=capacity
        self.memory=[]
        self.position=0
        
    
    def push(self, state,
             action, new_state,
             reward, done):
        
            transition=(state,action,new_state,reward,done)
            
            if self.position>=len(self.memory):
                self.memory.append(transition)
            else:
                self.memory[self.position]=transition
                
            self.position=(self.position+1)%self.capacity
        
    
    def sample(self,batch_size):
        return zip(*random.sample(self.memory, batch_size))
    
    def __len__(self):
        return len(self.memory)

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.linear_in  = nn.Linear(number_of_inputs,hidden_layer_size)
        self.linear_r_0_0 = nn.Linear(hidden_layer_size,hidden_layer_size)
        self.linear_r_0_1 = nn.Linear(hidden_layer_size,hidden_layer_size)
        self.linear_r_1_0 = nn.Linear(hidden_layer_size,hidden_layer_size)
        self.linear_r_1_1 = nn.Linear(hidden_layer_size,hidden_layer_size)
        self.linear_r_2_0 = nn.Linear(hidden_layer_size,hidden_layer_size)
        self.linear_r_2_1 = nn.Linear(hidden_layer_size,hidden_layer_size)
        
        self.linear_out = nn.Linear(hidden_layer_size,number_of_outputs)
        
        self.activation=nn.ReLU()
        
    def forward(self, x):
        x = self.linear_in(x)
        
        skip_0 = x
        x=self.linear_r_0_0(x)
        x=self.activation(x)
        x=self.linear_r_0_1(x)
        x=self.activation(x)
        x=x+skip_0
        
        skip_1 = x
        x=self.linear_r_1_0(x)
        x=self.activation(x)
        x=self.linear_r_1_1(x)
        x=self.activation(x)
        x=x+skip_1
        
        skip_2 = x
        x=self.linear_r_2_0(x)
        x=self.activation(x)
        x=self.linear_r_2_1(x)
        x=self.activation(x)
        x=x+skip_2
        
        x= self.linear_out(x)
        
        return x

# %%
class QNet_Agent():
    def __init__(self):
        self.nn = NeuralNetwork().to(device)
        self.loss_function = nn.MSELoss()
        self.optimizer = optim.Adam(params=self.nn.parameters(), lr=learning_rate)
        
    def select_action(self,state,epsilon):
        
        random_for_egreedy=torch.rand(1).item()
        
        if random_for_egreedy>epsilon:
            self.nn.eval()
            with torch.no_grad():
                state=torch.Tensor(state).to(device)
                predicted_value_from_nn=self.nn(state)
                action=torch.argmax(predicted_value_from_nn).item()
        else:
            action=env.action_space.sample()
                
                
        return action
    
    def optimize(self):
        
        if len(memory)<batch_size:
            return
        
        state, action, new_state, reward, done = memory.sample(batch_size)
        
        state=torch.Tensor(state).to(device)
        new_state=torch.Tensor(new_state).to(device)
        reward=torch.Tensor(reward).to(device)
        
        #the view call below is to transform into column vector
        #so that it can be used in the gather call
        #i.e. we will use it to pick out from the computed value
        #tensor only values indexed by selected action
        action=(torch.Tensor(action).view(-1,1).long()).to(device)
        #print('action: ')
        #print(action)
        #print('contiguous?', action.is_contiguous())
        done=torch.Tensor(done).to(device)
        
        #print('shape of: state, new state, reward, action, done:')
        #print(state.shape)
        #print(new_state.shape)
        #print(reward.shape)
        #print(action.shape)
        #print(done.shape)
        
        
        self.nn.eval()
            
        new_state_values=self.nn(new_state).detach()
        #print('shape of: new_state_values')
        #print(new_state_values.shape)
        
        max_new_state_values=torch.max(new_state_values,dim=1)[0]
        #print('shape of: max_new_state_values')
        #print(max_new_state_values.shape)
        target_value=(reward + (1-done)*gamma*max_new_state_values).view(-1,1)
        
        #print('shape of: target_value')
        #print(target_value.shape)
        self.nn.train()
        
        #this will select only the values of the desired actions
        predicted_value=torch.gather(self.nn(state),1,action)
        #print('shape of: predicted_value')
        #print(predicted_value.shape)
        
        
        loss=self.loss_function(predicted_value,target_value)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

# %%
memory=ExperienceReplay(replay_memory_size)

# %%
qnet_agent=QNet_Agent()

# %%
seed_value=23
env.seed(seed_value)
torch.manual_seed(seed_value)
random.seed(seed_value)

# %%
# %%time

num_episodes=1000

steps_total=np.full([num_episodes],-999,dtype=np.int32)

frames_total=0

solved_after = 0
solved = False

start_time = time.time()

for i_episode in range(num_episodes):
    
    state = env.reset()
    #for step in range(100):
    step=0
    while True:
        
        step+=1
        frames_total += 1
        
        epsilon=calculate_epsilon(frames_total)
        
        #action=env.action_space.sample()
        action=qnet_agent.select_action(state,epsilon)
        
        new_state, reward, done, info = env.step(action)
        memory.push(state, action, new_state,
                     reward, done)
        
        qnet_agent.optimize()
        
        state=new_state
        
        if done:
            steps_total[i_episode]=step
            
            if i_episode>100:
                mean_reward_100 = np.sum(steps_total[i_episode-100:i_episode])/100
            
                if (mean_reward_100 > score_to_solve and solved == False):
                    print("SOLVED! After %i episodes " % i_episode)
                    solved_after = i_episode
                    solved = True
            
            if (i_episode % report_interval == 0 and i_episode>1):
                print("**** Episode  {} **** ".format(i_episode))
                recent_avg_reward=np.average(steps_total[i_episode-report_interval:i_episode])
                print("Recent average reward: {}".format(recent_avg_reward))
                if i_episode>100:
                    print("Reward over last 100: {}".format(mean_reward_100))
                full_avg_so_far=np.average(steps_total[:i_episode])
                print("Average over all episodes so far: {}".format(full_avg_so_far))
                print("epsilon: {}".format(epsilon))
            
                #print("Episode {} finished after: {}".format(i_episode,step))
            break
            
if solved:
    print("Solved after %i episodes" % solved_after)
# Out:
# **** Episode  10 ****
# Recent average reward: 19.1
# Average over all episodes so far: 19.1
# epsilon: 0.6028453629258677
# **** Episode  20 ****
# Recent average reward: 12.8
# Average over all episodes so far: 15.95
# epsilon: 0.47665213453986754
# **** Episode  30 ****
# Recent average reward: 13.9
# Average over all episodes so far: 15.266666666666667
# epsilon: 0.36513025878628436
# **** Episode  40 ****
# Recent average reward: 11.0
# Average over all episodes so far: 14.2
# epsilon: 0.2964201269587322
# **** Episode  50 ****
# Recent average reward: 10.3
# Average over all episodes so far: 13.42
# epsilon: 0.24586148371912916
# **** Episode  60 ****
# Recent average reward: 11.6
# Average over all episodes so far: 13.116666666666667
# epsilon: 0.1980246292818494
# **** Episode  70 ****
# Recent average reward: 10.5
# Average over all episodes so far: 12.742857142857142
# epsilon: 0.1645928566107524
# **** Episode  80 ****
# Recent average reward: 9.4
# Average over all episodes so far: 12.325
# epsilon: 0.14005163086691652
# **** Episode  90 ****
# Recent average reward: 11.1
# Average over all episodes so far: 12.188888888888888
# epsilon: 0.11653657069365005
# **** Episode  100 ****
# Recent average reward: 9.6
# Average over all episodes so far: 11.93
# epsilon: 0.09903745922357791
# **** Episode  110 ****
# Recent average reward: 10.0
# Reward over last 100: 11.02
# Average over all episodes so far: 11.754545454545454
# epsilon: 0.08509982802280529
# **** Episode  120 ****
# Recent average reward: 9.8
# Reward over last 100: 10.72
# Average over all episodes so far: 11.591666666666667
# epsilon: 0.07340593635436683
# **** Episode  130 ****
# Recent average reward: 9.7
# Reward over last 100: 10.3
# Average over all episodes so far: 11.446153846153846
# epsilon: 0.06398822161313879
# **** Episode  140 ****
# Recent average reward: 9.6
# Reward over last 100: 10.16
# Average over all episodes so far: 11.314285714285715
# epsilon: 0.05630378143005771
# **** Episode  150 ****
# Recent average reward: 9.1
# Reward over last 100: 10.04
# Average over all episodes so far: 11.166666666666666
# epsilon: 0.05032346719011292
# **** Episode  160 ****
# Recent average reward: 9.2
# Reward over last 100: 9.8
# Average over all episodes so far: 11.04375
# epsilon: 0.045126470888015205
# **** Episode  170 ****
# Recent average reward: 9.5
# Reward over last 100: 9.7
# Average over all episodes so far: 10.952941176470588
# epsilon: 0.040861845313401264
# **** Episode  180 ****
# Recent average reward: 9.2
# Reward over last 100: 9.68
# Average over all episodes so far: 10.855555555555556
# epsilon: 0.03735571605011216
# **** Episode  190 ****
# Recent average reward: 9.5
# Reward over last 100: 9.52
# Average over all episodes so far: 10.784210526315789
# epsilon: 0.03438120157367723
# **** Episode  200 ****
# Recent average reward: 9.4
# Reward over last 100: 9.5
# Average over all episodes so far: 10.715
# epsilon: 0.03186890443591921
# **** Episode  210 ****
# Recent average reward: 9.3
# Reward over last 100: 9.43
# Average over all episodes so far: 10.647619047619047
# epsilon: 0.02985443795450765
# **** Episode  220 ****
# Recent average reward: 9.3
# Reward over last 100: 9.38
# Average over all episodes so far: 10.586363636363636
# epsilon: 0.028181879627015467
# **** Episode  230 ****
# Recent average reward: 10.0
# Reward over last 100: 9.41
# Average over all episodes so far: 10.560869565217391
# epsilon: 0.02668537234426826
# **** Episode  240 ****
# Recent average reward: 9.4
# Reward over last 100: 9.39
# Average over all episodes so far: 10.5125
# epsilon: 0.025561800615109414
# **** Episode  250 ****
# Recent average reward: 9.5
# Reward over last 100: 9.43
# Average over all episodes so far: 10.472
# epsilon: 0.024590192248831064
# **** Episode  260 ****
# Recent average reward: 9.8
# Reward over last 100: 9.49
# Average over all episodes so far: 10.446153846153846
# epsilon: 0.02378074812786206
# **** Episode  270 ****
# Recent average reward: 9.6
# Reward over last 100: 9.5
# Average over all episodes so far: 10.414814814814815
# epsilon: 0.0231265241974748
# **** Episode  280 ****
# Recent average reward: 9.7
# Reward over last 100: 9.55
# Average over all episodes so far: 10.389285714285714
# epsilon: 0.022564906196714276
# **** Episode  290 ****
# Recent average reward: 9.5
# Reward over last 100: 9.55
# Average over all episodes so far: 10.358620689655172
# epsilon: 0.022116834701185167
# **** Episode  300 ****
# Recent average reward: 9.2
# Reward over last 100: 9.53
# Average over all episodes so far: 10.32
# epsilon: 0.0217645962443465
# **** Episode  310 ****
# Recent average reward: 9.5
# Reward over last 100: 9.55
# Average over all episodes so far: 10.293548387096774
# epsilon: 0.021465097667485188
# **** Episode  320 ****
# Recent average reward: 9.3
# Reward over last 100: 9.55
# Average over all episodes so far: 10.2625
# epsilon: 0.021211575898245988
# **** Episode  330 ****
# Recent average reward: 9.7
# Reward over last 100: 9.52
# Average over all episodes so far: 10.245454545454546
# epsilon: 0.0209939403417094
# **** Episode  340 ****
# Recent average reward: 9.9
# Reward over last 100: 9.57
# Average over all episodes so far: 10.235294117647058
# epsilon: 0.020818666818820355
# **** Episode  350 ****
# Recent average reward: 9.5
# Reward over last 100: 9.57
# Average over all episodes so far: 10.214285714285714
# epsilon: 0.02067835936639794
# **** Episode  360 ****
# Recent average reward: 9.5
# Reward over last 100: 9.54
# Average over all episodes so far: 10.194444444444445
# epsilon: 0.020562098547786376
# **** Episode  370 ****
# Recent average reward: 9.6
# Reward over last 100: 9.54
# Average over all episodes so far: 10.178378378378378
# epsilon: 0.020462976911862135
# **** Episode  380 ****
# Recent average reward: 9.1
# Reward over last 100: 9.48
# Average over all episodes so far: 10.15
# epsilon: 0.020385167069323216
# **** Episode  390 ****
# Recent average reward: 9.7
# Reward over last 100: 9.5
# Average over all episodes so far: 10.138461538461538
# epsilon: 0.020317881027829263
# **** Episode  400 ****
# Recent average reward: 9.4
# Reward over last 100: 9.52
# Average over all episodes so far: 10.12
# epsilon: 0.020263928223752354
# **** Episode  410 ****
# Recent average reward: 8.7
# Reward over last 100: 9.44
# Average over all episodes so far: 10.085365853658537
# epsilon: 0.02022089272721438
# **** Episode  420 ****
# Recent average reward: 9.4
# Reward over last 100: 9.45
# Average over all episodes so far: 10.06904761904762
# epsilon: 0.020183034962490572
# **** Episode  430 ****
# Recent average reward: 9.4
# Reward over last 100: 9.42
# Average over all episodes so far: 10.053488372093023
# epsilon: 0.02015196909631443
# **** Episode  440 ****
# Recent average reward: 9.4
# Reward over last 100: 9.37
# Average over all episodes so far: 10.038636363636364
# epsilon: 0.020125672232274336
# **** Episode  450 ****
# Recent average reward: 9.7
# Reward over last 100: 9.39
# Average over all episodes so far: 10.03111111111111
# epsilon: 0.020103510927459836
# **** Episode  460 ****
# Recent average reward: 9.4
# Reward over last 100: 9.38
# Average over all episodes so far: 10.017391304347827
# epsilon: 0.020085942389861992
# **** Episode  470 ****
# Recent average reward: 9.1
# Reward over last 100: 9.33
# Average over all episodes so far: 9.997872340425532
# epsilon: 0.02007149855119262
# **** Episode  480 ****
# Recent average reward: 9.7
# Reward over last 100: 9.39
# Average over all episodes so far: 9.991666666666667
# epsilon: 0.020058890346833554
# **** Episode  490 ****
# Recent average reward: 9.7
# Reward over last 100: 9.39
# Average over all episodes so far: 9.985714285714286
# epsilon: 0.020048602607729588
# **** Episode  500 ****
# Recent average reward: 9.4
# Reward over last 100: 9.39
# Average over all episodes so far: 9.974
# epsilon: 0.02004019237039545
# **** Episode  510 ****
# Recent average reward: 9.6
# Reward over last 100: 9.48
# Average over all episodes so far: 9.966666666666667
# epsilon: 0.02003323744781335
# **** Episode  520 ****
# Recent average reward: 9.3
# Reward over last 100: 9.47
# Average over all episodes so far: 9.953846153846154
# epsilon: 0.02002754103808902
# **** Episode  530 ****
# Recent average reward: 9.6
# Reward over last 100: 9.49
# Average over all episodes so far: 9.947169811320755
# epsilon: 0.020022775313006
# **** Episode  540 ****
# Recent average reward: 9.2
# Reward over last 100: 9.47
# Average over all episodes so far: 9.933333333333334
# epsilon: 0.02001890974100633
# **** Episode  550 ****
# Recent average reward: 9.6
# Reward over last 100: 9.46
# Average over all episodes so far: 9.927272727272728
# epsilon: 0.020015606339133924
# **** Episode  560 ****
# Recent average reward: 9.9
# Reward over last 100: 9.51
# Average over all episodes so far: 9.926785714285714
# epsilon: 0.020012854284584353
# **** Episode  570 ****
# Recent average reward: 9.4
# Reward over last 100: 9.54
# Average over all episodes so far: 9.917543859649124
# epsilon: 0.02001062996804734
# **** Episode  580 ****
# Recent average reward: 9.4
# Reward over last 100: 9.51
# Average over all episodes so far: 9.908620689655173
# epsilon: 0.020008808147861438
# **** Episode  590 ****
# Recent average reward: 9.2
# Reward over last 100: 9.46
# Average over all episodes so far: 9.896610169491526
# epsilon: 0.02000731317259005
# **** Episode  600 ****
# Recent average reward: 9.5
# Reward over last 100: 9.47
# Average over all episodes so far: 9.89
# epsilon: 0.020006071934097064
# **** Episode  610 ****
# Recent average reward: 9.4
# Reward over last 100: 9.45
# Average over all episodes so far: 9.881967213114754
# epsilon: 0.020005011208915336
# **** Episode  620 ****
# Recent average reward: 9.5
# Reward over last 100: 9.47
# Average over all episodes so far: 9.875806451612902
# epsilon: 0.020004144064984634
# **** Episode  630 ****
# Recent average reward: 9.6
# Reward over last 100: 9.47
# Average over all episodes so far: 9.871428571428572
# epsilon: 0.020003420125295296
# **** Episode  640 ****
# Recent average reward: 9.6
# Reward over last 100: 9.51
# Average over all episodes so far: 9.8671875
# epsilon: 0.02000283396612026
# **** Episode  650 ****
# Recent average reward: 9.2
# Reward over last 100: 9.47
# Average over all episodes so far: 9.856923076923078
# epsilon: 0.020002352967238724
# **** Episode  660 ****
# Recent average reward: 9.3
# Reward over last 100: 9.41
# Average over all episodes so far: 9.848484848484848
# epsilon: 0.02000195360656817
# **** Episode  670 ****
# Recent average reward: 9.2
# Reward over last 100: 9.39
# Average over all episodes so far: 9.838805970149254
# epsilon: 0.020001625275250654
# **** Episode  680 ****
# Recent average reward: 9.5
# Reward over last 100: 9.4
# Average over all episodes so far: 9.833823529411765
# epsilon: 0.020001341350827553
# **** Episode  690 ****
# Recent average reward: 9.8
# Reward over last 100: 9.46
# Average over all episodes so far: 9.833333333333334
# epsilon: 0.020001104814211513
# **** Episode  700 ****
# Recent average reward: 9.4
# Reward over last 100: 9.45
# Average over all episodes so far: 9.827142857142857
# epsilon: 0.020000915465304418
# **** Episode  710 ****
# Recent average reward: 9.4
# Reward over last 100: 9.45
# Average over all episodes so far: 9.82112676056338
# epsilon: 0.0200007585680152
# **** Episode  720 ****
# Recent average reward: 9.8
# Reward over last 100: 9.48
# Average over all episodes so far: 9.820833333333333
# epsilon: 0.020000622306331227
# **** Episode  730 ****
# Recent average reward: 9.3
# Reward over last 100: 9.45
# Average over all episodes so far: 9.813698630136987
# epsilon: 0.02000051668451481
# **** Episode  740 ****
# Recent average reward: 9.5
# Reward over last 100: 9.44
# Average over all episodes so far: 9.80945945945946
# epsilon: 0.02000042727697889
# **** Episode  750 ****
# Recent average reward: 9.9
# Reward over last 100: 9.51
# Average over all episodes so far: 9.810666666666666
# epsilon: 0.020000350525152418
# **** Episode  760 ****
# Recent average reward: 9.3
# Reward over last 100: 9.51
# Average over all episodes so far: 9.803947368421053
# epsilon: 0.02000029161442444
# **** Episode  770 ****
# Recent average reward: 9.3
# Reward over last 100: 9.52
# Average over all episodes so far: 9.797402597402597
# epsilon: 0.020000242604480602
# **** Episode  780 ****
# Recent average reward: 9.3
# Reward over last 100: 9.5
# Average over all episodes so far: 9.79102564102564
# epsilon: 0.02000020102564067
# **** Episode  790 ****
# Recent average reward: 9.6
# Reward over last 100: 9.48
# Average over all episodes so far: 9.788607594936709
# epsilon: 0.020000165576357896
# **** Episode  800 ****
# Recent average reward: 9.5
# Reward over last 100: 9.49
# Average over all episodes so far: 9.785
# epsilon: 0.020000136924881527
# **** Episode  810 ****
# Recent average reward: 9.4
# Reward over last 100: 9.49
# Average over all episodes so far: 9.780246913580246
# epsilon: 0.02000011345797062
# **** Episode  820 ****
# Recent average reward: 9.2
# Reward over last 100: 9.43
# Average over all episodes so far: 9.773170731707317
# epsilon: 0.02000009457871639
# **** Episode  830 ****
# Recent average reward: 9.3
# Reward over last 100: 9.43
# Average over all episodes so far: 9.767469879518073
# epsilon: 0.020000078526210868
# **** Episode  840 ****
# Recent average reward: 9.1
# Reward over last 100: 9.39
# Average over all episodes so far: 9.75952380952381
# epsilon: 0.020000065198239395
# **** Episode  850 ****
# Recent average reward: 10.1
# Reward over last 100: 9.41
# Average over all episodes so far: 9.763529411764706
# epsilon: 0.02000005348667008
# **** Episode  860 ****
# Recent average reward: 9.2
# Reward over last 100: 9.4
# Average over all episodes so far: 9.756976744186046
# epsilon: 0.020000044231290367
# **** Episode  870 ****
# Recent average reward: 9.7
# Reward over last 100: 9.44
# Average over all episodes so far: 9.75632183908046
# epsilon: 0.020000036650697717
# **** Episode  880 ****
# Recent average reward: 9.1
# Reward over last 100: 9.42
# Average over all episodes so far: 9.748863636363636
# epsilon: 0.020000030552070745
# **** Episode  890 ****
# Recent average reward: 9.9
# Reward over last 100: 9.45
# Average over all episodes so far: 9.750561797752809
# epsilon: 0.020000025013919887
# **** Episode  900 ****
# Recent average reward: 9.2
# Reward over last 100: 9.42
# Average over all episodes so far: 9.744444444444444
# epsilon: 0.020000020893382153
# **** Episode  910 ****
# Recent average reward: 9.5
# Reward over last 100: 9.43
# Average over all episodes so far: 9.741758241758241
# epsilon: 0.020000017208999358
# **** Episode  920 ****
# Recent average reward: 9.4
# Reward over last 100: 9.45
# Average over all episodes so far: 9.73804347826087
# epsilon: 0.020000014288177763
# **** Episode  930 ****
# Recent average reward: 9.6
# Reward over last 100: 9.48
# Average over all episodes so far: 9.736559139784946
# epsilon: 0.020000011768570553
# **** Episode  940 ****
# Recent average reward: 9.3
# Reward over last 100: 9.5
# Average over all episodes so far: 9.731914893617022
# epsilon: 0.02000000977113338
# **** Episode  950 ****
# Recent average reward: 9.4
# Reward over last 100: 9.43
# Average over all episodes so far: 9.728421052631578
# epsilon: 0.020000008128955703
# **** Episode  960 ****
# Recent average reward: 9.1
# Reward over last 100: 9.42
# Average over all episodes so far: 9.721875
# epsilon: 0.020000006749257275
# **** Episode  970 ****
# Recent average reward: 9.2
# Reward over last 100: 9.37
# Average over all episodes so far: 9.716494845360824
# epsilon: 0.02000000562618991
# **** Episode  980 ****
# Recent average reward: 9.4
# Reward over last 100: 9.4
# Average over all episodes so far: 9.713265306122448
# epsilon: 0.020000004661943706
# **** Episode  990 ****
# Recent average reward: 9.6
# Reward over last 100: 9.37
# Average over all episodes so far: 9.712121212121213
# epsilon: 0.02000000384753416
# CPU times: user 1min 32s, sys: 894 ms, total: 1min 33s
# Wall time: 1min 34s

# %%
plt.plot(steps_total)
plt.show()

# %%
print("Average number of steps: {}". format(np.average(steps_total)))
# Out:
# Average number of steps: 9.706

# %%
print("Average number of steps=reward: {}". format(np.average(steps_total)))
print("Average number of steps=reward in last 100 episodes: {}". format(np.average(steps_total[-100:])))
# Out:
# Average number of steps=reward: 9.706
# Average number of steps=reward in last 100 episodes: 9.36

# %% [markdown]
# plt.figure(1,figsize=[12,5])
# plt.title("Rewards")
# plt.bar(torch.arange(len(rewards_total)), rewards_total,alpha=0.6, color='green')
# #plt.plot(rewards_total)
# plt.show()

# %%
plt.figure(2,figsize=[12,5])
plt.title("Steps to finish episode")
plt.plot(steps_total)
plt.show()
