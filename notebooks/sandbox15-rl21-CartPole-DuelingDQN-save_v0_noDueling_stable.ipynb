# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython import display

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
import numpy as np
import math
import random

# %%
import time

# %%
def show_state(env, episode,step, info=""):
    plt.figure(99999,figsize=[8,6])
    plt.clf()
    plt.imshow(env.render(mode='rgb_array'))
    plt.title("episode: {} step: {} ".format(episode,step))
    #plt.title("%s | Step: %d %s" % (env._spec.id,step, info))
    plt.axis('off')

    display.clear_output(wait=True)
    display.display(plt.gcf())

# %%
import gym

# %%
use_cuda = torch.cuda.is_available()
device=torch.device("cuda:4" if use_cuda else "cpu")

# %%
###### PARAMS ######
learning_rate = 0.001
num_episodes = 1000
gamma=0.9999
#gamma=0.85
egreedy = 0.9
egreedy_final = 0.01
egreedy_decay = 500

report_interval=10

score_to_solve = 195

hidden_layer_size=64

replay_memory_size=500000

batch_size=32

update_target_frequency = 1500

clip_error=False

double_dqn=True

# %%
env = gym.make('CartPole-v0')

# %%
#env = gym.wrappers.Monitor(env, '../mp4/sandbox10',video_callable=lambda episode_id: True,force=True)
#env = gym.wrappers.Monitor(env, '../mp4/cartpole-5',video_callable=lambda episode_id: episode_id%10==0)

# %%
number_of_inputs=env.observation_space.shape[0]
number_of_outputs=env.action_space.n

# %%
def calculate_epsilon(steps_done):
    epsilon = egreedy_final + (egreedy - egreedy_final) * \
              math.exp(-1. * steps_done / egreedy_decay )
    return epsilon

# %%
o=torch.arange(20,dtype=torch.float32).view(-1,4).contiguous()

# %%
class ExperienceReplay():
    def __init__(self, capacity):
        self.capacity=capacity
        self.memory=[]
        self.position=0
        
    
    def push(self, state,
             action, new_state,
             reward, done):
        
            transition=(state,action,new_state,reward,done)
            
            if self.position>=len(self.memory):
                self.memory.append(transition)
            else:
                self.memory[self.position]=transition
                
            self.position=(self.position+1)%self.capacity
        
    
    def sample(self,batch_size):
        return zip(*random.sample(self.memory, batch_size))
    
    def __len__(self):
        return len(self.memory)

# %%
class NeuralNetworkDueling(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.linear1 = nn.Linear(number_of_inputs,hidden_layer_size)
        self.advantage = nn.Linear(hidden_layer_size,number_of_outputs)
        self.value = nn.Linear(hidden_layer_size,1)
        
        self.activation=nn.Tanh()
        
    def forward(self, x):
        
        #print('x shape {} and value:'.format(x.shape))
        #print(x.detach().cpu())
        
        output1 = self.linear1(x)
        output1 = self.activation(output1)
        
        #print('output1 shape {} and value:'.format(output1.shape))
        #print(output1.detach().cpu())
        
        output_advantage=self.advantage(output1)
        output_value=self.value(output1)
        
        #print('output_advantage shape {} and value:'.format(output_advantage.shape))
        #print(output_advantage.detach().cpu())
        
        #print('output_value shape {} and value:'.format(output_value.shape))
        #print(output_value.detach().cpu())
        
        #print('output_advantage.mean shape {} and value:'.format(output_advantage.mean(dim=1,keepdim=True).shape))
        #print(output_advantage.mean(dim=1,keepdim=True).detach().cpu())
        
        output_final=output_value+output_advantage-output_advantage.mean(dim=1,keepdim=True)
        
        
        return output_final

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.linear1 = nn.Linear(number_of_inputs,hidden_layer_size)
        self.linear2 = nn.Linear(hidden_layer_size,number_of_outputs)
        
        self.activation=nn.Tanh()
        
    def forward(self, x):
        output1 = self.linear1(x)
        output1 = self.activation(output1)
        output2 = self.linear2(output1)
        
        return output2

# %%
class QNet_Agent():
    def __init__(self):
        
        self.nn = NeuralNetwork().to(device)
        self.target_nn = NeuralNetwork().to(device)
        
        self.loss_function = nn.MSELoss()
        self.optimizer = optim.Adam(params=self.nn.parameters(), lr=learning_rate)
        
        self.update_target_counter = 0
        
    def select_action(self,state,epsilon):
        
        random_for_egreedy=torch.rand(1).item()
        
        if random_for_egreedy>epsilon:
            self.nn.eval()
            with torch.no_grad():
                state=torch.Tensor(state).to(device)
                predicted_value_from_nn=self.nn(state.unsqueeze(dim=0)).squeeze()
                action=torch.argmax(predicted_value_from_nn).item()
        else:
            action=env.action_space.sample()
                
                
        return action
    
    def optimize(self):
        
        if len(memory)<batch_size:
            return
        
        state, action, new_state, reward, done = memory.sample(batch_size)
        
        state=torch.Tensor(state).to(device)
        new_state=torch.Tensor(new_state).to(device)
        reward=torch.Tensor(reward).to(device)
        
        #the view call below is to transform into column vector
        #so that it can be used in the gather call
        #i.e. we will use it to pick out from the computed value
        #tensor only values indexed by selected action
        action=(torch.Tensor(action).view(-1,1).long()).to(device)
        #print('action: ')
        #print(action)
        #print('contiguous?', action.is_contiguous())
        done=torch.Tensor(done).to(device)
        
        #print('shape of: state, new state, reward, action, done:')
        #print(state.shape)
        #print(new_state.shape)
        #print(reward.shape)
        #print(action.shape)
        #print(done.shape)
        
        
        self.nn.eval()
        self.target_nn.eval()
            
            
        if double_dqn:
            #print('in double DQN')
            new_state_values_from_nn=self.nn(new_state).detach()
            #print('new_state_values_from_nn shape {} and value:'.format(new_state_values_from_nn.shape))
            #print(new_state_values_from_nn)
            max_new_state_indexes=torch.max(new_state_values_from_nn,dim=1)[1].view(-1,1)
            #print('max_new_state_indexes shape {} and value:'.format(max_new_state_indexes.shape))
            #print(max_new_state_indexes)
            new_state_values=self.target_nn(new_state).detach()
            #print('new_state_values shape {} and value:'.format(new_state_values.shape))
            #print(new_state_values)
            max_new_state_values=torch.gather(new_state_values,1,max_new_state_indexes).squeeze()
            #print('max_new_state_values shape {} and value:'.format(max_new_state_values.shape))
            #print(max_new_state_values)
        else:
            #print('in regular DQN')
            new_state_values=self.target_nn(new_state).detach()
            #print('new_state_values shape {} and value'.format(new_state_values.shape))
            #print(new_state_values)
        
            max_new_state_values=torch.max(new_state_values,dim=1)[0]
            #print('max_new_state_values shape {} and value'.format(max_new_state_values.shape))
            #print(max_new_state_values)
            
        target_value=(reward + (1-done)*gamma*max_new_state_values).view(-1,1)
        
        #print('shape of: target_value')
        #print(target_value.shape)
        self.nn.train()
        
        #this will select only the values of the desired actions
        predicted_value=torch.gather(self.nn(state),1,action)
        #print('shape of: predicted_value')
        #print(predicted_value.shape)
        
        
        loss=self.loss_function(predicted_value,target_value)
        self.optimizer.zero_grad()
        loss.backward()
        
        if clip_error:
            for param in self.nn.parameters():
                param.grad.clamp_(-1.0,1.0)
        
        self.optimizer.step()
        
        if self.update_target_counter % update_target_frequency == 0:
            #print("***********************")
            #print("UPDATING TARGET NETWORK")
            #print("update counter: {}".format(self.update_target_counter))
            #print("***********************")
            self.target_nn.load_state_dict(self.nn.state_dict())
        
        self.update_target_counter+=1

# %%
memory=ExperienceReplay(replay_memory_size)

# %%
qnet_agent=QNet_Agent()

# %%
seed_value=23
env.seed(seed_value)
torch.manual_seed(seed_value)
random.seed(seed_value)

# %%
# %%time

steps_total=np.full([num_episodes],-999,dtype=np.int32)

frames_total=0

solved_after = 0
solved = False

start_time = time.time()

for i_episode in range(num_episodes):
    
    state = env.reset()
    #for step in range(100):
    step=0
    while True:
        
        step+=1
        frames_total += 1
        
        epsilon=calculate_epsilon(frames_total)
        
        #action=env.action_space.sample()
        action=qnet_agent.select_action(state,epsilon)
        
        new_state, reward, done, info = env.step(action)
        memory.push(state, action, new_state,
                     reward, done)
        
        qnet_agent.optimize()
        
        state=new_state
        
        if done:
            steps_total[i_episode]=step
            
            if i_episode>100:
                mean_reward_100 = np.sum(steps_total[i_episode-100:i_episode])/100
            
                if (mean_reward_100 > score_to_solve and solved == False):
                    print("SOLVED! After %i episodes " % i_episode)
                    solved_after = i_episode
                    solved = True
            
            if (i_episode % report_interval == 0 and i_episode>1):
                print("**** Episode  {} **** ".format(i_episode))
                recent_avg_reward=np.average(steps_total[i_episode-report_interval:i_episode])
                print("Recent average reward: {}".format(recent_avg_reward))
                if i_episode>100:
                    print("Reward over last 100: {}".format(mean_reward_100))
                full_avg_so_far=np.average(steps_total[:i_episode])
                print("Average over all episodes so far: {}".format(full_avg_so_far))
                print("epsilon: {}".format(epsilon))
            
                #print("Episode {} finished after: {}".format(i_episode,step))
            break
            
if solved:
    print("Solved after %i episodes" % solved_after)
# Out:
# **** Episode  10 ****
# Recent average reward: 17.8
# Average over all episodes so far: 17.8
# epsilon: 0.6149957678554857
# **** Episode  20 ****
# Recent average reward: 13.1
# Average over all episodes so far: 15.45
# epsilon: 0.480229777119658
# **** Episode  30 ****
# Recent average reward: 13.0
# Average over all episodes so far: 14.633333333333333
# epsilon: 0.3711240263865678
# **** Episode  40 ****
# Recent average reward: 12.1
# Average over all episodes so far: 14.0
# epsilon: 0.29237090218623185
# **** Episode  50 ****
# Recent average reward: 10.8
# Average over all episodes so far: 13.36
# epsilon: 0.23888540483254816
# **** Episode  60 ****
# Recent average reward: 10.3
# Average over all episodes so far: 12.85
# epsilon: 0.19702110336868062
# **** Episode  70 ****
# Recent average reward: 11.3
# Average over all episodes so far: 12.628571428571428
# epsilon: 0.15889203749300074
# **** Episode  80 ****
# Recent average reward: 9.7
# Average over all episodes so far: 12.2625
# epsilon: 0.13239107646540987
# **** Episode  90 ****
# Recent average reward: 12.3
# Average over all episodes so far: 12.266666666666667
# epsilon: 0.10589189495476907
# **** Episode  100 ****
# Recent average reward: 9.8
# Average over all episodes so far: 12.02
# epsilon: 0.08882431085929567
# **** Episode  110 ****
# Recent average reward: 10.4
# Reward over last 100: 11.28
# Average over all episodes so far: 11.872727272727273
# epsilon: 0.07414983139250182
# **** Episode  120 ****
# Recent average reward: 10.2
# Reward over last 100: 10.99
# Average over all episodes so far: 11.733333333333333
# epsilon: 0.06220725462519045
# **** Episode  130 ****
# Recent average reward: 9.9
# Reward over last 100: 10.68
# Average over all episodes so far: 11.592307692307692
# epsilon: 0.052829257809596845
# **** Episode  140 ****
# Recent average reward: 10.4
# Reward over last 100: 10.51
# Average over all episodes so far: 11.507142857142858
# epsilon: 0.04478622457010432
# **** Episode  150 ****
# Recent average reward: 9.3
# Reward over last 100: 10.36
# Average over all episodes so far: 11.36
# epsilon: 0.03893990569982485
# **** Episode  160 ****
# Recent average reward: 9.9
# Reward over last 100: 10.32
# Average over all episodes so far: 11.26875
# epsilon: 0.03369399078762338
# **** Episode  170 ****
# Recent average reward: 9.8
# Reward over last 100: 10.17
# Average over all episodes so far: 11.18235294117647
# epsilon: 0.029244426045495563
# **** Episode  180 ****
# Recent average reward: 10.3
# Reward over last 100: 10.23
# Average over all episodes so far: 11.133333333333333
# epsilon: 0.02575600342878212
# **** Episode  190 ****
# Recent average reward: 10.3
# Reward over last 100: 10.03
# Average over all episodes so far: 11.089473684210526
# epsilon: 0.02274605054862145
# **** Episode  200 ****
# Recent average reward: 11.0
# Reward over last 100: 10.15
# Average over all episodes so far: 11.085
# epsilon: 0.020352431945876423
# **** Episode  210 ****
# Recent average reward: 9.8
# Reward over last 100: 10.09
# Average over all episodes so far: 11.023809523809524
# epsilon: 0.01850982571818372
# **** Episode  220 ****
# Recent average reward: 9.1
# Reward over last 100: 9.98
# Average over all episodes so far: 10.936363636363636
# epsilon: 0.017108003926700397
# **** Episode  230 ****
# Recent average reward: 9.7
# Reward over last 100: 9.96
# Average over all episodes so far: 10.882608695652173
# epsilon: 0.015854563617798863
# **** Episode  240 ****
# Recent average reward: 9.5
# Reward over last 100: 9.87
# Average over all episodes so far: 10.825
# epsilon: 0.014831811565790914
# **** Episode  250 ****
# Recent average reward: 9.7
# Reward over last 100: 9.91
# Average over all episodes so far: 10.78
# epsilon: 0.013987727272504791
# **** Episode  260 ****
# Recent average reward: 9.5
# Reward over last 100: 9.87
# Average over all episodes so far: 10.73076923076923
# epsilon: 0.013284523088065945
# **** Episode  270 ****
# Recent average reward: 9.8
# Reward over last 100: 9.87
# Average over all episodes so far: 10.696296296296296
# epsilon: 0.012678404985613664
# **** Episode  280 ****
# Recent average reward: 10.0
# Reward over last 100: 9.84
# Average over all episodes so far: 10.67142857142857
# epsilon: 0.012214931467252658
# **** Episode  290 ****
# Recent average reward: 10.0
# Reward over last 100: 9.81
# Average over all episodes so far: 10.648275862068965
# epsilon: 0.01181343250819989
# **** Episode  300 ****
# Recent average reward: 9.1
# Reward over last 100: 9.62
# Average over all episodes so far: 10.596666666666666
# epsilon: 0.011511679769588896
# **** Episode  310 ****
# Recent average reward: 9.0
# Reward over last 100: 9.54
# Average over all episodes so far: 10.54516129032258
# epsilon: 0.011260138282208655
# **** Episode  320 ****
# Recent average reward: 10.0
# Reward over last 100: 9.63
# Average over all episodes so far: 10.528125
# epsilon: 0.011035849085361867
# **** Episode  330 ****
# Recent average reward: 14.2
# Reward over last 100: 10.08
# Average over all episodes so far: 10.639393939393939
# epsilon: 0.010779752640409835
# **** Episode  340 ****
# Recent average reward: 11.7
# Reward over last 100: 10.3
# Average over all episodes so far: 10.670588235294117
# epsilon: 0.010601229509922521
# **** Episode  350 ****
# Recent average reward: 11.1
# Reward over last 100: 10.44
# Average over all episodes so far: 10.682857142857143
# epsilon: 0.010494218013005882
# **** Episode  360 ****
# Recent average reward: 11.0
# Reward over last 100: 10.59
# Average over all episodes so far: 10.691666666666666
# epsilon: 0.010395035937473558
# **** Episode  370 ****
# Recent average reward: 11.5
# Reward over last 100: 10.76
# Average over all episodes so far: 10.713513513513513
# epsilon: 0.01031449769332954
# **** Episode  380 ****
# Recent average reward: 12.6
# Reward over last 100: 11.02
# Average over all episodes so far: 10.763157894736842
# epsilon: 0.010244441677275206
# **** Episode  390 ****
# Recent average reward: 9.8
# Reward over last 100: 11.0
# Average over all episodes so far: 10.738461538461538
# epsilon: 0.010201336319620393
# **** Episode  400 ****
# Recent average reward: 9.2
# Reward over last 100: 11.01
# Average over all episodes so far: 10.7
# epsilon: 0.01016783422590993
# **** Episode  410 ****
# Recent average reward: 10.7
# Reward over last 100: 11.18
# Average over all episodes so far: 10.7
# epsilon: 0.010134959771036588
# **** Episode  420 ****
# Recent average reward: 10.4
# Reward over last 100: 11.22
# Average over all episodes so far: 10.692857142857143
# epsilon: 0.01010961527570895
# **** Episode  430 ****
# Recent average reward: 15.5
# Reward over last 100: 11.35
# Average over all episodes so far: 10.804651162790698
# epsilon: 0.010080557945206294
# **** Episode  440 ****
# Recent average reward: 13.1
# Reward over last 100: 11.49
# Average over all episodes so far: 10.856818181818182
# epsilon: 0.010061866370327549
# **** Episode  450 ****
# Recent average reward: 12.4
# Reward over last 100: 11.62
# Average over all episodes so far: 10.891111111111112
# epsilon: 0.010048278037239624
# **** Episode  460 ****
# Recent average reward: 11.3
# Reward over last 100: 11.65
# Average over all episodes so far: 10.9
# epsilon: 0.010038589365823278
# **** Episode  470 ****
# Recent average reward: 11.6
# Reward over last 100: 11.66
# Average over all episodes so far: 10.914893617021276
# epsilon: 0.010030538150612169
# **** Episode  480 ****
# Recent average reward: 9.4
# Reward over last 100: 11.34
# Average over all episodes so far: 10.883333333333333
# epsilon: 0.01002530436072893
# **** Episode  490 ****
# Recent average reward: 9.6
# Reward over last 100: 11.32
# Average over all episodes so far: 10.857142857142858
# epsilon: 0.010020925672233387
# **** Episode  500 ****
# Recent average reward: 9.3
# Reward over last 100: 11.33
# Average over all episodes so far: 10.826
# epsilon: 0.010017339319771315
# **** Episode  510 ****
# Recent average reward: 9.7
# Reward over last 100: 11.23
# Average over all episodes so far: 10.803921568627452
# epsilon: 0.010014310259702239
# **** Episode  520 ****
# Recent average reward: 11.7
# Reward over last 100: 11.36
# Average over all episodes so far: 10.821153846153846
# epsilon: 0.010011301966551788
# **** Episode  530 ****
# Recent average reward: 12.3
# Reward over last 100: 11.04
# Average over all episodes so far: 10.849056603773585
# epsilon: 0.010008854951036178
# **** Episode  540 ****
# Recent average reward: 9.5
# Reward over last 100: 10.68
# Average over all episodes so far: 10.824074074074074
# epsilon: 0.010007308051910316
# **** Episode  550 ****
# Recent average reward: 10.5
# Reward over last 100: 10.49
# Average over all episodes so far: 10.818181818181818
# epsilon: 0.010005911956003428
# **** Episode  560 ****
# Recent average reward: 10.7
# Reward over last 100: 10.43
# Average over all episodes so far: 10.816071428571428
# epsilon: 0.010004801732266717
# **** Episode  570 ****
# Recent average reward: 14.1
# Reward over last 100: 10.68
# Average over all episodes so far: 10.873684210526315
# epsilon: 0.010003614583887193
# **** Episode  580 ****
# Recent average reward: 18.4
# Reward over last 100: 11.58
# Average over all episodes so far: 11.00344827586207
# epsilon: 0.010002437509305951
# **** Episode  590 ****
# Recent average reward: 18.6
# Reward over last 100: 12.48
# Average over all episodes so far: 11.132203389830508
# epsilon: 0.010001721122581693
# **** Episode  600 ****
# Recent average reward: 21.9
# Reward over last 100: 13.74
# Average over all episodes so far: 11.311666666666667
# epsilon: 0.010001048097631835
# **** Episode  610 ****
# Recent average reward: 29.8
# Reward over last 100: 15.75
# Average over all episodes so far: 11.614754098360656
# epsilon: 0.010000605910339614
# **** Episode  620 ****
# Recent average reward: 27.1
# Reward over last 100: 17.29
# Average over all episodes so far: 11.864516129032259
# epsilon: 0.010000315680940229
# **** Episode  630 ****
# Recent average reward: 22.3
# Reward over last 100: 18.29
# Average over all episodes so far: 12.03015873015873
# epsilon: 0.010000198092089428
# **** Episode  640 ****
# Recent average reward: 92.9
# Reward over last 100: 26.63
# Average over all episodes so far: 13.29375
# epsilon: 0.010000033809168418
# **** Episode  650 ****
# Recent average reward: 66.6
# Reward over last 100: 32.24
# Average over all episodes so far: 14.113846153846154
# epsilon: 0.010000007978353171
# **** Episode  660 ****
# Recent average reward: 83.9
# Reward over last 100: 39.56
# Average over all episodes so far: 15.171212121212122
# epsilon: 0.010000001400363745
# **** Episode  670 ****
# Recent average reward: 107.3
# Reward over last 100: 48.88
# Average over all episodes so far: 16.546268656716418
# epsilon: 0.010000000144674632
# **** Episode  680 ****
# Recent average reward: 139.7
# Reward over last 100: 61.01
# Average over all episodes so far: 18.35735294117647
# epsilon: 0.010000000010875226
# **** Episode  690 ****
# Recent average reward: 129.0
# Reward over last 100: 72.05
# Average over all episodes so far: 19.96086956521739
# epsilon: 0.010000000000649526
# **** Episode  700 ****
# Recent average reward: 178.0
# Reward over last 100: 87.66
# Average over all episodes so far: 22.21857142857143
# epsilon: 0.01000000000002005
# **** Episode  710 ****
# Recent average reward: 187.6
# Reward over last 100: 103.44
# Average over all episodes so far: 24.547887323943662
# epsilon: 0.01000000000000047
# **** Episode  720 ****
# Recent average reward: 195.2
# Reward over last 100: 120.25
# Average over all episodes so far: 26.918055555555554
# epsilon: 0.010000000000000009
# **** Episode  730 ****
# Recent average reward: 197.4
# Reward over last 100: 137.76
# Average over all episodes so far: 29.253424657534246
# epsilon: 0.01
# **** Episode  740 ****
# Recent average reward: 199.7
# Reward over last 100: 148.44
# Average over all episodes so far: 31.556756756756755
# epsilon: 0.01
# **** Episode  750 ****
# Recent average reward: 198.1
# Reward over last 100: 161.59
# Average over all episodes so far: 33.77733333333333
# epsilon: 0.01
# **** Episode  760 ****
# Recent average reward: 200.0
# Reward over last 100: 173.2
# Average over all episodes so far: 35.964473684210525
# epsilon: 0.01
# **** Episode  770 ****
# Recent average reward: 200.0
# Reward over last 100: 182.47
# Average over all episodes so far: 38.0948051948052
# epsilon: 0.01
# **** Episode  780 ****
# Recent average reward: 200.0
# Reward over last 100: 188.5
# Average over all episodes so far: 40.17051282051282
# epsilon: 0.01
# SOLVED! After 790 episodes
# **** Episode  790 ****
# Recent average reward: 200.0
# Reward over last 100: 195.6
# Average over all episodes so far: 42.19367088607595
# epsilon: 0.01
# **** Episode  800 ****
# Recent average reward: 200.0
# Reward over last 100: 197.8
# Average over all episodes so far: 44.16625
# epsilon: 0.01
# **** Episode  810 ****
# Recent average reward: 200.0
# Reward over last 100: 199.04
# Average over all episodes so far: 46.090123456790124
# epsilon: 0.01
# **** Episode  820 ****
# Recent average reward: 199.6
# Reward over last 100: 199.48
# Average over all episodes so far: 47.96219512195122
# epsilon: 0.01
# **** Episode  830 ****
# Recent average reward: 200.0
# Reward over last 100: 199.74
# Average over all episodes so far: 49.79397590361446
# epsilon: 0.01
# **** Episode  840 ****
# Recent average reward: 196.4
# Reward over last 100: 199.41
# Average over all episodes so far: 51.53928571428571
# epsilon: 0.01
# **** Episode  850 ****
# Recent average reward: 200.0
# Reward over last 100: 199.6
# Average over all episodes so far: 53.28588235294118
# epsilon: 0.01
# **** Episode  860 ****
# Recent average reward: 200.0
# Reward over last 100: 199.6
# Average over all episodes so far: 54.99186046511628
# epsilon: 0.01
# **** Episode  870 ****
# Recent average reward: 200.0
# Reward over last 100: 199.6
# Average over all episodes so far: 56.65862068965517
# epsilon: 0.01
# **** Episode  880 ****
# Recent average reward: 199.3
# Reward over last 100: 199.53
# Average over all episodes so far: 58.279545454545456
# epsilon: 0.01
# **** Episode  890 ****
# Recent average reward: 200.0
# Reward over last 100: 199.53
# Average over all episodes so far: 59.87191011235955
# epsilon: 0.01
# **** Episode  900 ****
# Recent average reward: 200.0
# Reward over last 100: 199.53
# Average over all episodes so far: 61.42888888888889
# epsilon: 0.01
# **** Episode  910 ****
# Recent average reward: 200.0
# Reward over last 100: 199.53
# Average over all episodes so far: 62.95164835164835
# epsilon: 0.01
# **** Episode  920 ****
# Recent average reward: 200.0
# Reward over last 100: 199.57
# Average over all episodes so far: 64.44130434782609
# epsilon: 0.01
# **** Episode  930 ****
# Recent average reward: 200.0
# Reward over last 100: 199.57
# Average over all episodes so far: 65.8989247311828
# epsilon: 0.01
# **** Episode  940 ****
# Recent average reward: 200.0
# Reward over last 100: 199.93
# Average over all episodes so far: 67.32553191489362
# epsilon: 0.01
# **** Episode  950 ****
# Recent average reward: 200.0
# Reward over last 100: 199.93
# Average over all episodes so far: 68.7221052631579
# epsilon: 0.01
# **** Episode  960 ****
# Recent average reward: 200.0
# Reward over last 100: 199.93
# Average over all episodes so far: 70.08958333333334
# epsilon: 0.01
# **** Episode  970 ****
# Recent average reward: 200.0
# Reward over last 100: 199.93
# Average over all episodes so far: 71.42886597938144
# epsilon: 0.01
# **** Episode  980 ****
# Recent average reward: 200.0
# Reward over last 100: 200.0
# Average over all episodes so far: 72.7408163265306
# epsilon: 0.01
# **** Episode  990 ****
# Recent average reward: 200.0
# Reward over last 100: 200.0
# Average over all episodes so far: 74.02626262626262
# epsilon: 0.01
# Solved after 790 episodes
# CPU times: user 4min 38s, sys: 4.16 s, total: 4min 42s
# Wall time: 4min 49s

# %%
plt.plot(steps_total)
plt.show()

# %%
print("Average number of steps: {}". format(np.average(steps_total)))
# Out:
# Average number of steps: 75.286

# %%
print("Average number of steps=reward: {}". format(np.average(steps_total)))
print("Average number of steps=reward in last 100 episodes: {}". format(np.average(steps_total[-100:])))
# Out:
# Average number of steps=reward: 75.286
# Average number of steps=reward in last 100 episodes: 200.0

# %% [markdown]
# plt.figure(1,figsize=[12,5])
# plt.title("Rewards")
# plt.bar(torch.arange(len(rewards_total)), rewards_total,alpha=0.6, color='green')
# #plt.plot(rewards_total)
# plt.show()

# %%
plt.figure(2,figsize=[12,5])
plt.title("Steps to finish episode")
plt.plot(steps_total)
plt.show()
